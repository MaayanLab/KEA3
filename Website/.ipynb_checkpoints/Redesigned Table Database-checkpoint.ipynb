# %%
import pandas as pd
import numpy as np

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:systemsbiology@localhost:3306/test')

# %%
species = pd.DataFrame(columns = ['id', 'kind'])

# %%
species = species.append([{
    'id': 1,
    'kind': 'Homo sapiens'
},

{
    'id': 2,
    'kind': 'Mus musculus'
},],
    ignore_index = True)

# %%
species.to_sql('species', con= engine, if_exists = 'replace', index = False)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# /home/maayanlab/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# /home/maayanlab/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#
# /home/maayanlab/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     165
# --> 166         result = self._query(query)
#     167         self._executed = query
#
# ...

# %%
interaction_type = pd.DataFrame(columns = ['id', 'kind'])

# %%
interaction_type = interaction_type.append([{
    'id': 1,
    'kind': 'kinase-substrate'
},

{
    'id': 2,
    'kind': 'protein-protein'
},
    
{
    'id': 3,
    'kind': 'transcription factor-target'
},],
    ignore_index = True)

# %%
interaction_type.to_sql('interaction_type', con= engine, if_exists = 'replace', index = False)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# /home/maayanlab/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# /home/maayanlab/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#
# /home/maayanlab/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     165
# --> 166         result = self._query(query)
#     167         self._executed = query
#
# ...
