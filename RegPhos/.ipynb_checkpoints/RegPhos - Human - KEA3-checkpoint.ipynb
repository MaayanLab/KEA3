# %% [markdown]
# # RegPhos (Human) Data Formatting
# This file takes data regarding human kinase-protein interactions from the RegPhos database and converts the data into the .gmt format. The data was retrieved from the RegPhos database on Wed, Jun 14 2017 15:24:15 as a .txt and was transferred to the excel format used on Wed, Jun 14 2017 15:39:54. This data will be added to enhance the KEA2 database and will be suitably formatted for use by ENRICHR and X2K.

# %% [markdown]
# ## Import packages necessary for following program

# %%
# %run /home/maayanlab/Desktop/Projects/Scripts/init.ipy
# %run /home/maayanlab/Desktop/Projects/Scripts/Scripts.py

# %% [markdown]
# ## Create a dataframe from a file containing Human RegPhos data

# %%
#Define column names as headers from original .txt file
colnames = ['ID', 'AC', 'position', 'decription', 
            'catalytic_kinase','reference', 'resource', 'code' ]

#read data from excel file into dataframe 'regphos_df'
regphos_df = pd.read_table('~/Desktop/Projects/KEA3/RegPhos_Phos_human.txt')

regphos_df.columns = colnames

#drop all rows with an 'NaN' value for the kinases
regphos_df.dropna(axis = 0, inplace = True)

#View dataframe
regphos_df.head(50)
# Out:
# /home/maayanlab/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              ID      AC  position        decription catalytic_kinase  \
# 0   AXA2L_HUMAN  A6NMY6        24   Phosphotyrosine              SRC
# 1    CLM7_HUMAN  A8K4G0       188   Phosphotyrosine              FYN
# 2    SGK1_HUMAN  O00141        78     Phosphoserine      Erk5(MAPK7)
# 3    SGK1_HUMAN  O00141       256  Phosphothreonine            PDHK2
# 4    SGK1_HUMAN  O00141       256  Phosphothreonine             PDK1
# 5    SGK1_HUMAN  O00141       369  Phosphothreonine        PKA_group
# 6    SGK1_HUMAN  O00141       377     Phosphoserine             NEK6
# 7    SGK1_HUMAN  O00141       422     Phosphoserine             NEK6
# 8    SGK1_HUMAN  O00141       422     Phosphoserine            PDHK2
# 9    SGK1_HUMAN  O00141       422     Phosphoserine             PDK1
# 10  SNP23_HUMAN  O00161        23     Phosphoserine             PKCa
# 11  SNP23_HUMAN  O00161        24  Phosphothreonine             PKCa
# 12  SNP23_HUMAN  O00161       161     Phosphoserine             PKCa
# 13    PLM_HUMAN  O00168        83     Phosphoserine        PKA_group
# 14    PLM_HUMAN  O00168        88     Phosphoserine        PKA_group
# 15  APBB1_HUMAN  O00213       175     Phosphoserine      Erk2(MAPK1)
# 16  APBB1_HUMAN  O00213       287     Phosphoserine      Erk2(MAPK1)
# 17  APBB1_HUMAN  O00213       347     Phosphoserine      Erk2(MAPK1)
# 18  APBB1_HUMAN  O00213       547   Phosphotyrosine        ABL1(Abl)
# 19  APBB1_HUMAN  O00213       709  Phosphothreonine      Erk2(MAPK1)
# 20   CBX4_HUMAN  O00257       497  Phosphothreonine            HIPK2
# 21  SPT5H_HUMAN  O00267       775  Phosphothreonine             CDK9
# 22  SPT5H_HUMAN  O00267       784  Phosphothreonine             CDK9
# 23  EIF3F_HUMAN  O00303        46     Phosphoserine            CDC21
# 24  PK3CD_HUMAN  O00329      1039     Phosphoserine    autocatalysis
# 25  PK3CD_HUMAN  O00329      1039     Phosphoserine           PIK3CD
# 26   WASL_HUMAN  O00401       242     Phosphoserine              ACK
# 27   WASL_HUMAN  O00401       256   Phosphotyrosine              FAK
# 28   WASL_HUMAN  O00401       256   Phosphotyrosine              ACK
# 29   EF2K_HUMAN  O00418        78     Phosphoserine           AMPKa1
# 30   EF2K_HUMAN  O00418        78     Phosphoserine           AMPKa2
# 31   EF2K_HUMAN  O00418        78     Phosphoserine       AMPK_group
# 32   EF2K_HUMAN  O00418       359     Phosphoserine     p38d(MAPK13)
# 33   EF2K_HUMAN  O00418       359     Phosphoserine             CDC2
# 34   EF2K_HUMAN  O00418       366     Phosphoserine           AMPKa1
# 35   EF2K_HUMAN  O00418       366     Phosphoserine           AMPKa2
# 36   EF2K_HUMAN  O00418       366     Phosphoserine            PKACa
# 37   EF2K_HUMAN  O00418       366     Phosphoserine             RSK3
# 38   EF2K_HUMAN  O00418       366     Phosphoserine       AMPK_group
# 39   EF2K_HUMAN  O00418       366     Phosphoserine     p70S6K_group
# 40   EF2K_HUMAN  O00418       366     Phosphoserine        RSK_group
# 41   EF2K_HUMAN  O00418       377     Phosphoserine         MAPKAPK2
# 42   EF2K_HUMAN  O00418       377     Phosphoserine         MAPKAPK3
# 43   EF2K_HUMAN  O00418       377     Phosphoserine         MAPKAPK5
# 44   EF2K_HUMAN  O00418       396     Phosphoserine     p38b(MAPK11)
# 45   EF2K_HUMAN  O00418       396     Phosphoserine     p38g(MAPK12)
# 46   EF2K_HUMAN  O00418       396     Phosphoserine     p38d(MAPK13)
# 47   EF2K_HUMAN  O00418       396     Phosphoserine     p38a(MAPK14)
# 48   EF2K_HUMAN  O00418       396     Phosphoserine      JNK1(MAPK8)
# 49   EF2K_HUMAN  O00418       396     Phosphoserine      JNK2(MAPK9)
#
#                               reference            resource code
# 0                              19534553  Swiss-Prot 1010711    Y
# 1                     16920917;17928527  Swiss-Prot 1010711    Y
# 2            11254654;18691976;19369195  Swiss-Prot 1010711    S
# 3                              10191262  Swiss-Prot 1010711    T
# 4                     10191262;10357815    PhosphoELM.10011    T
# 5                              11096081  Swiss-Prot 1010711    T
# 6                              12023960            HPRD 9.0    S
# 7                     10191262;12023960            HPRD 9.0    S
# 8                     10191262;12023960            HPRD 9.0    S
# 9                     10191262;12023960    PhosphoELM.10011    S
# 10                    12930825;20068231    PhosphoELM.10011    S
# 11                    12930825;19651622    PhosphoELM.10011    T
# 12           12930825;18578522;20166139            HPRD 9.0    S
# 13                    16155364;10556585    PhosphoELM.10011    S
# 14                             21868384  Swiss-Prot 1010711    S
# 15                             14697653    PhosphoELM.10011    S
# 16                             14697653    PhosphoELM.10011    S
# 17                             14697653    PhosphoELM.10011    S
# 18                    15031292;18922798  Swiss-Prot 1010711    Y
# 19                             14697653    PhosphoELM.10011    T
# 20                             17018294    PhosphoELM.10011    T
# 21                             10757782  Swiss-Prot 1010711    T
# 22                             10757782  Swiss-Prot 1010711    T
# 23                             12446680            HPRD 9.0    S
# 24                    10064595;19369195  Swiss-Prot 1010711    S
# 25                             10064595    PhosphoELM.10011    S
# 26                             16257963  Swiss-Prot 1010711    S
# 27  16257963;17389395;18083107;19534553  Swiss-Prot 1010711    Y
# 28  16257963;17389395;18083107;19534553  Swiss-Prot 1010711    Y
# 29                    15024086;14709557            HPRD 9.0    S
# 30                    15024086;14709557            HPRD 9.0    S
# 31                             14709557    PhosphoELM.10011    S
# 32           11500363;18337751;12171600  Swiss-Prot 1010711    S
# 33                    11500363;18337751  Swiss-Prot 1010711    S
# 34  11500364;14709557;15024086;11171059            HPRD 9.0    S
# 35  11500364;14709557;15024086;11171059            HPRD 9.0    S
# 36  11500364;14709557;15024086;11171059            HPRD 9.0    S
# 37  11500364;14709557;15024086;11171059            HPRD 9.0    S
# 38                    14709557;11500364    PhosphoELM.10011    S
# 39                    14709557;11500364    PhosphoELM.10011    S
# 40                    14709557;11500364    PhosphoELM.10011    S
# 41                             12171600            HPRD 9.0    S
# 42                             12171600            HPRD 9.0    S
# 43                             12171600            HPRD 9.0    S
# 44                             12171600            HPRD 9.0    S
# 45                             12171600            HPRD 9.0    S
# 46                             12171600            HPRD 9.0    S
# 47                             12171600            HPRD 9.0    S
# 48                             12171600            HPRD 9.0    S
# 49                             12171600            HPRD 9.0    S

# %% [markdown]
# ## Convert UniProt IDs to Gene Symbols

# %%
#Use uniprot_to_symbol function from Scripts.py to convert
regphos_df['target_symbol'] = Scripts.uniprot_to_symbol(regphos_df['AC'].tolist())

regphos_df.replace('alternate', np.nan, inplace = True)

regphos_df.dropna(inplace = True)

#View dataframe
regphos_df.head()
# Out:
#             ID      AC  position        decription catalytic_kinase  \
# 0  AXA2L_HUMAN  A6NMY6        24   Phosphotyrosine              SRC
# 1   CLM7_HUMAN  A8K4G0       188   Phosphotyrosine              FYN
# 2   SGK1_HUMAN  O00141        78     Phosphoserine      Erk5(MAPK7)
# 3   SGK1_HUMAN  O00141       256  Phosphothreonine            PDHK2
# 4   SGK1_HUMAN  O00141       256  Phosphothreonine             PDK1
#
#                     reference            resource code target_symbol
# 0                    19534553  Swiss-Prot 1010711    Y       ANXA2P2
# 1           16920917;17928527  Swiss-Prot 1010711    Y       CD300LB
# 2  11254654;18691976;19369195  Swiss-Prot 1010711    S          SGK1
# 3                    10191262  Swiss-Prot 1010711    T          SGK1
# 4           10191262;10357815    PhosphoELM.10011    T          SGK1

# %% [markdown]
# ## Format names of kinases
# If there are parantheses surrounding the actual kinase name, remove the extraneous name and just extract the gene symbol of the kinase out of the parantheses.

# %%
for index, string in regphos_df.catalytic_kinase.iteritems():
    s = string
    if '(' in s:
        s = string.split('(', 2)[1]
    if ')' in s:
        s = s.split(")", 1)
        regphos_df.catalytic_kinase[index] = s[0]
# Out:
# /home/maayanlab/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %% [markdown]
# ## Create a new column combining kinases and organism

# %%
# Combine 'kinases' and 'species' into one column 'kinase_organism'
regphos_df['kinase_organism'] = ['_'.join([str(kinase), 'Homo sapiens']) for kinase
                                in regphos_df.catalytic_kinase]

#View dataframe
regphos_df.head()
# Out:
#             ID      AC  position        decription catalytic_kinase  \
# 0  AXA2L_HUMAN  A6NMY6        24   Phosphotyrosine              SRC
# 1   CLM7_HUMAN  A8K4G0       188   Phosphotyrosine              FYN
# 2   SGK1_HUMAN  O00141        78     Phosphoserine            MAPK7
# 3   SGK1_HUMAN  O00141       256  Phosphothreonine            PDHK2
# 4   SGK1_HUMAN  O00141       256  Phosphothreonine             PDK1
#
#                     reference            resource code target_symbol  \
# 0                    19534553  Swiss-Prot 1010711    Y       ANXA2P2
# 1           16920917;17928527  Swiss-Prot 1010711    Y       CD300LB
# 2  11254654;18691976;19369195  Swiss-Prot 1010711    S          SGK1
# 3                    10191262  Swiss-Prot 1010711    T          SGK1
# 4           10191262;10357815    PhosphoELM.10011    T          SGK1
#
#       kinase_organism
# 0    SRC_Homo sapiens
# 1    FYN_Homo sapiens
# 2  MAPK7_Homo sapiens
# 3  PDHK2_Homo sapiens
# 4   PDK1_Homo sapiens

# %% [markdown]
# ## Perform preliminary data processing
# Select columns necessary for .gmt format and filter into new dataframe 'df' df = phospho_df[['acc', 'kinases', 'species']]We must drop duplicates and NaNs, as well as select only the columns necessary for the .gmt file format (the protein ids and kinase gene symbols).

# %%
#select columns necessary for .gmt format and filter into new dataframe 'df'
df = regphos_df[['target_symbol', 'kinase_organism']]

#drop duplicate rows in the dataframe
df.drop_duplicates(inplace = True)

#drop all rows with an 'NaN' value for the kinases
df.dropna(axis = 0, inplace = True)

#Visualize data
df.head(50)
# Out:
# /home/maayanlab/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/maayanlab/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    target_symbol             kinase_organism
# 0        ANXA2P2            SRC_Homo sapiens
# 1        CD300LB            FYN_Homo sapiens
# 2           SGK1          MAPK7_Homo sapiens
# 3           SGK1          PDHK2_Homo sapiens
# 4           SGK1           PDK1_Homo sapiens
# 5           SGK1      PKA_group_Homo sapiens
# 6           SGK1           NEK6_Homo sapiens
# 10        SNAP23           PKCa_Homo sapiens
# 13         FXYD1      PKA_group_Homo sapiens
# 15         APBB1          MAPK1_Homo sapiens
# 18         APBB1            Abl_Homo sapiens
# 20          CBX4          HIPK2_Homo sapiens
# 21        SUPT5H           CDK9_Homo sapiens
# 23         EIF3F          CDC21_Homo sapiens
# 24        PIK3CD  autocatalysis_Homo sapiens
# 25        PIK3CD         PIK3CD_Homo sapiens
# 26          WASL            ACK_Homo sapiens
# 27          WASL            FAK_Homo sapiens
# 29         EEF2K         AMPKa1_Homo sapiens
# 30         EEF2K         AMPKa2_Homo sapiens
# 31         EEF2K     AMPK_group_Homo sapiens
# 32         EEF2K         MAPK13_Homo sapiens
# 33         EEF2K           CDC2_Homo sapiens
# 36         EEF2K          PKACa_Homo sapiens
# 37         EEF2K           RSK3_Homo sapiens
# 39         EEF2K   p70S6K_group_Homo sapiens
# 40         EEF2K      RSK_group_Homo sapiens
# 41         EEF2K       MAPKAPK2_Homo sapiens
# 42         EEF2K       MAPKAPK3_Homo sapiens
# 43         EEF2K       MAPKAPK5_Homo sapiens
# 44         EEF2K         MAPK11_Homo sapiens
# 45         EEF2K         MAPK12_Homo sapiens
# 47         EEF2K         MAPK14_Homo sapiens
# 48         EEF2K          MAPK8_Homo sapiens
# 49         EEF2K          MAPK9_Homo sapiens
# 54         DNM1L           CDC2_Homo sapiens
# 55         DNM1L         CaMK1a_Homo sapiens
# 56         DNM1L      PKA_group_Homo sapiens
# 57       PIK3C2A           CDC2_Homo sapiens
# 58         STK25  autocatalysis_Homo sapiens
# 59         STK25           YSK1_Homo sapiens
# 60       PITPNM1           CDC2_Homo sapiens
# 62       PITPNM1          MAPK1_Homo sapiens
# 64         DDX3X           CDC2_Homo sapiens
# 66         ACACB         AMPKa2_Homo sapiens
# 67         ACACB     AMPK_group_Homo sapiens
# 68         CLDN4          EphA2_Homo sapiens
# 69         SOCS3            LCK_Homo sapiens
# 71      ARHGAP33            FYN_Homo sapiens
# 72        MAP2K7         MAP3K1_Homo sapiens

# %% [markdown]
# ## Create File of 'df' for Later Data Aggregation

# %%
#Create dictionary with index numbers as keys
d = dict([(key, '') for key in df.index])

# loop through rows with iterrows()
for index, rowData in df.iterrows():
    line = ('\t'.join(rowData))
    d[index] = line
    
#Transfer tab-separated info into a new txt file
with open('Uncondensed_RegPhos_human.txt', 'w') as openfile:
    for index in d:
        openfile.write(str(d[index]) + '\n')

# %% [markdown]
# ## Set Index to 'Kinase_Organism' and Aggregate Kinase Targets

# %%
df.set_index('kinase_organism')

#Group kinases in dataframe 'kin'
#Aggregate data in 'kin' according to kinase groups
kin = df.groupby('kinase_organism').agg(lambda x: tuple(x))

#Create a new column with 'RegPhos' as description of data
kin.insert(0, 'Description', 'RegPhos')

#Visualize Data
kin.head()
# Out:
#                   Description  \
# kinase_organism
# AAK1_Homo sapiens     RegPhos
# ABL_Homo sapiens      RegPhos
# ACK_Homo sapiens      RegPhos
# AKT1_Homo sapiens     RegPhos
# AKT2_Homo sapiens     RegPhos
#
#                                                        target_symbol
# kinase_organism
# AAK1_Homo sapiens                               (NUMB, AP2M1, AP1M1)
# ABL_Homo sapiens                             (PLSCR1, CDKN1B, ROBO1)
# ACK_Homo sapiens                                             (WASL,)
# AKT1_Homo sapiens  (CHUK, FOXO3, NUAK1, TBC1D4, RAF1, ITGB3, CREB...
# AKT2_Homo sapiens                         (CHUK, ESR1, XIAP, AKT1S1)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Calculate Number of Protein Targets for each kinase
# Create a new column with the number of substrates related to each kinase, and sort the dataframe by this column

# %%
# Create column representing counts of protein targets per kinase
kin['kinase_targets_num'] = [len(lst) for kinase, lst in kin['target_symbol'].iteritems()]

# Sort kinases from max to min according to number of protein targets each has
kin.sort_values(by = ['kinase_targets_num'], ascending= False, inplace=True)

# Visualize data
kin.head()
# Out:
#                            Description  \
# kinase_organism
# PKA_group_Homo sapiens         RegPhos
# autocatalysis_Homo sapiens     RegPhos
# SRC_Homo sapiens               RegPhos
# PKC_group_Homo sapiens         RegPhos
# CK2_group_Homo sapiens         RegPhos
#
#                                                                 target_symbol  \
# kinase_organism
# PKA_group_Homo sapiens      (SGK1, FXYD1, DNM1L, AURKA, PJA2, KCNQ2, RGS14...
# autocatalysis_Homo sapiens  (PIK3CD, STK25, CASK, PDPK1, DAPK3, MAP3K7, RI...
# SRC_Homo sapiens            (ANXA2P2, TERT, PLSCR1, NPHP1, TP73, INPPL1, R...
# PKC_group_Homo sapiens      (PLSCR1, KCNJ13, ADAP1, PRKD3, RASGRP1, HAND1,...
# CK2_group_Homo sapiens      (KIF1C, VAMP4, C1R, TNF, VTN, MYCN, JUN, SSB, ...
#
#                             kinase_targets_num
# kinase_organism
# PKA_group_Homo sapiens                     163
# autocatalysis_Homo sapiens                 118
# SRC_Homo sapiens                           107
# PKC_group_Homo sapiens                     102
# CK2_group_Homo sapiens                      84

# %% [markdown]
# ## Create Histogram to display distribution of number of targets per kinase

# %%
# Create histogram displaying the distribution of the number
#targets per kinase
kin.plot.hist(by = 'kinase_targets_num', bins = 37)

#Show histogram
plt.show()

# %% [markdown]
# # Creation of Final .GMT File

# %% [markdown]
# ## Create Dictionary of Tab-Separated Rows of the Dataframe

# %%
#Reset index of the dataframe
kin.reset_index(inplace = True)

#create column 'target_symbol_merged' in which all 'target_symbol' elements are joined by a \t symbol
kin['target_symbol_merged'] = ['\t'.join(x) for x in kin['target_symbol']]

#drop the now-unneccesary column 'target_symbol' and 'kinase_targets_num'
kin.drop('target_symbol', axis=1, inplace = True)
kin.drop('kinase_targets_num', axis=1, inplace = True)

#Create dictionary 'RegPhos' with index numbers as keys
RegPhos_num = dict([(key, '') for key in kin.index])

# loop through rows with iterrows()
for index, rowData in kin.iterrows():
    line = ('\t'.join(rowData))
    RegPhos_num[index] = line

# %% [markdown]
# ## Write Info from Dictionary into a .GMT file

# %%
#Transfer tab-separated info into a new txt file
with open('RegPhosHuman.gmt', 'w') as openfile:
    for index in RegPhos_num:
        openfile.write(str(RegPhos_num[index]) + '\n')

# %% [markdown]
# ## Test: Reading in the Newly-Created .GMT File

# %%
## Review formatting of the test, looks strange on this file but .gmt looks perfect
