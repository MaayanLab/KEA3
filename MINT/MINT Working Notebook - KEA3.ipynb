# %% [markdown]
# # MINT Data Formatting
# This file takes data regarding kinase-protein interactions from the MINT database and converts the data into the .gmt format. The data was retrieved from the MINT database on Thu, Jun 15 2017. This data will be added to enhance the KEA2 database and will be suitably formatted for use by ENRICHR and X2K. The citation for the data used in this script is "MINT, the molecular interaction database: 2012 update. Licata L, Briganti L, Peluso D, Perfetto L, Iannuccelli M, Galeota E, Sacco F, Palma A, Nardozza AP, Santonico E, Castagnoli L, Cesareni G. Nucleic Acids Res. 2012 Jan;40(Database issue):D857-61. doi: 10.1093/nar/gkr930. Epub 2011 Nov 16." and can also be found on the corresponding gh.pages website.

# %% [markdown]
# ## Import packages necessary for following program

# %%
# %run /home/maayanlab/Desktop/Projects/KEA3/Scripts/init.ipy
# %run /home/maayanlab/Desktop/Projects/KEA3/Scripts/Scripts.py

# %% [markdown]
# ## Create a dataframe from a file containing MINT data

# %%
#column names as retrieved from the MINT documentation
colnames = ['identifier_A', 'identifier_B', 'alt_A', 'alt_B', 'alias_A', 'alias_B',
           'interaction_detection_method', 'first author', 'identifier of pub', 
           'ncbi_taxid_A', 'ncbi_taxid_B', 'interaction_type', 'source_database',
           'interaction_identifier', 'confidence_score', 'complex_expansion', 
            'biorole_A', 'biorole_B', 'exp_role_A', 'exp_role_B', 'interactor_typeA'
           , 'interactor_typeB', 'Xref_A', 'Xref_B', 'xref_interaction', 'annot_A',
           'annot_B', 'ncbi_taxid_host', 'interaction_params', 'creation_date',
           'update_date', 'checksum_A', 'checksum_B', 'checksum_interaction', 'negative',
           'features_B', 'stoich_A', 'stoich_B', 'identification_method_A',
           'identification_method_B', 'psi-mi A', 'psi-mi B']

#read in data using full list of columns
m = pd.read_table('~/Desktop/Projects/KEA3/MINT_MiTab.txt', names = colnames)

# %%
#View dataframe
m.head()
# Out:
#        identifier_A      identifier_B                              alt_A  \
# 0  uniprotkb:P22139  uniprotkb:P16370  intact:EBI-15802|uniprotkb:D6W2R6
# 1  uniprotkb:P50106  uniprotkb:P22139  intact:EBI-15750|uniprotkb:D6VSD7
# 2  uniprotkb:P22139  uniprotkb:P07703  intact:EBI-15802|uniprotkb:D6W2R6
# 3  uniprotkb:P04051  uniprotkb:P22139  intact:EBI-15810|uniprotkb:D6W2H5
# 4  uniprotkb:P22139  uniprotkb:P16370  intact:EBI-15802|uniprotkb:D6W2R6
#
#                                alt_B  \
# 0  intact:EBI-15773|uniprotkb:D6VVQ8
# 1  intact:EBI-15802|uniprotkb:D6W2R6
# 2  intact:EBI-15831|uniprotkb:D6W4A9
# 3  intact:EBI-15802|uniprotkb:D6W2R6
# 4  intact:EBI-15773|uniprotkb:D6VVQ8
#
#                                              alias_A  \
# 0  psi-mi:rpab5_yeast(display_long)|uniprotkb:YOR...
# 1  psi-mi:rpa14_yeast(display_long)|uniprotkb:RPA...
# 2  psi-mi:rpab5_yeast(display_long)|uniprotkb:YOR...
# 3  psi-mi:rpc1_yeast(display_long)|uniprotkb:RPO3...
# 4  psi-mi:rpab5_yeast(display_long)|uniprotkb:YOR...
#
#                                              alias_B  \
# 0  psi-mi:rpb3_yeast(display_long)|uniprotkb:YIL0...
# 1  psi-mi:rpab5_yeast(display_long)|uniprotkb:YOR...
# 2  psi-mi:rpac1_yeast(display_long)|uniprotkb:RPC...
# 3  psi-mi:rpab5_yeast(display_long)|uniprotkb:YOR...
# 4  psi-mi:rpb3_yeast(display_long)|uniprotkb:YIL0...
#
#                      interaction_detection_method          first author  \
# 0  psi-mi:"MI:0676"(tandem affinity purification)  Krogan et al. (2006)
# 1  psi-mi:"MI:0676"(tandem affinity purification)  Krogan et al. (2006)
# 2  psi-mi:"MI:0676"(tandem affinity purification)  Krogan et al. (2006)
# 3  psi-mi:"MI:0676"(tandem affinity purification)  Krogan et al. (2006)
# 4  psi-mi:"MI:0676"(tandem affinity purification)  Krogan et al. (2006)
#
#                                  identifier of pub  \
# 0  mint:MINT-5218454|pubmed:16554755|imex:IM-15332
# 1  mint:MINT-5218454|pubmed:16554755|imex:IM-15332
# 2  mint:MINT-5218454|pubmed:16554755|imex:IM-15332
# 3  mint:MINT-5218454|pubmed:16554755|imex:IM-15332
# 4  mint:MINT-5218454|pubmed:16554755|imex:IM-15332
#
#                                         ncbi_taxid_A  \
# 0  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 1  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 2  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 3  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 4  taxid:559292(yeast)|taxid:559292("Saccharomyce...
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                 checksum_B  \
# 0  rogid:cr2DgnGnKtGbd84HyGNM4xLS4FM559292
# 1  rogid:fIDAOOpJrLwSXy7vygwP4Cu96Ww559292
# 2  rogid:cr2DgnGnKtGbd84HyGNM4xLS4FM559292
# 3  rogid:DoIDVE/XVbuQ8WSo+elSj7Ho5Ww559292
# 4  rogid:cr2DgnGnKtGbd84HyGNM4xLS4FM559292
#
#                       checksum_interaction  \
# 0  rogid:JMIGnvEpr4Scb2i5tqjqSV2wvEw559292
# 1  rogid:cr2DgnGnKtGbd84HyGNM4xLS4FM559292
# 2  rogid:erepZ6yX0AYInV5koxEj9V9E2pI559292
# 3  rogid:cr2DgnGnKtGbd84HyGNM4xLS4FM559292
# 4  rogid:JMIGnvEpr4Scb2i5tqjqSV2wvEw559292
#
#                                             negative features_B  \
# 0  intact-crc:E217044E57716137|rigid:x2uppdTBgoEy...      False
# 1  intact-crc:F877914BAF04FA84|rigid:tsaqThE60JlS...      False
# 2  intact-crc:BA67000B6C6FDB37|rigid:WI8zmM8YwnP0...      False
# 3  intact-crc:29B003419662EB86|rigid:nFLdGkUKY75h...      False
# 4  intact-crc:8328974676378558|rigid:x2uppdTBgoEy...      False
#
#                                             stoich_A  \
# 0  calmodulin binding peptide plus protein a tag:...
# 1                                                  -
# 2  calmodulin binding peptide plus protein a tag:...
# 3                                                  -
# 4  calmodulin binding peptide plus protein a tag:...
#
#                                             stoich_B identification_method_A  \
# 0                                                  -                       1
# 1  calmodulin binding peptide plus protein a tag:...                       1
# 2                                                  -                       1
# 3  calmodulin binding peptide plus protein a tag:...                       1
# 4                                                  -                       1
#
#   identification_method_B                                           psi-mi A  \
# 0                       1  psi-mi:"MI:0078"(nucleotide sequence identific...
# 1                       1  psi-mi:"MI:0658"(multidimensional protein iden...
# 2                       1  psi-mi:"MI:0078"(nucleotide sequence identific...
# 3                       1  psi-mi:"MI:0658"(multidimensional protein iden...
# 4                       1  psi-mi:"MI:0078"(nucleotide sequence identific...
#
#                                             psi-mi B
# 0  psi-mi:"MI:0658"(multidimensional protein iden...
# 1  psi-mi:"MI:0078"(nucleotide sequence identific...
# 2  psi-mi:"MI:0658"(multidimensional protein iden...
# 3  psi-mi:"MI:0078"(nucleotide sequence identific...
# 4  psi-mi:"MI:0658"(multidimensional protein iden...
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Create dataframe with only data pertinent to .gmt files

# %%
#Filter only columns necessary for .gmt format
#We will be including all data, regardless of confidence score, so confidence
#score is not necessary for this dataframe
mint = m[['identifier_A', 'identifier_B', 'ncbi_taxid_A', 'ncbi_taxid_B', 
          'interaction_type', 'biorole_A', 'biorole_B']]

#Drop all NaNs in data
mint.dropna(inplace = True)

#Drop all duplicate values in the data
mint.drop_duplicates(inplace = True)

#View dataframe
mint.head(50)
# Out:
# /home/maayanlab/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/maayanlab/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
#         identifier_A      identifier_B  \
# 0   uniprotkb:P22139  uniprotkb:P16370
# 1   uniprotkb:P50106  uniprotkb:P22139
# 2   uniprotkb:P22139  uniprotkb:P07703
# 3   uniprotkb:P04051  uniprotkb:P22139
# 5   uniprotkb:P22138  uniprotkb:P22139
# 6   uniprotkb:P04050  uniprotkb:P22139
# 7   uniprotkb:P22139  uniprotkb:P04050
# 8   uniprotkb:P34087  uniprotkb:P22139
# 9   uniprotkb:P22139  uniprotkb:P04051
# 11  uniprotkb:P22139  uniprotkb:P08518
# 12  uniprotkb:P22139  uniprotkb:Q01080
# 13  uniprotkb:P38902  uniprotkb:P22139
# 14  uniprotkb:P22139  uniprotkb:P47006
# 15  uniprotkb:P47006  uniprotkb:P22139
# 16  uniprotkb:P22139  uniprotkb:P38111
# 17  uniprotkb:P22276  uniprotkb:P22139
# 18  uniprotkb:P22139  uniprotkb:P20434
# 19  uniprotkb:P22139  uniprotkb:P28000
# 21  uniprotkb:P27999  uniprotkb:P22139
# 23  uniprotkb:P20434  uniprotkb:P22139
# 24  uniprotkb:P08518  uniprotkb:P22139
# 26  uniprotkb:P38902  uniprotkb:P27692
# 27  uniprotkb:P38902  uniprotkb:Q07532
# 28  uniprotkb:P38902  uniprotkb:P16370
# 29  uniprotkb:P38902  uniprotkb:P38338
# 30  uniprotkb:P22139  uniprotkb:P38902
# 31  uniprotkb:P38902  uniprotkb:P41896
# 32  uniprotkb:P20435  uniprotkb:P38902
# 33  uniprotkb:P38902  uniprotkb:P04050
# 34  uniprotkb:P41895  uniprotkb:P38902
# 35  uniprotkb:P20433  uniprotkb:P38902
# 36  uniprotkb:P08518  uniprotkb:P38902
# 37  uniprotkb:P34087  uniprotkb:P38902
# 38  uniprotkb:P07273  uniprotkb:P38902
# 39  uniprotkb:P38902  uniprotkb:P27999
# 40  uniprotkb:P20434  uniprotkb:P38902
# 41  uniprotkb:P32558  uniprotkb:P16370
# 42  uniprotkb:P07273  uniprotkb:P16370
# 43  uniprotkb:P16370  uniprotkb:P32914
# 44  uniprotkb:P34087  uniprotkb:P16370
# 46  uniprotkb:P27692  uniprotkb:P16370
# 51  uniprotkb:P16370  uniprotkb:P15108
# 52  uniprotkb:P16370  uniprotkb:P35189
# 53  uniprotkb:P16370  uniprotkb:P22139
# 54  uniprotkb:P16370  uniprotkb:P27692
# 55  uniprotkb:P16370  uniprotkb:P07273
# 56  uniprotkb:P35189  uniprotkb:P16370
# 57  uniprotkb:P16370  uniprotkb:P27999
# 58  uniprotkb:P41896  uniprotkb:P16370
# 59  uniprotkb:P40422  uniprotkb:P16370
#
#                                          ncbi_taxid_A  \
# 0   taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 1   taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 2   taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 3   taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 5   taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 6   taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 7   taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 8   taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 9   taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 11  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 12  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 13  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 14  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 15  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 16  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 17  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 18  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 19  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 21  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 23  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 24  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 26  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 27  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 28  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 29  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 30  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 31  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 32  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 33  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 34  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 35  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 36  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 37  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 38  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 39  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 40  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 41  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 42  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 43  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 44  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 46  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 51  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 52  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 53  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 54  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 55  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 56  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 57  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 58  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 59  taxid:559292(yeast)|taxid:559292("Saccharomyce...
#
#                                          ncbi_taxid_B  \
# 0   taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 1   taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 2   taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 3   taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 5   taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 6   taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 7   taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 8   taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 9   taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 11  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 12  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 13  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 14  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 15  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 16  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 17  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 18  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 19  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 21  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 23  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 24  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 26  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 27  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 28  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 29  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 30  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 31  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 32  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 33  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 34  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 35  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 36  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 37  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 38  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 39  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 40  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 41  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 42  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 43  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 44  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 46  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 51  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 52  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 53  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 54  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 55  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 56  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 57  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 58  taxid:559292(yeast)|taxid:559292("Saccharomyce...
# 59  taxid:559292(yeast)|taxid:559292("Saccharomyce...
#
#                           interaction_type  \
# 0   psi-mi:"MI:0915"(physical association)
# 1   psi-mi:"MI:0915"(physical association)
# 2   psi-mi:"MI:0915"(physical association)
# 3   psi-mi:"MI:0915"(physical association)
# 5   psi-mi:"MI:0915"(physical association)
# 6   psi-mi:"MI:0915"(physical association)
# 7   psi-mi:"MI:0915"(physical association)
# 8   psi-mi:"MI:0915"(physical association)
# 9   psi-mi:"MI:0915"(physical association)
# 11  psi-mi:"MI:0915"(physical association)
# 12  psi-mi:"MI:0915"(physical association)
# 13  psi-mi:"MI:0915"(physical association)
# 14  psi-mi:"MI:0915"(physical association)
# 15  psi-mi:"MI:0915"(physical association)
# 16  psi-mi:"MI:0915"(physical association)
# 17  psi-mi:"MI:0915"(physical association)
# 18  psi-mi:"MI:0915"(physical association)
# 19  psi-mi:"MI:0915"(physical association)
# 21  psi-mi:"MI:0915"(physical association)
# 23  psi-mi:"MI:0915"(physical association)
# 24  psi-mi:"MI:0915"(physical association)
# 26  psi-mi:"MI:0915"(physical association)
# 27  psi-mi:"MI:0915"(physical association)
# 28  psi-mi:"MI:0915"(physical association)
# 29  psi-mi:"MI:0915"(physical association)
# 30  psi-mi:"MI:0915"(physical association)
# 31  psi-mi:"MI:0915"(physical association)
# 32  psi-mi:"MI:0915"(physical association)
# 33  psi-mi:"MI:0915"(physical association)
# 34  psi-mi:"MI:0915"(physical association)
# 35  psi-mi:"MI:0915"(physical association)
# 36  psi-mi:"MI:0915"(physical association)
# 37  psi-mi:"MI:0915"(physical association)
# 38  psi-mi:"MI:0915"(physical association)
# 39  psi-mi:"MI:0915"(physical association)
# 40  psi-mi:"MI:0915"(physical association)
# 41  psi-mi:"MI:0915"(physical association)
# 42  psi-mi:"MI:0915"(physical association)
# 43  psi-mi:"MI:0915"(physical association)
# 44  psi-mi:"MI:0915"(physical association)
# 46  psi-mi:"MI:0915"(physical association)
# 51  psi-mi:"MI:0915"(physical association)
# 52  psi-mi:"MI:0915"(physical association)
# 53  psi-mi:"MI:0915"(physical association)
# 54  psi-mi:"MI:0915"(physical association)
# 55  psi-mi:"MI:0915"(physical association)
# 56  psi-mi:"MI:0915"(physical association)
# 57  psi-mi:"MI:0915"(physical association)
# 58  psi-mi:"MI:0915"(physical association)
# 59  psi-mi:"MI:0915"(physical association)
#
#                              biorole_A                           biorole_B
# 0   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 1   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 2   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 3   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 5   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 6   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 7   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 8   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 9   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 11  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 12  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 13  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 14  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 15  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 16  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 17  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 18  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 19  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 21  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 23  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 24  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 26  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 27  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 28  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 29  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 30  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 31  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 32  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 33  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 34  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 35  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 36  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 37  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 38  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 39  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 40  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 41  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 42  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 43  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 44  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 46  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 51  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 52  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 53  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 54  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 55  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 56  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 57  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 58  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 59  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)

# %% [markdown]
# ## Filter by interaction type to only choose phosphorylation reactions

# %%
#Obtain indices of interactions that are of type 'phosphorylation reaction'
#PSI - MI for a phosphorylation reaction is MI: 0217
indices = [index for index, rowData in mint.iterrows()
           if rowData['interaction_type'] == 'psi-mi:"MI:0217"(phosphorylation reaction)']

#Filter out dataframe 'mint' to choose only phosphorylation reactions
mint_filter = mint.loc[indices]

#View dataframe
mint_filter.head(50)
# Out:
#              identifier_A        identifier_B  \
# 2831     uniprotkb:Q16539    uniprotkb:O43257
# 2832   uniprotkb:P15336-1    uniprotkb:Q16539
# 2833     uniprotkb:O43257    uniprotkb:Q15759
# 2834   uniprotkb:P15336-1    uniprotkb:Q15759
# 2922     uniprotkb:P67999    uniprotkb:P67999
# 2923     uniprotkb:P47196    uniprotkb:O08874
# 2924     uniprotkb:Q63065    uniprotkb:P67999
# 2971     uniprotkb:O00141  uniprotkb:P10636-7
# 2972     uniprotkb:P51812  uniprotkb:P10636-7
# 2973   uniprotkb:P10636-7    uniprotkb:P31749
# 2974     uniprotkb:P11275  uniprotkb:P10636-7
# 2975   uniprotkb:P10636-7    uniprotkb:O75582
# 2976     uniprotkb:P23443  uniprotkb:P10636-7
# 2977   uniprotkb:P10636-7    uniprotkb:Q15418
# 2978     uniprotkb:P49841  uniprotkb:P10636-7
# 2993     uniprotkb:P04637    uniprotkb:P49841
# 3002     uniprotkb:P06400    uniprotkb:O96017
# 3003     uniprotkb:O14757    uniprotkb:P06400
# 3004     uniprotkb:Q16539    uniprotkb:P06400
# 3110     uniprotkb:Q03160    uniprotkb:P34152
# 3153     uniprotkb:P20444    uniprotkb:O08785
# 3154     uniprotkb:O08785    uniprotkb:P63318
# 3276     uniprotkb:P68400    uniprotkb:Q16665
# 3301     uniprotkb:O95067    uniprotkb:P21333
# 3329     uniprotkb:O07778    uniprotkb:O07777
# 3371     uniprotkb:O54748    uniprotkb:Q95RA8
# 12449    uniprotkb:Q2LK75    uniprotkb:P70032
taxid:9606(human)|taxid:9606(Homo sapiens)
# 16130  taxid:284812(schpo)|taxid:284812("Schizosaccha...
# 16269       taxid:10090(mouse)|taxid:10090(Mus musculus)
# 16312         taxid:9606(human)|taxid:9606(Homo sapiens)
# 16313         taxid:9606(human)|taxid:9606(Homo sapiens)
# 16314         taxid:9606(human)|taxid:9606(Homo sapiens)
# 16593  taxid:10116(rat)|taxid:10116("Rattus norvegicu...
# 23339       taxid:10090(mouse)|taxid:10090(Mus musculus)
# 23340       taxid:10090(mouse)|taxid:10090(Mus musculus)
# 34046         taxid:9606(human)|taxid:9606(Homo sapiens)
# 34047  taxid:7227(drome)|taxid:7227("Drosophila melan...
# 34049         taxid:9606(human)|taxid:9606(Homo sapiens)
# 34050         taxid:9606(human)|taxid:9606(Homo sapiens)
# 34085  taxid:6239(caeel)|taxid:6239(Caenorhabditis el...
# 34206         taxid:9606(human)|taxid:9606(Homo sapiens)
# 34207       taxid:10090(mouse)|taxid:10090(Mus musculus)
# 34208         taxid:9606(human)|taxid:9606(Homo sapiens)
# 34641         taxid:9606(human)|taxid:9606(Homo sapiens)
# 34662         taxid:9606(human)|taxid:9606(Homo sapiens)
#
#                                  interaction_type  \
# 2831   psi-mi:"MI:0217"(phosphorylation reaction)
# 2832   psi-mi:"MI:0217"(phosphorylation reaction)
# 2833   psi-mi:"MI:0217"(phosphorylation reaction)
# 2834   psi-mi:"MI:0217"(phosphorylation reaction)
# 2922   psi-mi:"MI:0217"(phosphorylation reaction)
# 2923   psi-mi:"MI:0217"(phosphorylation reaction)
# 2924   psi-mi:"MI:0217"(phosphorylation reaction)
# 2971   psi-mi:"MI:0217"(phosphorylation reaction)
# 2972   psi-mi:"MI:0217"(phosphorylation reaction)
# 2973   psi-mi:"MI:0217"(phosphorylation reaction)
# 2974   psi-mi:"MI:0217"(phosphorylation reaction)
# 2975   psi-mi:"MI:0217"(phosphorylation reaction)
# 2976   psi-mi:"MI:0217"(phosphorylation reaction)
# 2977   psi-mi:"MI:0217"(phosphorylation reaction)
# 2978   psi-mi:"MI:0217"(phosphorylation reaction)
# 2993   psi-mi:"MI:0217"(phosphorylation reaction)
# 3002   psi-mi:"MI:0217"(phosphorylation reaction)
# 3003   psi-mi:"MI:0217"(phosphorylation reaction)
# 3004   psi-mi:"MI:0217"(phosphorylation reaction)
# 3110   psi-mi:"MI:0217"(phosphorylation reaction)
# 3153   psi-mi:"MI:0217"(phosphorylation reaction)
# 3154   psi-mi:"MI:0217"(phosphorylation reaction)
# 3276   psi-mi:"MI:0217"(phosphorylation reaction)
# 3301   psi-mi:"MI:0217"(phosphorylation reaction)
# 3329   psi-mi:"MI:0217"(phosphorylation reaction)
# 3371   psi-mi:"MI:0217"(phosphorylation reaction)
# 12449  psi-mi:"MI:0217"(phosphorylation reaction)
# 12508  psi-mi:"MI:0217"(phosphorylation reaction)
# 12509  psi-mi:"MI:0217"(phosphorylation reaction)
# 14850  psi-mi:"MI:0217"(phosphorylation reaction)
# 14862  psi-mi:"MI:0217"(phosphorylation reaction)
# 15926  psi-mi:"MI:0217"(phosphorylation reaction)
# 16130  psi-mi:"MI:0217"(phosphorylation reaction)
# 16269  psi-mi:"MI:0217"(phosphorylation reaction)
# 16312  psi-mi:"MI:0217"(phosphorylation reaction)
# 16313  psi-mi:"MI:0217"(phosphorylation reaction)
# 16314  psi-mi:"MI:0217"(phosphorylation reaction)
# 16593  psi-mi:"MI:0217"(phosphorylation reaction)
# 23339  psi-mi:"MI:0217"(phosphorylation reaction)
# 23340  psi-mi:"MI:0217"(phosphorylation reaction)
# 34046  psi-mi:"MI:0217"(phosphorylation reaction)
# 34047  psi-mi:"MI:0217"(phosphorylation reaction)
# 34049  psi-mi:"MI:0217"(phosphorylation reaction)
# 34050  psi-mi:"MI:0217"(phosphorylation reaction)
# 34085  psi-mi:"MI:0217"(phosphorylation reaction)
# 34206  psi-mi:"MI:0217"(phosphorylation reaction)
# 34207  psi-mi:"MI:0217"(phosphorylation reaction)
# 34208  psi-mi:"MI:0217"(phosphorylation reaction)
# 34641  psi-mi:"MI:0217"(phosphorylation reaction)
# 34662  psi-mi:"MI:0217"(phosphorylation reaction)
#
#                              biorole_A                        biorole_B
# 2831          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 2832   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 2833   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 2834   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 2922   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 2923          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 2924          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 2971          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 2972          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 2973   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 2974          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 2975   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 2976          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 2977   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 2978          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 2993   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 3002   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 3003          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 3004          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 3110   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 3153          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 3154   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 3276          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 3301          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 3329          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 3371          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 12449  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 12508         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 12509         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 14850         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 14862  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 15926  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 16130  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 16269  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 16312         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 16313  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 16314  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 16593  psi-mi:"MI:0502"(enzyme target)  psi-mi:"MI:0502"(enzyme target)
# 23339  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 23340         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 34046  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 34047         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 34049  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 34050  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 34085  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 34206  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 34207  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 34208  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 34641  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 34662         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)

# %% [markdown]
# ## Filter by Organism (Mouse and Human only)

# %%
# Replace taxid IDs for human and mouse with respective scientific names
#taxid_human - 9606
#taxid_mouse - 10090
mint_filter = mint_filter.replace('taxid:9606(human)|taxid:9606(Homo sapiens)',
                    'Homo sapiens')
mint_filter = mint_filter.replace('taxid:10090(mouse)|taxid:10090(Mus musculus)',
                    'Mus musculus')

#Filter dataframe for data only pertaining to either human or mouse species 
#for protein A
indices = [index for index, rowData in mint_filter.iterrows() if 
           rowData['ncbi_taxid_A'] == 'Homo sapiens' 
           or rowData['ncbi_taxid_A'] == 'Mus musculus']

mint_filter2 = mint_filter.loc[indices]

#Filter dataframe for data only pertaining to either human or mouse species 
#for protein B
indices2 = [index for index, rowData in mint_filter.iterrows() if 
           rowData['ncbi_taxid_B'] == 'Homo sapiens' 
           or rowData['ncbi_taxid_B'] == 'Mus musculus']

mint_filter3 = mint_filter2.loc[indices2]

indices3 = [index for index, rowData in mint_filter.iterrows() if 
           rowData['ncbi_taxid_B'] == rowData['ncbi_taxid_A']]

df = mint_filter3.loc[indices3]

#Drop any NaNs in the dataset (resulting from rows in which only one of the
#species was either human or mouse)
df.dropna(inplace = True)

# %%
#View dataframe
df.head(50)
# Out:
#              identifier_A        identifier_B  ncbi_taxid_A  ncbi_taxid_B  \
# 2831     uniprotkb:Q16539    uniprotkb:O43257  Homo sapiens  Homo sapiens
# 2832   uniprotkb:P15336-1    uniprotkb:Q16539  Homo sapiens  Homo sapiens
# 2833     uniprotkb:O43257    uniprotkb:Q15759  Homo sapiens  Homo sapiens
# 2834   uniprotkb:P15336-1    uniprotkb:Q15759  Homo sapiens  Homo sapiens
# 2971     uniprotkb:O00141  uniprotkb:P10636-7  Homo sapiens  Homo sapiens
# 2972     uniprotkb:P51812  uniprotkb:P10636-7  Homo sapiens  Homo sapiens
# 2973   uniprotkb:P10636-7    uniprotkb:P31749  Homo sapiens  Homo sapiens
# 35111  psi-mi:"MI:0217"(phosphorylation reaction)
# 35112  psi-mi:"MI:0217"(phosphorylation reaction)
# 35113  psi-mi:"MI:0217"(phosphorylation reaction)
# 35116  psi-mi:"MI:0217"(phosphorylation reaction)
# 35128  psi-mi:"MI:0217"(phosphorylation reaction)
# 35129  psi-mi:"MI:0217"(phosphorylation reaction)
# 35261  psi-mi:"MI:0217"(phosphorylation reaction)
# 35262  psi-mi:"MI:0217"(phosphorylation reaction)
# 35263  psi-mi:"MI:0217"(phosphorylation reaction)
#
#                              biorole_A                        biorole_B
# 2831          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 2832   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 2833   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 2834   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 2971          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 2972          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 2973   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 2975   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 2976          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 2977   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 2978          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 2993   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 3002   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 3003          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 3004          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 3110   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 3153          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 3154   psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 3276          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 3301          psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 12508         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 12509         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 14850         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 14862  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 15926  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 16269  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 16312         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 16313  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 16314  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 23339  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 23340         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 34046  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 34206  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 34207  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 34641  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 34662         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 34732  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 34863  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 34967         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 35066         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 35067         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 35111         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 35112         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 35113         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 35116  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 35128         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 35129  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 35261         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 35262         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 35263         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)

# %% [markdown]
# ## Convert UniProt IDs into Gene Symbols

# %%
#separate accession number from 'uniprotkb:' string for protein A
for index, string in df.identifier_A.iteritems():
    df.identifier_A[index] = string.split(":", 2)[1]

#Use uniprot_to_symbol function from Scripts.py to convert
df['gene_symbol_A'] = Scripts.uniprot_to_symbol(df['identifier_A'].tolist())

# %%
#separate accession number from 'uniprotkb:' string for protein B
for index, string in df.identifier_B.iteritems():
    df.identifier_B[index] = string.split(":", 2)[1]

#Use uniprot_to_symbol function from Scripts.py to convert
df['gene_symbol_B'] = Scripts.uniprot_to_symbol(df['identifier_B'].tolist())

# %%
#View Dataframe
df.head()
# Out:
#      identifier_A identifier_B  ncbi_taxid_A  ncbi_taxid_B  \
# 2831       Q16539       O43257  Homo sapiens  Homo sapiens
# 2832     P15336-1       Q16539  Homo sapiens  Homo sapiens
# 2833       O43257       Q15759  Homo sapiens  Homo sapiens
# 2834     P15336-1       Q15759  Homo sapiens  Homo sapiens
# 2971       O00141     P10636-7  Homo sapiens  Homo sapiens
#
#                                 interaction_type  \
# 2831  psi-mi:"MI:0217"(phosphorylation reaction)
# 2832  psi-mi:"MI:0217"(phosphorylation reaction)
# 2833  psi-mi:"MI:0217"(phosphorylation reaction)
# 2834  psi-mi:"MI:0217"(phosphorylation reaction)
# 2971  psi-mi:"MI:0217"(phosphorylation reaction)
#
#                             biorole_A                        biorole_B  \
# 2831         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
# 2832  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 2833  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 2834  psi-mi:"MI:0502"(enzyme target)         psi-mi:"MI:0501"(enzyme)
# 2971         psi-mi:"MI:0501"(enzyme)  psi-mi:"MI:0502"(enzyme target)
#
#      gene_symbol_A gene_symbol_B
# 2831        MAPK14        ZNHIT1
# 2832          None        MAPK14
# 2833        ZNHIT1        MAPK11
# 2834          None        MAPK11
# 2971          SGK1          None

# %% [markdown]
# ## Reformat dataframe

# %%
#Replace all instances of 'None' with 'NaN' and drop all  'NaN'
df = df.replace('None', np.nan)
df.dropna(inplace = True)

# Switch from PSI-MI ID to 'kinase' and 'target' labels
df = df.replace('psi-mi:"MI:0501"(enzyme)', 'Kinase')
df = df.replace('psi-mi:"MI:0502"(enzyme target)', 'Target')

#drop columns no longer needed
df.drop('identifier_A', axis=1, inplace = True)
df.drop('identifier_B', axis=1, inplace = True)
df.drop('interaction_type', axis=1, inplace = True)

# %%
#View dataframe
df.head()
# Out:
#       ncbi_taxid_A  ncbi_taxid_B biorole_A biorole_B gene_symbol_A  \
# 2831  Homo sapiens  Homo sapiens    Kinase    Target        MAPK14
# 2833  Homo sapiens  Homo sapiens    Target    Kinase        ZNHIT1
# 2993  Homo sapiens  Homo sapiens    Target    Kinase          TP53
# 3002  Homo sapiens  Homo sapiens    Target    Kinase           RB1
# 3003  Homo sapiens  Homo sapiens    Kinase    Target         CHEK1
#
#      gene_symbol_B
# 2831        ZNHIT1
# 2833        MAPK11
# 2993         GSK3B
# 3002         CHEK2
# 3003           RB1

# %% [markdown]
# ## Sort Proteins by Kinase/Target Role and Specify Species of Kinase

# %%
#Add two columns 'Kinase_Organism' and 'Target'
df.insert(0, 'Kinase_organism', 'None')
df.insert(0, 'Target', 'None')

#Determine whether protein A or protein B is the kinase, and designate the two
#proteins into the 'Kinase_organism' or 'Target' columns accordingly
for index, rowData in df.biorole_A.iteritems():
    if rowData == 'Kinase':
        df.gene_symbol_A[index] = '_'.join([df.gene_symbol_A[index], df.ncbi_taxid_A[index]])
        df.Kinase_organism[index] = df.gene_symbol_A[index]
        df.Target[index] = df.gene_symbol_B[index]
    else:
        df.gene_symbol_B[index] =  '_'.join([df.gene_symbol_B[index], df.ncbi_taxid_B[index]])
        df.Kinase_organism[index] = df.gene_symbol_B[index]
        df.Target[index] = df.gene_symbol_A[index]

#Drop columns which are no longer needed in the dataframe
df.drop('gene_symbol_A', axis=1, inplace = True)
df.drop('gene_symbol_B', axis=1, inplace = True)
df.drop('ncbi_taxid_A', axis=1, inplace = True)
df.drop('ncbi_taxid_B', axis=1, inplace = True)
df.drop('biorole_A', axis=1, inplace = True)
df.drop('biorole_B', axis=1, inplace = True)

#View dataframe
df.head()
# Out:
#       Target      Kinase_organism
# 2831  ZNHIT1  MAPK14_Homo sapiens
# 2833  ZNHIT1  MAPK11_Homo sapiens
# 2993    TP53   GSK3B_Homo sapiens
# 3002     RB1   CHEK2_Homo sapiens
# 3003     RB1   CHEK1_Homo sapiens

# %% [markdown]
# ## Create File of 'df' for Later Data Aggregation

# %%
#Create dictionary with index numbers as keys
d = dict([(key, '') for key in df.index])

# loop through rows with iterrows()
for index, rowData in df.iterrows():
    line = ('\t'.join(rowData))
    d[index] = line
    
#Transfer tab-separated info into a new txt file
with open('Uncondensed_MINT.txt', 'w') as openfile:
    for index in d:
        openfile.write(str(d[index]) + '\n')

# %% [markdown]
# ## Set Index to 'Kinase_Organism' and Aggregate Kinase Targets

# %%
#Set index to 'Kinase_organism'
df.set_index('Kinase_organism')

#Group kinases in dataframe 'kin'
#Aggregate data in 'kin' according to kinase groups
kin = df.groupby('Kinase_organism').agg(lambda x: tuple(x))

#Create a new column 'MINT' as description of data
kin.insert(0, 'Description', 'MINT')

#Visualize Data
kin.head()
# Out:
#                    Description  \
# Kinase_organism
# ABL1_Homo sapiens         MINT
# AKT1_Homo sapiens         MINT
# ATM_Homo sapiens          MINT
# AURKA_Homo sapiens        MINT
# AURKB_Homo sapiens        MINT
#
#                                                                Target
# Kinase_organism
# ABL1_Homo sapiens                                 (CBL, MUC1, CTNNB1)
# AKT1_Homo sapiens   (SORBS2, SORBS2, TOPBP1, MDM2, MDM2, CDKN1B, F...
# ATM_Homo sapiens                                              (TP53,)
# AURKA_Homo sapiens                                       (NPM1, NPM1)
# AURKB_Homo sapiens                                    (RACGAP1, NPM1)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Calculate Number of Protein targets for each kinase
# Create a new column with the number of substrates related to each kinase, and sort the dataframe by this column

# %%
# Create column representing counts of protein targets per kinase
kin['kinase_substrate_num'] = [len(lst) for kinase, lst in kin['Target'].iteritems()]

# Sort kinases from max to min according to number of protein targets each has
kin.sort_values(by = ['kinase_substrate_num'], ascending= False, inplace=True)

# View dataframe
kin.head()
# Out:
#                      Description  \
# Kinase_organism
# PASK_Homo sapiens           MINT
# CHEK2_Homo sapiens          MINT
# CSNK2A1_Homo sapiens        MINT
# MAPK1_Homo sapiens          MINT
# AKT1_Homo sapiens           MINT
#
#                                                                  Target  \
# Kinase_organism
# PASK_Homo sapiens     (PDX1, GYS1, RAB11FIP1, FXN, PIAS1, CREB1, NFA...
# CHEK2_Homo sapiens    (RB1, MDM2, TP53, NBN, CDC25A, TP53, CHEK2, ST...
# CSNK2A1_Homo sapiens  (HIF1A, KANK2, XRCC1, XRCC4, CDC34, SUB1, RELA...
# MAPK1_Homo sapiens        (YBX1, YBX3, YBX1, YBX3, BCL2, IER3, PPP2R5C)
# AKT1_Homo sapiens     (SORBS2, SORBS2, TOPBP1, MDM2, MDM2, CDKN1B, F...
#
#                       kinase_substrate_num
# Kinase_organism
# PASK_Homo sapiens                       28
# CHEK2_Homo sapiens                      11
# CSNK2A1_Homo sapiens                     9
# MAPK1_Homo sapiens                       7
# AKT1_Homo sapiens                        7

# %% [markdown]
# ## Create Histogram to display distribution of number of targets per kinase

# %%
# Create histogram displaying the distribution of the number
#targets per kinase
kin.plot.hist(by = 'kinase_substrate_num', bins = 63)

#Show histogram
plt.show()

# %% [markdown]
# # Creation of Final .GMT File

# %% [markdown]
# ## Create dictionary of Tab-Separated Rows of the dataframe

# %%
#Reset index of the dataframe
kin.reset_index(inplace = True)

#create column 'acc_merged' in which all 'acc' elements are joined by a \t symbol
kin['target_merged'] = ['\t'.join(x) for x in kin['Target']]

#drop the now-unneccesary column 'Substrates'
kin.drop('Target', axis=1, inplace = True)

#also drop the data-exploratory column 'kinase_substrate_num'
kin.drop('kinase_substrate_num', axis=1, inplace = True)

#Create dictionary 'MINT' with index numbers as keys
MINT_num = dict([(key, '') for key in kin.index])

# loop through rows with iterrows()
for index, rowData in kin.iterrows():
    line = ('\t'.join(rowData))
    MINT_num[index] = line

# %% [markdown]
# ## Write info from Dictionary into a .GMT file

# %%
#Transfer tab-separated info into a new txt file
with open('MINT.gmt', 'w') as openfile:
    for index in MINT_num:
        openfile.write(str(MINT_num[index]) + '\n')
