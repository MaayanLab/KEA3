# %% [markdown]
# # Combined .GMT File
# This notebook contains code that will concatenate all of the .gmt files created for seven databases (RegPhos, NetworKIN, Swiss-Prot, PhosphoELM, PhosphoSite, HPRD, and MINT) into a single .gmt file. It will also show a distribution for the number of targets per kinase for this combined file. For the reference column of this file, citations to the paper corresponding to the database will be provided in cases during which the data does not have a pubmed id number. Otherwise, the PubMed id will be displayed.

# %% [markdown]
# ## Import and Run Necessary Files

# %%
# %run /home/maayanlab/Desktop/Projects/KEA3/Scripts/init.ipy

# %% [markdown]
# ## Retrieving and Downloading all .GMT files

# %%
HPRD = pd.read_table("~/Desktop/Projects/KEA3/HPRD/Uncondensed_HPRD.txt", header = None)

MINT = pd.read_table("~/Desktop/Projects/KEA3/MINT/Uncondensed_MINT.txt", header = None)

NetworKIN = pd.read_table("~/Desktop/Projects/KEA3/NetworKIN/Uncondensed_NetworKIN.txt", header = None)

PhosphoELM = pd.read_table("~/Desktop/Projects/KEA3/PhosphoELM/Uncondensed_PhosphoELM.txt", header = None)

PhosphoSite = pd.read_table("~/Desktop/Projects/KEA3/PhosphoSite/Uncondensed_PhosphoSite.txt", header = None)

RP_Hum = pd.read_table("~/Desktop/Projects/KEA3/RegPhos/Uncondensed_RegPhos_human.txt", header = None)

RP_Mouse = pd.read_table("~/Desktop/Projects/KEA3/RegPhos/Uncondensed_RegPhos_mouse.txt", header = None)

SP_E = pd.read_table("~/Desktop/Projects/KEA3/SwissProt/Uncondensed_SwissProtE.txt", header = None)

SP_P = pd.read_table("~/Desktop/Projects/KEA3/SwissProt/Uncondensed_SwissProt_Put.txt", header = None)

# %% [markdown]
# ## Concatenate all GMT Dataframes into a Single Dataframe
# Also removes any duplicates or NAs that may be present in the newly created dataframe.

# %%
#Create a list of all of the dataframe
c = [HPRD, MINT, NetworKIN, PhosphoELM, PhosphoELM, RP_Hum, RP_Mouse, SP_E, SP_P]

#Concatenate all of the rows in the dataframes
combined = pd.concat(c)

#Assign column names
combined.columns = ['kinase_organism', 'substrate', 'reference']

#Drop any duplicate rows in the dataframe
combined.drop_duplicates(['kinase_organism', 'substrate'], inplace = True)
combined.dropna(inplace = True)

# %%
#View dataframe of combined kinase-substrate interactions
combined
# Out:
#               kinase_organism substrate  \
# 0           PTK2_Homo sapiens     ACTN1
# 1            HCK_Homo sapiens     STAT3
# 2           JAK1_Homo sapiens     STAT3
# 3           JAK2_Homo sapiens     STAT3
# 4          MAPK1_Homo sapiens     STAT3
# 5          PRKCD_Homo sapiens     STAT3
# 6            SRC_Homo sapiens     STAT3
# 7          MAPK8_Homo sapiens     STAT3
# 8          MAPK3_Homo sapiens     STAT3
# 9        RPS6KA5_Homo sapiens     STAT3
# 10         PRKCD_Homo sapiens      ADD1
# 11        PRKACA_Homo sapiens      ADD1
# 12         ROCK1_Homo sapiens      ADD1
# 13         PRKCD_Homo sapiens      ADD2
# 14        PRKACA_Homo sapiens      ADD2
# 15        ADRBK1_Homo sapiens    ADRA2A
# 16         PRKCD_Homo sapiens    ADRA2A
# 17         PRKCA_Homo sapiens    ADRA1B
# 18          CDK5_Homo sapiens     PSEN1
# 19         PRKCZ_Homo sapiens     PSEN1
# 20        PRKACA_Homo sapiens     PSEN1
# 21         GSK3B_Homo sapiens     PSEN1
# 22          CDK5_Homo sapiens       APP
# 23         GSK3B_Homo sapiens       APP
# 24          CDK1_Homo sapiens     APLP2
# 25         PRKCA_Homo sapiens     APLP2
# 26         PRKCE_Homo sapiens    SLC4A3
# 27           LYN_Homo sapiens      CD19
# 28         MAPK1_Homo sapiens      CD19
# 29          ABL1_Homo sapiens      CD19
# ..                        ...       ...
# 468         MAPK_Homo sapiens      JIP3
# 469         MAPK_Homo sapiens      MACS
# 470         MAPK_Homo sapiens     MAPK2
# 471         MAPK_Homo sapiens      PPAT
# 472  Tyr-kinases_Homo sapiens      ACHB
# 473  Tyr-kinases_Homo sapiens      ACHD
# 474  Tyr-kinases_Homo sapiens     FABPA
# 475  Tyr-kinases_Homo sapiens     FABPH
# 476  Tyr-kinases_Homo sapiens      ITB7
# 477  Tyr-kinases_Homo sapiens       LAT
# 478  Tyr-kinases_Homo sapiens     SHPS1
# 479         MAPK_Mus musculus     ADA17
# 480         MAPK_Mus musculus       DCX
# 481         MAPK_Mus musculus      ESR2
# 482         MAPK_Mus musculus     GORS2
# 483         MAPK_Mus musculus     GTF2I
# 484         MAPK_Mus musculus     PA24A
# 485         MAPK_Mus musculus      PPAT
# 486          JAK_Mus musculus     STA5A
# 487          JAK_Mus musculus     STA5B
# 488          JAK_Mus musculus     STAT1
# 489          JAK_Mus musculus     STAT2
# 490          JAK_Mus musculus     STAT3
# 491          JAK_Mus musculus     STAT4
# 492          JAK_Mus musculus     STAT6
# 493          JAK_Homo sapiens     STA5B
# 494          JAK_Homo sapiens     STAT2
# 495          JAK_Homo sapiens     STAT3
# 496          JAK_Homo sapiens     STAT4
# 497          JAK_Homo sapiens     STAT6
#
#                                              reference
# 0                                    11369769,16291744
# 1    11940572,11294897,10918587,12244095,11350938,1...
# 2    11940572,11294897,10918587,12244095,11350938,1...
# 3    11940572,11294897,10918587,12244095,11350938,1...
# 4    11350938,10521505,9343414,10446219,12576423,14...
# 5    11350938,10521505,9343414,10446219,12576423,14...
# 6    11940572,11294897,10918587,12244095,11350938,1...
# 7    11350938,10521505,9343414,10446219,12576423,14...
# 8    11350938,10521505,9343414,10446219,12576423,14...
# 9    11350938,10521505,9343414,10446219,12576423,14...
# 10                                     8810272,9679146
# 11                                             8810272
# 12                                            10209029
# 13                   9679146,8810272,19664994,18452278
# 14                   9679146,8810272,19664994,18452278
# 15                                             7876239
# 16                                            11732925
# 17                                             9353340
# 18                                            12056836
# 19                                            14576165
# 20                                            14576165
# 21                                            11104755
# 22                           8764598,10936190,15178331
# 23                           8764598,10936190,15178331
# 24                                             9109675
# 25                                             9109675
# 26                                            11739292
# 27                                            10933394
# 28                                   10706702,16497976
# 29                                            11120811
# ..                                                 ...
# 468  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 469  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 470  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 471  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 472  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 473  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 474  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 475  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 476  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 477  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 478  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 479  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 480  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 481  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 482  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 483  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 484  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 485  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 486  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 487  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 488  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 489  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 490  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 491  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 492  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 493  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 494  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 495  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 496  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
# 497  Huang, H.-D., Lee, T.-Y., Tzeng, S.-W., & Horn...
#
# [32596 rows x 3 columns]

# %% [markdown]
# ## Set Index by 'kinase_organism' Column and Group Proteins by Kinase
# Also, creating a copy of 'combined' to be used later in also creating a combined .SIG file

# %%
#Create a dataframe copy of 'combined' known as 'df'
df = combined.copy()

combined.drop("reference", axis = 1, inplace = True)

#Set index of the dataframe as 'kinase_organism'
combined.set_index('kinase_organism', inplace = True)

#Combine rows according to same index 'kinase_organism'
kin = combined.groupby('kinase_organism').agg(lambda x: tuple(x))

# %%
#Confirm that 'df' is a copy of 'combined' and is unchanged by setting the index
df.head()
# Out:
#       kinase_organism substrate  \
# 0   PTK2_Homo sapiens     ACTN1
# 1    HCK_Homo sapiens     STAT3
# 2   JAK1_Homo sapiens     STAT3
# 3   JAK2_Homo sapiens     STAT3
# 4  MAPK1_Homo sapiens     STAT3
#
#                                            reference
# 0                                  11369769,16291744
# 1  11940572,11294897,10918587,12244095,11350938,1...
# 2  11940572,11294897,10918587,12244095,11350938,1...
# 3  11940572,11294897,10918587,12244095,11350938,1...
# 4  11350938,10521505,9343414,10446219,12576423,14...

# %%
#View new dataframe
kin
# Out:
#                                                                     substrate
# kinase_organism
# ABL1_Homo sapiens           (CD19, CDK5, JAK2, MAPT, CRK, MDM2, JUN, PTPN6...
# ABL1_Mus musculus           (Abl1, Pdgfrb, Myod1, App, Cbl, Cdk5, Cav1, Do...
# ACTR2B_Homo sapiens         (PPARA, RELA, AHSG, SNIP1, TJP1, NEDD4L, SOX9,...
# ACTR2_Homo sapiens          (LCK, FYN, PEX1, NEDD4L, AHSG, EP300, RND3, SL...
# ADRBK1_Homo sapiens         (ADRA2A, BDKRB2, FPR1, MC4R, SNCA, OPRD1, RPLP...
# AKT1_Homo sapiens           (BRCA1, CDKN1A, CREB1, ESR1, FOXO1, GATA2, NR4...
# AKT1_Mus musculus           (Chek1, Cdkn1b, Creb1, Gsk3a, Tbc1d1, Pde3b, T...
# AKT2_Homo sapiens                           (ESR1, FOXO4, XIAP, CHUK, AKT1S1)
# AKT2_Mus musculus                   (Clk2, Creb1, Pde3b, Acly, Foxo1, Stxbp4)
# AMPK_group_Homo sapiens     (IRS1, KPNA2, EP300, EEF2K, PFKFB2, HNF4A, PRK...
# AMPK_group_Mus musculus     (Ppargc1a, Ulk1, Tp53, Hist1h2bn, Hist1h2bm, I...
# AMPKa1_Homo sapiens         (PPARA, STRADA, FASN, MLXIPL, GRIK2, PROX1, TN...
# AMPKa2_Homo sapiens         (RIPK2, SIK2, APPL1, NOS1, TRIP6, NOS2, PARP1,...
# ARAF_Homo sapiens           (PIK3C2A, SRC, MPP1, LNPEP, FOS, MAPK1, PLA2G4...
# ATM_Homo sapiens            (BRCA1, CREB1, MDM2, E2F1, ABL1, TP53, FANCD2,...
# ATM_Mus musculus                            (Chek1, Tp53, H2afx, Ttc5, Stk11)
# ATR_Homo sapiens            (BRCA1, E2F1, TP53, XPA, CHEK1, CHEK2, RAD17, ...
# AURKB_Homo sapiens                (CENPA, DES, INCENP, RACGAP1, NSUN2, SEPT1)
# Abl_Homo sapiens            (PTCH1, FLT1, EFNB1, NUP160, CDK16, PPP1R1B, P...
# Abl_Mus musculus                  (Abl1, Cav1, Crk, Dok1, Apbb1, Myod1, Jak2)
# Aurora A_Homo sapiens       (TP53, HIST1H3J, CDC25B, BRCA1, AURKA, MBD3, C...
# Aurora B_Homo sapiens       (BIRC5, VIM, HIST1H3J, GFAP, DES, CENPA, INCEN...
# AuroraA_Homo sapiens        (CTNNB1, TRAF4, CTNND1, CLIP2, MLF1IP, DCP2, R...
# AuroraB_Homo sapiens        (MCM2, NEK2, ECT2, PPP2R5C, CDC45L, FEN1, MYBL...
# AuroraC_Homo sapiens        (TACC2, EPN1, ZCCHC7, STK11IP, CDCA8, AURKB, I...
# BCKDK_Homo sapiens          (PDHA2, TRAF4, ARAF, BCKDHB, CKB, PDHX, ARID4B...
# BTK_Homo sapiens            (CD19, BMX, BTK, WAS, PLCG2, STAT5A, GTF2I, DA...
# CAMK1_Homo sapiens                   (ATF1, NOS1, SYN1, CAMK1, EIF4G3, HDAC5)
# CAMK2A_Homo sapiens         (ATP2A2, EGFR, GFAP, GRIN2B, GRIN2A, HSF1, KRT...
# CAMK2B_Homo sapiens             (COL4A3, GRIN2B, GRIN2A, ETS1, PLCB3, CAMK2B)
# ...                                                                       ...
# SGK3_Homo sapiens           (KCNQ1, GRIK2, CTNNB1, PLEK, FOXO3, TRPV5, CAC...
# SGK_group_Homo sapiens      (FOXO3, CREB1, HTT, GSK3B, MAP3K3, FOXO1, NDRG...
# SLK_Homo sapiens            (PRKCD, STK25, ASAP1, PPP1R12A, CSF1R, KHDRBS1...
# SRC_Homo sapiens            (STAT3, LRP1, GRB2, ATP2B4, CEACAM1, CTNNB1, G...
# SRC_Mus musculus            (Cav1, Dab1, Shc1, Adam12, Cav2, Cttn, Efs, Bc...
# STK11_Homo sapiens                         (PTEN, STK11, MARK1, STRADA, SNRK)
# SYK_Homo sapiens            (SLC4A1, FCGR2A, LCK, SNCA, PLCG1, PRKCA, TUBA...
# SYK_Mus musculus              (Prkca, Btk, Syk, Tuba1a, Prkcb, Sh3bp2, Plcg1)
# Src_Homo sapiens            (FLI1, STK35, PPP1CB, DOK3, CNGA2, ST5, EPB41L...
# TBK1_Homo sapiens            (IKBKB, NFKBIA, IRF5, IRF3, TMEM173, IRF7, OPTN)
# TEC_Homo sapiens                         (FGF2, TEC, BMX, BTK, GRB10, PTPN18)
# TGFbR2_Homo sapiens         (MAP3K5, DRD3, ITGB2, HRAS, FOXO1, SH3KBP1, IN...
# TLK1_Homo sapiens           (CLSPN, HIRA, HIST1H1A, PTGES3, CHEK1, INCENP,...
# TLK2_Homo sapiens           (HIRA, IFNAR1, TLK1, FEZ1, TMC8, BIN1, PVRL2, ...
# TNIK_Homo sapiens           (HRAS, DNM2, RAPGEF4, APC, TANK, ARHGEF7, FLT1...
# TRKA_Homo sapiens           (PDGFRB, KIT, EGF, AATF, NTRK3, CDC42, FZD1, S...
# TRKB_Homo sapiens           (NTRK3, CALB2, PDGFRB, KDR, KIT, THRB, CBL, EG...
# TRKC_Homo sapiens           (NTRK1, CALB2, SH2B3, PTPN1, SH2B2, HPSE, CSK,...
# TTK_Homo sapiens            (KRT5, RPAP1, CHMP2A, CCAR1, FBXW7, ACOT1, POL...
# Tyk2_Homo sapiens           (IKZF1, TBX21, MPO, SIVA1, CCR5, IL7R, IL9, IL...
# Tyr-kinases_Homo sapiens         (ACHB, ACHD, FABPA, FABPH, ITB7, LAT, SHPS1)
# Tyr-kinases_Mus musculus    (ACHB, ACHD, ESR1, FABPA, FABPH, LAT, MYCS, SH...
# VRK1_Homo sapiens                    (BANF1, TP53, JUN, ATF2, COIL, HIST1H3J)
# YSK1_Homo sapiens           (STK11, MBP, MAP2K3, STK4, MOBKL1A, PRPF31, SL...
# ZAP70_Homo sapiens          (MUC1, ZAP70, DUSP3, SHC1, LCP2, LAT, SH2B3, G...
# autocatalysis_Homo sapiens  (PIK3CD, STK25, CASK, PDPK1, DAPK3, MAP3K7, RI...
# autocatalysis_Mus musculus  (Epha8, Map3k5, Clk2, Nlk, Abl1, Prkaca, Lck, ...
# p38a_Mus musculus              (Atf2, Stat4, Mapkapk2, Dlx5, Siah2, Mapkapk3)
# p70S6K_Homo sapiens         (PPP2R5C, BAD, PRKAA2, CSNK2A1, LYN, CCND1, AK...
# p70S6Kb_Homo sapiens        (RPTOR, LYN, TSC2, BRCA1, AKT2, SYK, PDK1, BTK...
#
# [370 rows x 1 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Calculate Number of Protein Targets for each Kinase and Sort in Descending Order

# %%
# Create column representing counts of protein targets per kinase
kin['kinase_substrate_num'] = [len(lst) for kinase, lst in kin['substrate'].iteritems()]

# Sort kinases from max to min according to number of protein targets each has
kin.sort_values(by = ['kinase_substrate_num'], ascending= False, inplace=True)

# View dataframe
kin.head()
# Out:
#                                                                substrate  \
# kinase_organism
# FRK_Homo sapiens       (DNAJC1, PTPRN, DLX2, B3GALT4, OXR1, SYNGR2, M...
# PKCzeta_Homo sapiens   (F2R, CRKL, SORBS1, TSC1, DNM1, RPTN, PGM2L1, ...
# MAPK1_Homo sapiens     (STAT3, CD19, SLC9A1, ARRB1, GJA1, ESR1, NR3C1...
# PKAalpha_Homo sapiens  (SFN, DCP1A, RBM10, MAP3K8, ELF3, POLR2A, BCL2...
# CDK1_Homo sapiens      (APLP2, CALD1, CSNK2A1, CSNK2B, CUX1, CDK1, CD...
#
#                        kinase_substrate_num
# kinase_organism
# FRK_Homo sapiens                       1739
# PKCzeta_Homo sapiens                   1721
# MAPK1_Homo sapiens                     1585
# PKAalpha_Homo sapiens                  1228
# CDK1_Homo sapiens                      1131

# %% [markdown]
# ## Display a Histogram Showing the Distribution of the Number of Kinase Targets

# %%
# Create histogram displaying the distribution of the number
#targets per kinase
kin.plot.hist(by = 'kinase_substrate_num', bins = 100)

#Show histogram
plt.show()

# %% [markdown]
# ## Filter Kinases by the Number of Kinase Targets They Have
# If they have fewer than five or more than 2000, they will be filtered out of the dataframe.

# %%
#Create list of indexes(kinase names) for kinases with fewer than five substrates
sig_key = [index for index, rowData in kin.kinase_substrate_num.iteritems() if rowData < 5 or rowData > 2000]

#Set indices for dataframe 'kin' of kinases with five or more substrates
#indices will also filter out kinases with more than 2000 substrates
indices = [index for index in kin.index if index not in sig_key]

#Create dataframe of only kinases with five or more substrates
#or 2000 or fewer substrates
sig = df.set_index('kinase_organism').loc[indices]

#Reset index of new dataframe
sig.reset_index(inplace = True)

#Rename columns of this dataframe to match .sig format
colnames = ['Source', 'Substrate', 'Reference']
sig.columns = colnames

# %%
#Remove kinases with fewer than five substrates or 
#more than 2000 substrates in 'kin'
kin = kin.loc[indices]

# %%
indices
# Out:
# ['FRK_Homo sapiens',
#  'PKCzeta_Homo sapiens',
#  'MAPK1_Homo sapiens',
#  'PKAalpha_Homo sapiens',
#  'CDK1_Homo sapiens',
#  'CDK2_Homo sapiens',
#  'TTK_Homo sapiens',
#  'CK2alpha_Homo sapiens',
#  'PKBalpha_Homo sapiens',
#  'PKCdelta_Homo sapiens',
#  'HIPK2_Homo sapiens',
#  'GSK3beta_Homo sapiens',
#  'ATM_Homo sapiens',
#  'PKCepsilon_Homo sapiens',
#  'PKCgamma_Homo sapiens',
#  'Src_Homo sapiens',
#  'PKCiota_Homo sapiens',
#  'GRK2_Homo sapiens',
#  'RAF1_Homo sapiens',
#  'CDK5_Homo sapiens',
#  'CK1delta_Homo sapiens',
#  'MAPK8_Homo sapiens',
#  'PKCtheta_Homo sapiens',
#  'ROCK1_Homo sapiens',
#  'TGFbR2_Homo sapiens',
#  'PKG1cGKI_Homo sapiens',
#  'PDHK1_Homo sapiens',
#  'CaMKIV_Homo sapiens',
#  'LKB1_Homo sapiens',
#  'CK2a2_Homo sapiens',
#  'PKBbeta_Homo sapiens',
#  'EGFR_Homo sapiens',
#  'PKCeta_Homo sapiens',
#  'PLK1_Homo sapiens',
#  'ATR_Homo sapiens',
#  'PKAgamma_Homo sapiens',
#  'autocatalysis_Homo sapiens',
#  'CDK4_Homo sapiens',
#  'Abl_Homo sapiens',
#  'DNAPK_Homo sapiens',
#  'MAPK11_Homo sapiens',
#  'PAK2_Homo sapiens',
#  'MAP2K1_Homo sapiens',
#  'PKA_group_Homo sapiens',
#  'PKAbeta_Homo sapiens',
#  'CaMKIIbeta_Homo sapiens',
#  'autocatalysis_Mus musculus',
#  'GSK3alpha_Homo sapiens',
#  'AuroraA_Homo sapiens',
#  'PKBgamma_Homo sapiens',
#  'NLK_Homo sapiens',
#  'AuroraB_Homo sapiens',
#  'NEK2_Homo sapiens',
#  'MAP2K4_Homo sapiens',
#  'MAPK9_Homo sapiens',
#  'PKG2cGKII_Homo sapiens',
#  'CDK7_Homo sapiens',
#  'PRKACA_Homo sapiens',
#  'ErbB2_Homo sapiens',
#  'MAPK14_Homo sapiens',
#  'ARAF_Homo sapiens',
#  'IKKbeta_Homo sapiens',
#  'CSNK2A1_Homo sapiens',
#  'SRC_Homo sapiens',
#  'PRKCA_Homo sapiens',
#  'CLK1_Homo sapiens',
#  'CDK3_Homo sapiens',
#  'Pim1_Homo sapiens',
#  'Kit_Homo sapiens',
#  'MAPK12_Homo sapiens',
#  'PKC_group_Homo sapiens',
#  'PLK4_Homo sapiens',
#  'IKKalpha_Homo sapiens',
#  'CaMKIIdelta_Homo sapiens',
#  'EphB2_Homo sapiens',
#  'PKD1_Homo sapiens',
#  'PAK3_Homo sapiens',
#  'Met_Homo sapiens',
#  'AMPKa2_Homo sapiens',
#  'MAP2K3_Homo sapiens',
#  'Tyk2_Homo sapiens',
#  'EphA2_Homo sapiens',
#  'CaMKIIgamma_Homo sapiens',
#  'CK1epsilon_Homo sapiens',
#  'MAP2K6_Homo sapiens',
#  'MAPK13_Homo sapiens',
#  'CK2_group_Homo sapiens',
#  'InsR_Homo sapiens',
#  'ROCK2_Homo sapiens',
#  'MAPK10_Homo sapiens',
#  'PAK4_Homo sapiens',
#  'ACTR2_Homo sapiens',
#  'PKA_Homo sapiens',
#  'TRKA_Homo sapiens',
#  'ACTR2B_Homo sapiens',
#  'MAPK7_Homo sapiens',
#  'KDR_Homo sapiens',
#  'MAPK3_Homo sapiens',
#  'EIF2AK2_Homo sapiens',
#  'IGF1R_Homo sapiens',
#  'PKC_alpha_Homo sapiens',
#  'EphB1_Homo sapiens',
#  'PDGFRalpha_Homo sapiens',
#  'RSK2_Homo sapiens',
#  'FLT1_Homo sapiens',
#  'PDGFRbeta_Homo sapiens',
#  'SGK1_Homo sapiens',
#  'ErbB4_Homo sapiens',
#  'RSK3_Homo sapiens',
#  'MAP2K7_Homo sapiens',
#  'CDK6_Homo sapiens',
#  'MAP2K2_Homo sapiens',
#  'EphA3_Homo sapiens',
#  'AKT1_Homo sapiens',
#  'p70S6K_Homo sapiens',
#  'PKA_Mus musculus',
#  'EphA4_Homo sapiens',
#  'MAP2K5_Homo sapiens',
#  'CK2_alpha_Homo sapiens',
#  'TRKB_Homo sapiens',
#  'CSF1R_Homo sapiens',
#  'DMPK1_Homo sapiens',
#  'EphA1_Homo sapiens',
#  'MRCKa_Homo sapiens',
#  'PKB_group_Homo sapiens',
#  'ErbB3_Homo sapiens',
#  'CSNK2A2_Homo sapiens',
#  'MOK_Homo sapiens',
#  'MAP4K4_Homo sapiens',
#  'EphB3_Homo sapiens',
#  'DAPK1_Homo sapiens',
#  'PKC_Homo sapiens',
#  'EphA5_Homo sapiens',
#  'PRKCD_Homo sapiens',
#  'FLT3_Homo sapiens',
#  'CDC2_Homo sapiens',
#  'EphB4_Homo sapiens',
#  'CLK2_Homo sapiens',
#  'GSK3B_Homo sapiens',
#  'FYN_Homo sapiens',
#  'EphA7_Homo sapiens',
#  'EphA6_Homo sapiens',
#  'AMPKa1_Homo sapiens',
#  'GRK3_Homo sapiens',
#  'MAPK_group_Homo sapiens',
#  'MST4_Homo sapiens',
#  'EphA8_Homo sapiens',
#  'TNIK_Homo sapiens',
#  'PKC_Mus musculus',
#  'GRK5_Homo sapiens',
#  'MST3_Homo sapiens',
#  'PDHK4_Homo sapiens',
#  'PRKCB_Homo sapiens',
#  'PKA_group_Mus musculus',
#  'CK1gamma1_Homo sapiens',
#  'LCK_Homo sapiens',
#  'CDK_group_Homo sapiens',
#  'GRK1_Homo sapiens',
#  'TRKC_Homo sapiens',
#  'Ron_Homo sapiens',
#  'PLK2_Homo sapiens',
#  'PKCa_Homo sapiens',
#  'Pim2_Homo sapiens',
#  'EphB6_Homo sapiens',
#  'LYN_Homo sapiens',
#  'CDC2_Mus musculus',
#  'PAK1_Homo sapiens',
#  'PAK6_Homo sapiens',
#  'AMPK_group_Mus musculus',
#  'ERK2_Mus musculus',
#  'PASK_Homo sapiens',
#  'GRK6_Homo sapiens',
#  'CK1gamma2_Homo sapiens',
#  'CK2_Homo sapiens',
#  'CK1_group_Homo sapiens',
#  'CLK4_Homo sapiens',
#  'MARK4_Homo sapiens',
#  'MARK3_Homo sapiens',
#  'GRK4_Homo sapiens',
#  'ICK_Homo sapiens',
#  'YSK1_Homo sapiens',
#  'Lck_Homo sapiens',
#  'ABL1_Homo sapiens',
#  'MAPKAPK2_Homo sapiens',
#  'SYK_Homo sapiens',
#  'Chak2_Homo sapiens',
#  'NEK1_Homo sapiens',
#  'CK2_Mus musculus',
#  'GSK-3_beta_Homo sapiens',
#  'PKC_group_Mus musculus',
#  'NRK_Homo sapiens',
#  'PRKCG_Homo sapiens',
#  'p70S6Kb_Homo sapiens',
#  'AMPK_group_Homo sapiens',
#  'MAPKAPK5_Homo sapiens',
#  'PKA_alpha_Mus musculus',
#  'Lyn_Homo sapiens',
#  'TLK2_Homo sapiens',
#  'PDHK2_Homo sapiens',
#  'CAMK2A_Homo sapiens',
#  'PAK5_Homo sapiens',
#  'SRC_Mus musculus',
#  'PDK-1_Homo sapiens',
#  'PKACa_Mus musculus',
#  'RPS6KA1_Homo sapiens',
#  'MST2_Homo sapiens',
#  'Fyn_Homo sapiens',
#  'PKACa_Homo sapiens',
#  'INSR_Homo sapiens',
#  'RSK_group_Homo sapiens',
#  'PRKG1_Homo sapiens',
#  'MAP4K6_Homo sapiens',
#  'MAPK1_Mus musculus',
#  'CaM-KII_group_Homo sapiens',
#  'CAMK2G_Homo sapiens',
#  'MST1_Homo sapiens',
#  'PDPK1_Homo sapiens',
#  'PRKCZ_Homo sapiens',
#  'CaM-KII_alpha_Homo sapiens',
#  'CSK_Homo sapiens',
#  'PKCa_Mus musculus',
#  'GSK3B_Mus musculus',
#  'PKC_delta_Homo sapiens',
#  'PKC_alpha_Mus musculus',
#  'CSNK2B_Homo sapiens',
#  'CK2a1_Homo sapiens',
#  'IRR_Homo sapiens',
#  'CDK5_Mus musculus',
#  'GRK7_Homo sapiens',
#  'MARK1_Homo sapiens',
#  'CaMKIalpha_Homo sapiens',
#  'Probable_Homo sapiens',
#  'HCK_Homo sapiens',
#  'JAK2_Homo sapiens',
#  'RPS6KA5_Homo sapiens',
#  'SGK3_Homo sapiens',
#  'ABL1_Mus musculus',
#  'CSNK1A1_Homo sapiens',
#  'PKD3_Homo sapiens',
#  'CHEK2_Homo sapiens',
#  'SLK_Homo sapiens',
#  'TLK1_Homo sapiens',
#  'Lyn_Mus musculus',
#  'Haspin_Homo sapiens',
#  'MST1_Mus musculus',
#  'MAPKAPK3_Homo sapiens',
#  'MAPK_Mus musculus',
#  'AKT1_Mus musculus',
#  'CLK3_Homo sapiens',
#  'Aurora B_Homo sapiens',
#  'CK2a1_Mus musculus',
#  'PDK1_Homo sapiens',
#  'PKD2_Homo sapiens',
#  'MAPK_group_Mus musculus',
#  'SGK_group_Homo sapiens',
#  'CK2_alpha_Mus musculus',
#  'CK1gamma3_Homo sapiens',
#  'CK1alpha2_Homo sapiens',
#  'GRK-2_Homo sapiens',
#  'GSK-3_group_Homo sapiens',
#  'LYN_Mus musculus',
#  'PKC_epsilon_Homo sapiens',
#  'PRKCQ_Homo sapiens',
#  'PRKCE_Homo sapiens',
#  'CK1_alpha_Homo sapiens',
#  'Pim3_Homo sapiens',
#  'RPS6KA3_Homo sapiens',
#  'SGK2_Homo sapiens',
#  'BTK_Homo sapiens',
#  'BCKDK_Homo sapiens',
#  'ZAP70_Homo sapiens',
#  'PKC_zeta_Homo sapiens',
#  'CHEK1_Homo sapiens',
#  'MAK_Homo sapiens',
#  'DAPK3_Homo sapiens',
#  'RET_Homo sapiens',
#  'PKG1/cGK-I_Homo sapiens',
#  'JNK1_Mus musculus',
#  'PLK3_Homo sapiens',
#  'JAK1_Homo sapiens',
#  'ROCK_group_Homo sapiens',
#  'CDK2_Mus musculus',
#  'CDK1_Mus musculus',
#  'RSK-2_Homo sapiens',
#  'ERK1_Mus musculus',
#  'PRKDC_Homo sapiens',
#  'DYRK1A_Homo sapiens',
#  'ADRBK1_Homo sapiens',
#  'HIPK1_Homo sapiens',
#  'DNA-PK_Homo sapiens',
#  'FYN_Mus musculus',
#  'DAPK2_Homo sapiens',
#  'Probable_Mus musculus',
#  'PKB_group_Mus musculus',
#  'MAPKAPK2_Mus musculus',
#  'GSK3_Homo sapiens',
#  'MAPK_Homo sapiens',
#  'CSNK1D_Homo sapiens',
#  'Tyr-kinases_Mus musculus',
#  'PDHK3_Homo sapiens',
#  'Aurora A_Homo sapiens',
#  'AuroraC_Homo sapiens',
#  'NEK4_Homo sapiens',
#  'GSK3A_Homo sapiens',
#  'CK2a_Homo sapiens',
#  'NEK3_Homo sapiens',
#  'SYK_Mus musculus',
#  'TBK1_Homo sapiens',
#  'JAK_Mus musculus',
#  'ROCK2_Mus musculus',
#  'LKB1_Mus musculus',
#  'Abl_Mus musculus',
#  'Tyr-kinases_Homo sapiens',
#  'RSK-1_Homo sapiens',
#  'PKC_beta_Homo sapiens',
#  'CHK2_Homo sapiens',
#  'ILK_Homo sapiens',
#  'PRKD1_Homo sapiens',
#  'ITK_Homo sapiens',
#  'CHK1_Homo sapiens',
#  'IKBKB_Homo sapiens',
#  'CaMKIgamma_Homo sapiens',
#  'CK2_group_Mus musculus',
#  'TEC_Homo sapiens',
#  'CaMKIdelta_Homo sapiens',
#  'PTK2_Homo sapiens',
#  'CaMK2a_Mus musculus',
#  'IKK_group_Homo sapiens',
#  'CaMK2_group_Mus musculus',
#  'CAMK1_Homo sapiens',
#  'FER_Homo sapiens',
#  'MAP2K_group_Homo sapiens',
#  'PKG1_Mus musculus',
#  'PKC_theta_Homo sapiens',
#  'VRK1_Homo sapiens',
#  'AKT2_Mus musculus',
#  'GSK-3_beta_Mus musculus',
#  'p38a_Mus musculus',
#  'AURKB_Homo sapiens',
#  'HIPK2_Mus musculus',
#  'MAPK3_Mus musculus',
#  'CAMK2B_Homo sapiens',
#  'CDK_group_Mus musculus',
#  'CHUK_Homo sapiens',
#  'PRKAA1_Homo sapiens',
#  'SGK1_Mus musculus',
#  'MAPK8_Mus musculus',
#  'CaM-KII_alpha_Mus musculus',
#  'FGFR1_Homo sapiens',
#  'AKT2_Homo sapiens',
#  'CK1_group_Mus musculus',
#  'PRKAA2_Homo sapiens',
#  'CaM-KIV_Homo sapiens',
#  'PKB/AKT1_Homo sapiens',
#  'ATM_Mus musculus',
#  'FAK_Homo sapiens',
#  'PKCd_Homo sapiens',
#  'PAK1_Mus musculus',
#  'RPS6KB1_Homo sapiens',
#  'IKK_alpha_Homo sapiens',
#  'LCK_Mus musculus',
#  'CSNK1E_Homo sapiens',
#  'Csk_Homo sapiens',
#  'JAK2_Mus musculus',
#  'PDK1_Mus musculus',
#  'JAK_Homo sapiens',
#  'RSK_group_Mus musculus',
#  'STK11_Homo sapiens',
#  'JNK_group_Homo sapiens',
#  'EGFR_Mus musculus']

# %% [markdown]
# ## Create .SIG File by Formatting 'df' to sig file format

# %%
#Insert first four columns for .sig file format (NaNs)
sig.insert(1, 'NA-1', str(np.nan))
sig.insert(2, 'NA-2', str(np.nan))
sig.insert(3, 'NA-3', str(np.nan))
sig.insert(4, 'NA-4', str(np.nan))

#Insert column corresponding to sign (with '?' because it is unknown)
sig.insert(6, 'Sign', '?')

#Insert column specifying interaction type as phosphorylation
sig.insert(7, 'Interaction', 'Phosphorylation')

#View dataframe
sig.head()
# Out:
#              Source NA-1 NA-2 NA-3 NA-4 Substrate Sign      Interaction  \
# 0  FRK_Homo sapiens  nan  nan  nan  nan    DNAJC1    ?  Phosphorylation
# 1  FRK_Homo sapiens  nan  nan  nan  nan     PTPRN    ?  Phosphorylation
# 2  FRK_Homo sapiens  nan  nan  nan  nan      DLX2    ?  Phosphorylation
# 3  FRK_Homo sapiens  nan  nan  nan  nan   B3GALT4    ?  Phosphorylation
# 4  FRK_Homo sapiens  nan  nan  nan  nan      OXR1    ?  Phosphorylation
#
#                                            Reference
# 0  Linding et al., Systematic discovery of in viv...
# 1  Linding et al., Systematic discovery of in viv...
# 2  Linding et al., Systematic discovery of in viv...
# 3  Linding et al., Systematic discovery of in viv...
# 4  Linding et al., Systematic discovery of in viv...

# %%
#Create dictionary 'sigd' with index numbers as keys
sigd = dict([(key, '') for key in sig.index])

# loop through rows with iterrows()
for index, rowData in sig.iterrows():
    if type(rowData) != type('Hello'):
        rowData = str(rowData)
    line = ('\t'.join(rowData))
    sigd[index] = line
    
#Transfer tab-separated info into a new txt file
#Make sure to include in ReadMe corresponding column names
with open('Combinedsig.txt', 'w') as openfile:
    for index in sigd:
        openfile.write(sigd[index] + '\n')

# %% [markdown]
# # Create Combined .GMT File

# %% [markdown]
# ## Create Dictionary of Row Data to be Included in the Final .GMT

# %%
#Reset index of the dataframe
kin.reset_index(inplace = True)

#create column 'acc_merged' in which all 'acc' elements are joined by a \t symbol
kin['substrates_merged'] = ['\t'.join(x) for x in kin['substrate']]

#drop the now-unneccesary column 'Substrates'
kin.drop('substrate', axis=1, inplace = True)

#also drop the data-exploratory column 'kinase_substrate_num'
kin.drop('kinase_substrate_num', axis=1, inplace = True)

#Create dictionary 'PhosphoSite' with index numbers as keys
Combined_num = dict([(key, '') for key in kin.index])

# loop through rows with iterrows()
for index, rowData in kin.iterrows():
    line = ('\t'.join(rowData))
    Combined_num[index] = line
# Out:
# kinase_organism                                       FRK_Homo sapiens
# substrates_merged    DNAJC1\tPTPRN\tDLX2\tB3GALT4\tOXR1\tSYNGR2\tMY...
# Name: 0, dtype: object
# kinase_organism                                   PKCzeta_Homo sapiens
# substrates_merged    F2R\tCRKL\tSORBS1\tTSC1\tDNM1\tRPTN\tPGM2L1\tS...
# Name: 1, dtype: object
# kinase_organism                                     MAPK1_Homo sapiens
# substrates_merged    STAT3\tCD19\tSLC9A1\tARRB1\tGJA1\tESR1\tNR3C1\...
# Name: 2, dtype: object
# kinase_organism                                  PKAalpha_Homo sapiens
# substrates_merged    SFN\tDCP1A\tRBM10\tMAP3K8\tELF3\tPOLR2A\tBCL2\...
# Name: 3, dtype: object
# kinase_organism                                      CDK1_Homo sapiens
# substrates_merged    APLP2\tCALD1\tCSNK2A1\tCSNK2B\tCUX1\tCDK1\tCDC...
# Name: 4, dtype: object
# kinase_organism                                      CDK2_Homo sapiens
# substrates_merged    BRCA1\tCDK2\tCCNE1\tMYOD1\tNPM1\tPTHLH\tRB1\tP...
# Name: 5, dtype: object
# kinase_organism                                       TTK_Homo sapiens
# substrates_merged    KRT5\tRPAP1\tCHMP2A\tCCAR1\tFBXW7\tACOT1\tPOLD...
# Name: 6, dtype: object
# kinase_organism                                  CK2alpha_Homo sapiens
# substrates_merged    SMC1A\tSNAPC5\tLMNA\tERF\tHSPA8\tEXO1\tAHCYL1\...
# Name: 7, dtype: object
# kinase_organism                                  PKBalpha_Homo sapiens
# substrates_merged    GMIP\tAPBB1IP\tSFRS9\tMYLK\tADRA2A\tTGFBR1\tRE...
# Name: 8, dtype: object
# kinase_organism                                  PKCdelta_Homo sapiens
# substrates_merged    NKX3-1\tMAP2K5\tGRB10\tGNG12\tSTK11\tCDC37\tRP...
# Name: 9, dtype: object
# kinase_organism                                     HIPK2_Homo sapiens
# substrates_merged    USP20\tCASP2\tNRIP1\tLATS2\tARNT\tBCL6\tHDAC2\...
# Name: 10, dtype: object
# kinase_organism                                  GSK3beta_Homo sapiens
# substrates_merged    ETS2\tPPP1R9B\tIQGAP1\tRBM14\tKDR\tWWC1\tFUS\t...
# Name: 11, dtype: object
# kinase_organism                                       ATM_Homo sapiens
# substrates_merged    BRCA1\tCREB1\tMDM2\tE2F1\tABL1\tTP53\tFANCD2\t...
# Name: 12, dtype: object
# kinase_organism                                PKCepsilon_Homo sapiens
# substrates_merged    EDAR\tVCAN\tCD247\tBCL10\tSLC26A3\tUBTF\tARHGA...
# Name: 13, dtype: object
# kinase_organism                                  PKCgamma_Homo sapiens
# substrates_merged    SOX9\tTGFB1I1\tFYB\tCRTC2\tTSC1\tRB1CC1\tLMNA\...
# Name: 14, dtype: object
# kinase_organism                                       Src_Homo sapiens
# substrates_merged    FLI1\tSTK35\tPPP1CB\tDOK3\tCNGA2\tST5\tEPB41L5...
# Name: 15, dtype: object
# kinase_organism                                   PKCiota_Homo sapiens
# substrates_merged    ETHE1\tTICAM2\tNOS3\tHSPA8\tDNAJC5\tRAB3A\tTFA...
# Name: 16, dtype: object
# kinase_organism                                      GRK2_Homo sapiens
# substrates_merged    AP1S1\tADCY9\tPTPN1\tCCNB1\tRAB4A\tGNB3\tAPPL1...
# Name: 17, dtype: object
# kinase_organism                                      RAF1_Homo sapiens
# substrates_merged    CEP152\tAANAT\tFGFR1OP\tPSMC5\tALMS1\tEPN1\tPL...
# Name: 18, dtype: object
# kinase_organism                                      CDK5_Homo sapiens
# substrates_merged    PSEN1\tAPP\tEZR\tGRIN2A\tMAPT\tMAP2K1\tSRC\tER...
# Name: 19, dtype: object
# kinase_organism                                  CK1delta_Homo sapiens
# substrates_merged    STAT3\tNF1\tSTEAP3\tRASGRF2\tFGF2\tCCNE1\tTBL1...
# Name: 20, dtype: object
# kinase_organism                                     MAPK8_Homo sapiens
# substrates_merged    STAT3\tCDKN1A\tNR3C1\tHSF1\tIRS1\tKRT8\tBCL2\t...
# Name: 21, dtype: object
# kinase_organism                                  PKCtheta_Homo sapiens
# substrates_merged    TSC2\tDGKD\tADRB2\tAC012652.1\tTGFB1I1\tGJB1\t...
# Name: 22, dtype: object
# kinase_organism                                     ROCK1_Homo sapiens
# substrates_merged    ADD1\tEZR\tDES\tGFAP\tRDX\tVIM\tMSN\tLIMK1\tLI...
# Name: 23, dtype: object
# kinase_organism                                    TGFbR2_Homo sapiens
# substrates_merged    MAP3K5\tDRD3\tITGB2\tHRAS\tFOXO1\tSH3KBP1\tINC...
# Name: 24, dtype: object
# kinase_organism                                  PKG1cGKI_Homo sapiens
# substrates_merged    NR4A2\tCYP19A1\tGNAQ\tTFRC\tFOSL1\tPHKG1\tJUNB...
# Name: 25, dtype: object
# kinase_organism                                     PDHK1_Homo sapiens
# substrates_merged    RAPGEF4\tFRK\tAMPH\tF2R\tKPNA2\tTERT\tLNPEP\tR...
# Name: 26, dtype: object
# kinase_organism                                    CaMKIV_Homo sapiens
# substrates_merged    DUSP1\tELK1\tPLCB2\tPIK3R2\tGRIN2C\tLYN\tKIT\t...
# Name: 27, dtype: object
# kinase_organism                                      LKB1_Homo sapiens
# substrates_merged    CSNK2A1\tFOXO3\tGTF2F1\tE4F1\tIPO4\tADRM1\tINS...
# Name: 28, dtype: object
# kinase_organism                                     CK2a2_Homo sapiens
# substrates_merged    LRRFIP2\tASF1A\tCAMK2B\tSTXBP5\tCDC34\tVCL\tYW...
# Name: 29, dtype: object
# kinase_organism                                   PKBbeta_Homo sapiens
# substrates_merged    ERBB2\tPAK2\tCACNG2\tSETD2\tTBX3\tCEBPB\tNCOR2...
# Name: 30, dtype: object
# kinase_organism                                      EGFR_Homo sapiens
# substrates_merged    GRB2\tCALM1\tCALM2\tCALM3\tEZR\tEPB41\tEGFR\tR...
# Name: 31, dtype: object
# kinase_organism                                    PKCeta_Homo sapiens
# substrates_merged    CASP3\tKRT18\tTGFB1I1\tGJB1\tITGA4\tEPHA5\tPTE...
# Name: 32, dtype: object
# kinase_organism                                      PLK1_Homo sapiens
# substrates_merged    CCNB1\tCDC25C\tNPM1\tWEE1\tBRCA2\tMYT1\tPKMYT1...
# Name: 33, dtype: object
# kinase_organism                                       ATR_Homo sapiens
# substrates_merged    BRCA1\tE2F1\tTP53\tXPA\tCHEK1\tCHEK2\tRAD17\tT...
# Name: 34, dtype: object
# kinase_organism                                  PKAgamma_Homo sapiens
# substrates_merged    XIAP\tSLC9A3R1\tRALA\tEPB41L1\tGJB1\tRARA\tPCN...
# Name: 35, dtype: object
# kinase_organism                             autocatalysis_Homo sapiens
# substrates_merged    PIK3CD\tSTK25\tCASK\tPDPK1\tDAPK3\tMAP3K7\tRIP...
# Name: 36, dtype: object
# kinase_organism                                      CDK4_Homo sapiens
# substrates_merged    TRIM28\tXRCC1\tRBBP8\tATM\tCBX4\tTK1\tDYRK1A\t...
# Name: 37, dtype: object
# kinase_organism                                       Abl_Homo sapiens
# substrates_merged    PTCH1\tFLT1\tEFNB1\tNUP160\tCDK16\tPPP1R1B\tPL...
# Name: 38, dtype: object
# kinase_organism                                     DNAPK_Homo sapiens
# substrates_merged    PTS\tMEF2C\tSMAD1\tPPARA\tRECQL5\tTBL1XR1\tMCM...
# Name: 39, dtype: object
# kinase_organism                                    MAPK11_Homo sapiens
# substrates_merged    GTF2I\tRAF1\tYEATS2\tPPARG\tMTOR\tERBB2\tTSC1\...
# Name: 40, dtype: object
# kinase_organism                                      PAK2_Homo sapiens
# substrates_merged    RPS6\tVIM\tSYN1\tMYLK\tPAK2\tMKNK1\tKALRN\tNCO...
# Name: 41, dtype: object
# kinase_organism                                    MAP2K1_Homo sapiens
# substrates_merged    MAP2K1\tMAPK1\tCASP9\tRPS6KA4\tPARVA\tFGFR1\tP...
# Name: 42, dtype: object
# kinase_organism                                 PKA_group_Homo sapiens
# substrates_merged    HIST1H2BI\tFGA\tESR1\tRAF1\tANXA1\tTH\tADRB2\t...
# Name: 43, dtype: object
# kinase_organism                                   PKAbeta_Homo sapiens
# substrates_merged    SLC9A3R1\tRALA\tEPB41L1\tGJB1\tCDC25A\tRB1\tYW...
# Name: 44, dtype: object
# kinase_organism                                CaMKIIbeta_Homo sapiens
# substrates_merged    EGFR\tITPR3\tPDE8B\tIL6ST\tPDE8A\tPDE3B\tTJP1\...
# Name: 45, dtype: object
# kinase_organism                             autocatalysis_Mus musculus
# substrates_merged    Epha8\tMap3k5\tClk2\tNlk\tAbl1\tPrkaca\tLck\tH...
# Name: 46, dtype: object
# kinase_organism                                 GSK3alpha_Homo sapiens
# substrates_merged    PRKAR2A\tSMAD3\tVANGL1\tADD2\tBUB1\tPI4K2A\tSR...
# Name: 47, dtype: object
# kinase_organism                                   AuroraA_Homo sapiens
# substrates_merged    CTNNB1\tTRAF4\tCTNND1\tCLIP2\tMLF1IP\tDCP2\tRA...
# Name: 48, dtype: object
# kinase_organism                                  PKBgamma_Homo sapiens
# substrates_merged    MAST1\tJAK1\tNEFL\tRGS3\tPRKAG2\tPHKA1\tSRC\tS...
# Name: 49, dtype: object
# kinase_organism                                       NLK_Homo sapiens
# substrates_merged    FOS\tRELA\tRBL1\tTICAM1\tMSX2\tNUP214\tTGFBR1\...
# Name: 50, dtype: object
# kinase_organism                                   AuroraB_Homo sapiens
# substrates_merged    MCM2\tNEK2\tECT2\tPPP2R5C\tCDC45L\tFEN1\tMYBL2...
# Name: 51, dtype: object
# kinase_organism                                      NEK2_Homo sapiens
# substrates_merged    ERCC6L\tCENPT\tRAD21\tSGOL2\tFZR1\tDHX38\tMCM5...
# Name: 52, dtype: object
# kinase_organism                                    MAP2K4_Homo sapiens
# substrates_merged    MAPK8\tMAP2K4\tMAPK12\tMAPK9\tMAPK10\tPTK2B\tA...
# Name: 53, dtype: object
# kinase_organism                                     MAPK9_Homo sapiens
# substrates_merged    ATF2\tELK1\tELK3\tH3F3A\tNFATC3\tBCL2L11\tEEF2...
# Name: 54, dtype: object
# kinase_organism                                 PKG2cGKII_Homo sapiens
# substrates_merged    PRKACA\tPRKACG\tPRKX\tSLC26A6\tHRAS\tSLC1A3\tS...
# Name: 55, dtype: object
# kinase_organism                                      CDK7_Homo sapiens
# substrates_merged    CDK1\tCDK2\tESR1\tE2F1\tLASP1\tPCGF6\tBCR\tRPS...
# Name: 56, dtype: object
# kinase_organism                                    PRKACA_Homo sapiens
# substrates_merged    ADD1\tADD2\tPSEN1\tLRP1\tACLY\tATP2B1\tADRBK1\...
# Name: 57, dtype: object
# kinase_organism                                     ErbB2_Homo sapiens
# substrates_merged    PDGFRB\tPKP4\tUSP8\tBIRC6\tEPHB1\tPPP3R1\tNF1\...
# Name: 58, dtype: object
# kinase_organism                                    MAPK14_Homo sapiens
# substrates_merged    SLC9A1\tATF2\tDDIT3\tESR1\tKRT8\tMAX\tCDC25C\t...
# Name: 59, dtype: object
# kinase_organism                                      ARAF_Homo sapiens
# substrates_merged    PIK3C2A\tSRC\tMPP1\tLNPEP\tFOS\tMAPK1\tPLA2G4A...
# Name: 60, dtype: object
# kinase_organism                                   IKKbeta_Homo sapiens
# substrates_merged    ADAM9\tRNF31\tC11orf30\tTICAM2\tTNFRSF11A\tPAR...
# Name: 61, dtype: object
# kinase_organism                                   CSNK2A1_Homo sapiens
# substrates_merged    APEX1\tARRB2\tMS4A1\tBRCA1\tCASQ2\tCTNNB1\tCDK...
# Name: 62, dtype: object
# kinase_organism                                       SRC_Homo sapiens
# substrates_merged    STAT3\tLRP1\tGRB2\tATP2B4\tCEACAM1\tCTNNB1\tGJ...
# Name: 63, dtype: object
# kinase_organism                                     PRKCA_Homo sapiens
# substrates_merged    ADRA1B\tAPLP2\tATP2B1\tATP2B2\tADRBK1\tGJA1\tC...
# Name: 64, dtype: object
# kinase_organism                                      CLK1_Homo sapiens
# substrates_merged    PCBP1\tATM\tCHD1\tHNRNPM\tDHX38\tSFRS12\tHNRNP...
# Name: 65, dtype: object
# kinase_organism                                      CDK3_Homo sapiens
# substrates_merged    CREBBP\tPKMYT1\tEP300\tFEN1\tSTIP1\tMNAT1\tZBT...
# Name: 66, dtype: object
# kinase_organism                                      Pim1_Homo sapiens
# substrates_merged    PPP1R1B\tATL2\tPRKCD\tRYR2\tALOX5\tRHOB\tMYOD1...
# Name: 67, dtype: object
# kinase_organism                                       Kit_Homo sapiens
# substrates_merged    CD33\tBCL2\tSDC1\tRPS6KB1\tDNTT\tPIK3CD\tDND1\...
# Name: 68, dtype: object
# kinase_organism                                    MAPK12_Homo sapiens
# substrates_merged    MAPT\tSNTA1\tMAPK12\tEEF2K\tSH3BP5\tTNFRSF1A\t...
# Name: 69, dtype: object
# kinase_organism                                 PKC_group_Homo sapiens
# substrates_merged    EGFR\tIL2RA\tLMNA\tFGA\tTFRC\tRAF1\tANXA1\tEEF...
# Name: 70, dtype: object
# kinase_organism                                      PLK4_Homo sapiens
# substrates_merged    CEP350\tNUP133\tVTN\tMAP2\tSMC1A\tKIF14\tTP53\...
# Name: 71, dtype: object
# kinase_organism                                  IKKalpha_Homo sapiens
# substrates_merged    GLI2\tBCL3\tPDLIM7\tCYLD\tBIRC2\tSTAT1\tGRB10\...
# Name: 72, dtype: object
# kinase_organism                               CaMKIIdelta_Homo sapiens
# substrates_merged    TCAP\tSYNGAP1\tACACA\tAPBA1\tPRKAR1B\tNOS1\tEP...
# Name: 73, dtype: object
# kinase_organism                                     EphB2_Homo sapiens
# substrates_merged    MAP3K7IP3\tIQGAP1\tPLCG2\tFGFR4\tCLTA\tTNIK\tO...
# Name: 74, dtype: object
# kinase_organism                                      PKD1_Homo sapiens
# substrates_merged    SLC5A5\tTRPV1\tSLC2A1\tMEF2D\tCORO1B\tTBL1X\tI...
# Name: 75, dtype: object
# kinase_organism                                      PAK3_Homo sapiens
# substrates_merged    FGD1\tAKT1\tPEBP1\tSRGAP1\tYWHAZ\tYWHAB\tIGF1R...
# Name: 76, dtype: object
# kinase_organism                                       Met_Homo sapiens
# substrates_merged    ARHGEF12\tCLTC\tEEA1\tCD34\tCDH2\tPLXNB2\tSMC1...
# Name: 77, dtype: object
# kinase_organism                                    AMPKa2_Homo sapiens
# substrates_merged    RIPK2\tSIK2\tAPPL1\tNOS1\tTRIP6\tNOS2\tPARP1\t...
# Name: 78, dtype: object
# kinase_organism                                    MAP2K3_Homo sapiens
# substrates_merged    CALD1\tCENPI\tMAP2K1\tSLC8A1\tGRM3\tPTK2B\tZAK...
# Name: 79, dtype: object
# kinase_organism                                      Tyk2_Homo sapiens
# substrates_merged    IKZF1\tTBX21\tMPO\tSIVA1\tCCR5\tIL7R\tIL9\tIL5...
# Name: 80, dtype: object
# kinase_organism                                     EphA2_Homo sapiens
# substrates_merged    CBLB\tARHGAP5\tCTTN\tKHDRBS1\tBCAR3\tIQGAP1\tI...
# Name: 81, dtype: object
# kinase_organism                               CaMKIIgamma_Homo sapiens
# substrates_merged    RASGRF2\tPDE3A\tPPP3CA\tCHRNA7\tGRIK1\tAPBA1\t...
# Name: 82, dtype: object
# kinase_organism                                CK1epsilon_Homo sapiens
# substrates_merged    EIF6\tCLIP2\tCTNND1\tLRP6\tMYC\tCAMK2D\tCSNK1G...
# Name: 83, dtype: object
# kinase_organism                                    MAP2K6_Homo sapiens
# substrates_merged    CALD1\tSLC20A1\tSTK3\tSTK25\tSTK24\tXIAP\tMAPK...
# Name: 84, dtype: object
# kinase_organism                                    MAPK13_Homo sapiens
# substrates_merged    PLA2G4A\tMTOR\tPPARG\tAKT1\tTAOK1\tUTF1\tETV4\...
# Name: 85, dtype: object
# kinase_organism                                 CK2_group_Homo sapiens
# substrates_merged    C1R\tJUN\tSSB\tPGR\tCDK1\tHSP90AA1\tHNRNPC\tSP...
# Name: 86, dtype: object
# kinase_organism                                      InsR_Homo sapiens
# substrates_merged    PDGFRB\tKIT\tSTAT6\tPIK3CD\tIL4R\tDNM2\tSH2B3\...
# Name: 87, dtype: object
# kinase_organism                                     ROCK2_Homo sapiens
# substrates_merged    GNAQ\tNUDC\tAKAP4\tCALD1\tSSH1\tMPP1\tARHGEF12...
# Name: 88, dtype: object
# kinase_organism                                    MAPK10_Homo sapiens
# substrates_merged    CREB3L2\tFYN\tMAPK9\tPIN1\tAPP\tMAP3K5\tMAPK8\...
# Name: 89, dtype: object
# kinase_organism                                      PAK4_Homo sapiens
# substrates_merged    CDC42EP3\tCDC42EP4\tPXN\tPAK7\tMAP3K11\tARHGDI...
# Name: 90, dtype: object
# kinase_organism                                     ACTR2_Homo sapiens
# substrates_merged    LCK\tFYN\tPEX1\tNEDD4L\tAHSG\tEP300\tRND3\tSLC...
# Name: 91, dtype: object
# kinase_organism                                       PKA_Homo sapiens
# substrates_merged    ABCA1\tADDA\tADDB\tADRB2\tAP2A\tAQP2\tAT2B1\tC...
# Name: 92, dtype: object
# kinase_organism                                      TRKA_Homo sapiens
# substrates_merged    PDGFRB\tKIT\tEGF\tAATF\tNTRK3\tCDC42\tFZD1\tSP...
# Name: 93, dtype: object
# kinase_organism                                    ACTR2B_Homo sapiens
# substrates_merged    PPARA\tRELA\tAHSG\tSNIP1\tTJP1\tNEDD4L\tSOX9\t...
# Name: 94, dtype: object
# kinase_organism                                     MAPK7_Homo sapiens
# substrates_merged    GJA1\tETS1\tRXRA\tMEF2A\tMEF2C\tMEF2D\tSGK1\tM...
# Name: 95, dtype: object
# kinase_organism                                       KDR_Homo sapiens
# substrates_merged    HSP90AA1\tCSF2RB\tCRK\tSTAT3\tBMX\tSHC4\tMTOR\...
# Name: 96, dtype: object
# kinase_organism                                     MAPK3_Homo sapiens
# substrates_merged    STAT3\tARRB1\tADRBK1\tGJA1\tHSF1\tTCF3\tKRT8\t...
# Name: 97, dtype: object
# kinase_organism                                   EIF2AK2_Homo sapiens
# substrates_merged    NFKBIA\tEIF2AK2\tTP53\tPPP2R5A\tEIF2S1\tIRS1\t...
# Name: 98, dtype: object
# kinase_organism                                     IGF1R_Homo sapiens
# substrates_merged    FCGR2A\tKL\tSH3GL1\tSH3GL2\tBCL2\tSNAP29\tEPS1...
# Name: 99, dtype: object
# kinase_organism                                 PKC_alpha_Homo sapiens
# substrates_merged    EGFR\tTFRC\tANXA1\tINSR\tANXA2\tPLEK\tSRF\tCFT...
# Name: 100, dtype: object
# kinase_organism                                     EphB1_Homo sapiens
# substrates_merged    VAV1\tCD3E\tCBL\tCD247\tTNIK\tFRS2\tKIRREL\tDN...
# Name: 101, dtype: object
# kinase_organism                                PDGFRalpha_Homo sapiens
# substrates_merged    FOS\tPIK3CD\tCD34\tMDM4\tIDH1\tITGA3\tSTRN\tST...
# Name: 102, dtype: object
# kinase_organism                                      RSK2_Homo sapiens
# substrates_merged    SH3KBP1\tCASP8\tEGFR\tEPN1\tEPS15L1\tSURF4\tKR...
# Name: 103, dtype: object
# kinase_organism                                      FLT1_Homo sapiens
# substrates_merged    TLR3\tPDGFRB\tPDGFRA\tPLCG2\tFLG\tPCNA\tATR\tP...
# Name: 104, dtype: object
# kinase_organism                                 PDGFRbeta_Homo sapiens
# substrates_merged    MPL\tINPPL1\tGRB14\tMTOR\tPRDX2\tSOS2\tSHB\tFI...
# Name: 105, dtype: object
# kinase_organism                                      SGK1_Homo sapiens
# substrates_merged    CREB1\tBRAF\tSLC1A3\tFOXO3\tNEDD4L\tGSK3A\tKPN...
# Name: 106, dtype: object
# kinase_organism                                     ErbB4_Homo sapiens
# substrates_merged    PTPRD\tFLT1\tSTAT2\tPDGFRB\tINSR\tUSP8\tBIRC6\...
# Name: 107, dtype: object
# kinase_organism                                      RSK3_Homo sapiens
# substrates_merged    PLD1\tPLCB3\tFPGS\tSYK\tSLC9A1\tMYCBP2\tNR4A3\...
# Name: 108, dtype: object
# kinase_organism                                    MAP2K7_Homo sapiens
# substrates_merged    SLC2A2\tMAP1B\tCGN\tGRIN2B\tMAPK1\tMAP3K7IP3\t...
# Name: 109, dtype: object
# kinase_organism                                      CDK6_Homo sapiens
# substrates_merged    EIF2AK1\tHSP90AA1\tCDC37\tBCAS1\tAKT1\tLARP6\t...
# Name: 110, dtype: object
# kinase_organism                                    MAP2K2_Homo sapiens
# substrates_merged    PAK4\tPXN\tPTEN\tMAP2K4\tERBB3\tFLT1\tFYN\tGAB...
# Name: 111, dtype: object
# kinase_organism                                     EphA3_Homo sapiens
# substrates_merged    CRKL\tIGF1R\tFOXG1\tIRS2\tBCR\tDOK3\tCD247\tPD...
# Name: 112, dtype: object
# kinase_organism                                      AKT1_Homo sapiens
# substrates_merged    BRCA1\tCDKN1A\tCREB1\tESR1\tFOXO1\tGATA2\tNR4A...
# Name: 113, dtype: object
# kinase_organism                                    p70S6K_Homo sapiens
# substrates_merged    PPP2R5C\tBAD\tPRKAA2\tCSNK2A1\tLYN\tCCND1\tAKT...
# Name: 114, dtype: object
# kinase_organism                                       PKA_Mus musculus
# substrates_merged    LASP1\tPTPRR\tS25BP\tSTMN1\tVIME\tABCA1\tACLY\...
# Name: 115, dtype: object
# kinase_organism                                     EphA4_Homo sapiens
# substrates_merged    CBLB\tCRK\tBLNK\tKDR\tTNS1\tSYK\tCD247\tCSF1R\...
# Name: 116, dtype: object
# kinase_organism                                    MAP2K5_Homo sapiens
# substrates_merged    SMAD1\tPAK2\tECT2\tDUSP3\tMAP2K4\tTRAF7\tMAPK3...
# Name: 117, dtype: object
# kinase_organism                                 CK2_alpha_Homo sapiens
# substrates_merged    C1R\tJUN\tSSB\tPGR\tCDK1\tHSP90AA1\tHSP90AB1\t...
# Name: 118, dtype: object
# kinase_organism                                      TRKB_Homo sapiens
# substrates_merged    NTRK3\tCALB2\tPDGFRB\tKDR\tKIT\tTHRB\tCBL\tEGF...
# Name: 119, dtype: object
# kinase_organism                                     CSF1R_Homo sapiens
# substrates_merged    VAV1\tMYO18A\tSLK\tPIK3R2\tFYN\tINPPL1\tINPP5D...
# Name: 120, dtype: object
# kinase_organism                                     DMPK1_Homo sapiens
# substrates_merged    DOCK5\tFHOD1\tTNNI3\tJUN\tPAH\tADCY2\tCAMK2B\t...
# Name: 121, dtype: object
# kinase_organism                                     EphA1_Homo sapiens
# substrates_merged    LCP2\tPDGFRB\tINPPL1\tPIK3R2\tEGFR\tZAP70\tDNM...
# Name: 122, dtype: object
# kinase_organism                                     MRCKa_Homo sapiens
# substrates_merged    PARD3\tPAK2\tFNBP1L\tSEPT7\tSPRY2\tMYH4\tARHGE...
# Name: 123, dtype: object
# kinase_organism                                 PKB_group_Homo sapiens
# substrates_merged    TERT\tCHUK\tFANCA\tFOXO3\tRAF1\tADRB2\tAR\tNCF...
# Name: 124, dtype: object
# kinase_organism                                     ErbB3_Homo sapiens
# substrates_merged    GAB2\tCDC42\tBIRC6\tHSP90AA1\tADAM17\tPLBD1\tM...
# Name: 125, dtype: object
# kinase_organism                                   CSNK2A2_Homo sapiens
# substrates_merged    ARRB2\tMS4A1\tCASQ2\tCLTB\tCREM\tPTPRC\tLGALS3...
# Name: 126, dtype: object
# kinase_organism                                       MOK_Homo sapiens
# substrates_merged    MEFV\tRAG2\tIQGAP1\tKHDRBS1\tLRP2\tSRC\tHDAC4\...
# Name: 127, dtype: object
# kinase_organism                                    MAP4K4_Homo sapiens
# substrates_merged    RAPGEF4\tMAP2K2\tBDKRB2\tDNM2\tMAP2K7\tPOLR2A\...
# Name: 128, dtype: object
# kinase_organism                                     EphB3_Homo sapiens
# substrates_merged    ANGPT1\tKHDRBS1\tSRC\tKDR\tUFD1L\tDOK1\tPDGFRB...
# Name: 129, dtype: object
# kinase_organism                                     DAPK1_Homo sapiens
# substrates_merged    PDCD6IP\tRASSF2\tCALD1\tDCC\tAGAP2\tCDKN1B\tSM...
# Name: 130, dtype: object
# kinase_organism                                       PKC_Homo sapiens
# substrates_merged    ADDA\tADDB\tANXA1\tANXA2\tAT2B1\tCD44\tCFTR\tE...
# Name: 131, dtype: object
# kinase_organism                                     EphA5_Homo sapiens
# substrates_merged    EPHB4\tCD247\tEPHB3\tARNT\tBCAR1\tCTNND1\tPIK3...
# Name: 132, dtype: object
# kinase_organism                                     PRKCD_Homo sapiens
# substrates_merged    STAT3\tADD1\tADD2\tADRA2A\tADRBK1\tADRB2\tBDKR...
# Name: 133, dtype: object
# kinase_organism                                      FLT3_Homo sapiens
# substrates_merged    CD33\tIDH2\tBCL2\tIKZF1\tTK1\tGATA1\tPIK3CD\tS...
# Name: 134, dtype: object
# kinase_organism                                      CDC2_Homo sapiens
# substrates_merged    EEF2K\tDNM1L\tPIK3C2A\tPITPNM1\tDDX3X\tCHEK1\t...
# Name: 135, dtype: object
# kinase_organism                                     EphB4_Homo sapiens
# substrates_merged    EGFR\tLYN\tEPHA5\tEPHA2\tEPHA7\tDNM1\tKDR\tADA...
# Name: 136, dtype: object
# kinase_organism                                      CLK2_Homo sapiens
# substrates_merged    PARD3\tAURKB\tMTOR\tBCL2L11\tSP1\tPLA2G3\tPLA2...
# Name: 137, dtype: object
# kinase_organism                                     GSK3B_Homo sapiens
# substrates_merged    PSEN1\tAPP\tACLY\tCTNNB1\tCEBPA\tCREB1\tCREM\t...
# Name: 138, dtype: object
# kinase_organism                                       FYN_Homo sapiens
# substrates_merged    CD79A\tCTNNB1\tCDK5\tCTLA4\tFYN\tGRIN2B\tFCGR2...
# Name: 139, dtype: object
# kinase_organism                                     EphA7_Homo sapiens
# substrates_merged    EPHB4\tCD247\tBCAR1\tARNT\tCTNND1\tEPHB3\tPIK3...
# Name: 140, dtype: object
# kinase_organism                                     EphA6_Homo sapiens
# substrates_merged    DNM1\tCD247\tARNT\tBCAR1\tCTNND1\tPIK3R1\tGRB2...
# Name: 141, dtype: object
# kinase_organism                                    AMPKa1_Homo sapiens
# substrates_merged    PPARA\tSTRADA\tFASN\tMLXIPL\tGRIK2\tPROX1\tTNS...
# Name: 142, dtype: object
# kinase_organism                                      GRK3_Homo sapiens
# substrates_merged    ADRA1B\tCRHR1\tPLCB1\tMYO18A\tZMYM6\tOR4K13\tJ...
# Name: 143, dtype: object
# kinase_organism                                MAPK_group_Homo sapiens
# substrates_merged    ESR1\tNR3C1\tTP53\tBCL2\tETS1\tHIST1H3J\tSTMN1...
# Name: 144, dtype: object
# kinase_organism                                      MST4_Homo sapiens
# substrates_merged    PRKAG2\tPRKAA2\tPRKAB1\tKIF11\tBRAF\tSIK2\tTP5...
# Name: 145, dtype: object
# kinase_organism                                     EphA8_Homo sapiens
# substrates_merged    DNM1\tLYN\tARNT\tBCAR1\tCTNND1\tPIK3R1\tCBL\tV...
# Name: 146, dtype: object
# kinase_organism                                      TNIK_Homo sapiens
# substrates_merged    HRAS\tDNM2\tRAPGEF4\tAPC\tTANK\tARHGEF7\tFLT1\...
# Name: 147, dtype: object
# kinase_organism                                       PKC_Mus musculus
# substrates_merged    ANXA2\tBCL2\tIL1R1\tMACS\tPEA15\tSNP25\tVIME\t...
# Name: 148, dtype: object
# kinase_organism                                      GRK5_Homo sapiens
# substrates_merged    ADRB2\tBDKRB2\tSNCA\tGRK5\tSNCB\tSNCG\tPPP1R9B...
# Name: 149, dtype: object
# kinase_organism                                      MST3_Homo sapiens
# substrates_merged    WNK1\tTGM6\tSTK11\tMOBKL1A\tCTTN\tSTK4\tSLC12A...
# Name: 150, dtype: object
# kinase_organism                                     PDHK4_Homo sapiens
# substrates_merged    HNF4A\tPRKG2\tPRKCD\tAKT1\tPDHA2\tHMGCS2\tPNPL...
# Name: 151, dtype: object
# kinase_organism                                     PRKCB_Homo sapiens
# substrates_merged    GJA1\tTOP2A\tEPB41\tEIF4E\tGRIN2B\tSDC2\tITGB7...
# Name: 152, dtype: object
# kinase_organism                                 PKA_group_Mus musculus
# substrates_merged    Hspb1\tVim\tStmn1\tSnapin\tAurkc\tTnni3\tMybpc...
# Name: 153, dtype: object
# kinase_organism                                 CK1gamma1_Homo sapiens
# substrates_merged    MYC\tCTNND1\tAPC\tVANGL1\tCTNNB1\tCDC25A\tPER2...
# Name: 154, dtype: object
# kinase_organism                                       LCK_Homo sapiens
# substrates_merged    CTLA4\tEZR\tESR1\tRASA1\tIL2RB\tCD79B\tCD5\tLC...
# Name: 155, dtype: object
# kinase_organism                                 CDK_group_Homo sapiens
# substrates_merged    DAB1\tLMNA\tESR1\tTP53\tRB1\tPPP1CA\tMAPT\tSRC...
# Name: 156, dtype: object
# kinase_organism                                      GRK1_Homo sapiens
# substrates_merged    NR2E3\tTBL1XR1\tTBL1X\tACAP2\tMAP3K7IP1\tRPS6K...
# Name: 157, dtype: object
# kinase_organism                                      TRKC_Homo sapiens
# substrates_merged    NTRK1\tCALB2\tSH2B3\tPTPN1\tSH2B2\tHPSE\tCSK\t...
# Name: 158, dtype: object
# kinase_organism                                       Ron_Homo sapiens
# substrates_merged    HSPA8\tPLXNB2\tLONP1\tYES1\tINPP5D\tINPPL1\tSF...
# Name: 159, dtype: object
# kinase_organism                                      PLK2_Homo sapiens
# substrates_merged    TP53\tLRP2\tVLDLR\tSRF\tSNX1\tNBR1\tPRKDC\tPBX...
# Name: 160, dtype: object
# kinase_organism                                      PKCa_Homo sapiens
# substrates_merged    SNAP23\tSLC9A3R1\tPLD2\tKCNQ2\tDLX3\tPFKFB2\tE...
# Name: 161, dtype: object
# kinase_organism                                      Pim2_Homo sapiens
# substrates_merged    PRKCD\tFOXO1\tCBX5\tRAF1\tCRK\tBCLAF1\tSTAT5A\...
# Name: 162, dtype: object
# kinase_organism                                     EphB6_Homo sapiens
# substrates_merged    KDR\tLYN\tDNM1\tSRC\tPIK3R1\tEPHA3\tWASL\tTIAM...
# Name: 163, dtype: object
# kinase_organism                                       LYN_Homo sapiens
# substrates_merged    CD19\tSLC4A1\tCD79A\tCDK1\tFCGR2A\tCD79B\tNMT1...
# Name: 164, dtype: object
# kinase_organism                                      CDC2_Mus musculus
# substrates_merged    Birc5\tPak1\tPolr2a\tMyod1\tItpr1\tHmga1\tMcm3...
# Name: 165, dtype: object
# kinase_organism                                      PAK1_Homo sapiens
# substrates_merged    ESR1\tFOXO1\tCASP1\tRAF1\tMAP2K1\tSYN1\tMYLK\t...
# Name: 166, dtype: object
# kinase_organism                                      PAK6_Homo sapiens
# substrates_merged    CTTN\tGNG12\tMTAP\tCD226\tSFN\tABCC5\tMYLK2\tR...
# Name: 167, dtype: object
# kinase_organism                                AMPK_group_Mus musculus
# substrates_merged    Ppargc1a\tUlk1\tTp53\tHist1h2bn\tHist1h2bm\tIr...
# Name: 168, dtype: object
# kinase_organism                                      ERK2_Mus musculus
# substrates_merged    Fos\tItpr1\tEts2\tAtf2\tTnfrsf1a\tCebpb\tDusp1...
# Name: 169, dtype: object
# kinase_organism                                      PASK_Homo sapiens
# substrates_merged    PDX1\tGYS1\tRAB11FIP1\tFXN\tPIAS1\tCREB1\tNFAT...
# Name: 170, dtype: object
# kinase_organism                                      GRK6_Homo sapiens
# substrates_merged    BDKRB2\tSNCA\tGRK6\tLTB4R\tSLC9A3R1\tDVL2\tADR...
# Name: 171, dtype: object
# kinase_organism                                 CK1gamma2_Homo sapiens
# substrates_merged    CDC25A\tPER2\tKCNIP3\tCDKN1B\tMDM4\tGLI3\tGLI2...
# Name: 172, dtype: object
# kinase_organism                                       CK2_Homo sapiens
# substrates_merged    A4\tC1R\tESR1\tFURIN\tLA\tMYCN\tNRF1\tPTEN\tSY...
# Name: 173, dtype: object
# kinase_organism                                 CK1_group_Homo sapiens
# substrates_merged    TP53\tAPC\tYWHAQ\tCTNNB1\tCSNK1E\tNFATC3\tCDK5...
# Name: 174, dtype: object
# kinase_organism                                      CLK4_Homo sapiens
# substrates_merged    PPIG\tPTPN1\tZNF638\tSFRS11\tSFRS6\tSLTM\tU2AF...
# Name: 175, dtype: object
# kinase_organism                                     MARK4_Homo sapiens
# substrates_merged    PAWR\tDFFA\tTUBB2A\tCYFIP1\tACTA1\tHSPA4\tTUBA...
# Name: 176, dtype: object
# kinase_organism                                     MARK3_Homo sapiens
# substrates_merged    MAP2\tHDAC4\tSFN\tIKBKB\tRASGRF1\tC17orf53\tRP...
# Name: 177, dtype: object
# kinase_organism                                      GRK4_Homo sapiens
# substrates_merged    IKBKG\tAGTR1\tCEBPZ\tADD2\tGNAQ\tBDKRB2\tRGS12...
# Name: 178, dtype: object
# kinase_organism                                       ICK_Homo sapiens
# substrates_merged    NIPBL\tPML\tULK1\tRPS6KB1\tCLIP1\tPPARGC1A\tCD...
# Name: 179, dtype: object
# kinase_organism                                      YSK1_Homo sapiens
# substrates_merged    STK11\tMBP\tMAP2K3\tSTK4\tMOBKL1A\tPRPF31\tSLK...
# Name: 180, dtype: object
# kinase_organism                                       Lck_Homo sapiens
# substrates_merged    SOCS3\tESR1\tLCK\tEZR\tVAV1\tNFKBIA\tVAV2\tLCP...
# Name: 181, dtype: object
# kinase_organism                                      ABL1_Homo sapiens
# substrates_merged    CD19\tCDK5\tJAK2\tMAPT\tCRK\tMDM2\tJUN\tPTPN6\...
# Name: 182, dtype: object
# kinase_organism                                  MAPKAPK2_Homo sapiens
# substrates_merged    CREB1\tALOX5\tLSP1\tZFP36\tTSC2\tTH\tETV1\tSRF...
# Name: 183, dtype: object
# kinase_organism                                       SYK_Homo sapiens
# substrates_merged    SLC4A1\tFCGR2A\tLCK\tSNCA\tPLCG1\tPRKCA\tTUBA4...
# Name: 184, dtype: object
# kinase_organism                                     Chak2_Homo sapiens
# substrates_merged    ATP1A1\tTRPV5\tVIM\tFXYD1\tGNB2L1\tINSR\tTJP1\...
# Name: 185, dtype: object
# kinase_organism                                      NEK1_Homo sapiens
# substrates_merged    HNRNPA1\tCEBPB\tPPP1R15A\tXRCC2\tNCAPD2\tSUFU\...
# Name: 186, dtype: object
# kinase_organism                                       CK2_Mus musculus
# substrates_merged    A4\tC1R\tDCX\tDSPP\tESR1\tFKBP4\tFURIN\tGA45B\...
# Name: 187, dtype: object
# kinase_organism                                GSK-3_beta_Homo sapiens
# substrates_merged    MYC\tESR1\tMAPT\tMUC1\tNFKB1\tCDKN1A\tPSEN1\tR...
# Name: 188, dtype: object
# kinase_organism                                 PKC_group_Mus musculus
# substrates_merged    Lmna\tIl1r1\tHspb1\tVim\tMarcksl1\tIrs1\tPea15...
# Name: 189, dtype: object
# kinase_organism                                       NRK_Homo sapiens
# substrates_merged    ARHGEF7\tABLIM1\tFLT1\tEGFR\tMAP2K7\tKIRREL\tS...
# Name: 190, dtype: object
# kinase_organism                                     PRKCG_Homo sapiens
# substrates_merged    ADRBK1\tGJA1\tTOP2A\tEIF4E\tGRIN2B\tSDC2\tIRS1...
# Name: 191, dtype: object
# kinase_organism                                   p70S6Kb_Homo sapiens
# substrates_merged    RPTOR\tLYN\tTSC2\tBRCA1\tAKT2\tSYK\tPDK1\tBTK\...
# Name: 192, dtype: object
# kinase_organism                                AMPK_group_Homo sapiens
# substrates_merged    IRS1\tKPNA2\tEP300\tEEF2K\tPFKFB2\tHNF4A\tPRKA...
# Name: 193, dtype: object
# kinase_organism                                  MAPKAPK5_Homo sapiens
# substrates_merged    HBP1\tMAPK13\tMAPK4\tCDC25B\tMAPK12\tMAPK1\tJU...
# Name: 194, dtype: object
# kinase_organism                                 PKA_alpha_Mus musculus
# substrates_merged    Vim\tGsk3b\tSptbn1\tDcx\tPrkaca\tPln\tItpr1\tP...
# Name: 195, dtype: object
# kinase_organism                                       Lyn_Homo sapiens
# substrates_merged    LYN\tCD19\tCSNK2A1\tSTAT5A\tBTK\tEPOR\tSLC4A1\...
# Name: 196, dtype: object
# kinase_organism                                      TLK2_Homo sapiens
# substrates_merged    HIRA\tIFNAR1\tTLK1\tFEZ1\tTMC8\tBIN1\tPVRL2\tW...
# Name: 197, dtype: object
# kinase_organism                                     PDHK2_Homo sapiens
# substrates_merged    AKT3\tGSK3A\tILK\tPDHA2\tBCKDHB\tNEK6\tKIF3B\t...
# Name: 198, dtype: object
# kinase_organism                                    CAMK2A_Homo sapiens
# substrates_merged    ATP2A2\tEGFR\tGFAP\tGRIN2B\tGRIN2A\tHSF1\tKRT1...
# Name: 199, dtype: object
# kinase_organism                                      PAK5_Homo sapiens
# substrates_merged    PLD1\tBAIAP2\tPAK4\tIQGAP2\tITSN1\tPAK2\tGNG12...
# Name: 200, dtype: object
# kinase_organism                                       SRC_Mus musculus
# substrates_merged    Cav1\tDab1\tShc1\tAdam12\tCav2\tCttn\tEfs\tBca...
# Name: 201, dtype: object
# kinase_organism                                     PDK-1_Homo sapiens
# substrates_merged    PDPK1\tRPS6KB1\tAKT1\tAKT2\tMAP2K1\tPAK1\tRPS6...
# Name: 202, dtype: object
# kinase_organism                                     PKACa_Mus musculus
# substrates_merged    Dcx\tMos\tPrkaca\tEn2\tRara\tItpr1\tCsf2rb\tRa...
# Name: 203, dtype: object
# kinase_organism                                   RPS6KA1_Homo sapiens
# substrates_merged    CREB1\tESR1\tNR4A1\tNFKBIA\tFOS\tCEBPB\tTSC2\t...
# Name: 204, dtype: object
# kinase_organism                                      MST2_Homo sapiens
# substrates_merged    CTTNBP2\tAURKA\tTP53\tPDCD6IP\tSTK24\tSTRN\tST...
# Name: 205, dtype: object
# kinase_organism                                       Fyn_Homo sapiens
# substrates_merged    FYB\tFYN\tCD247\tCBL\tCTNNB1\tCAV1\tGRB10\tSNC...
# Name: 206, dtype: object
# kinase_organism                                     PKACa_Homo sapiens
# substrates_merged    EEF2K\tAURKA\tCLDN3\tRGS14\tPLIN1\tPFKFB2\tSNA...
# Name: 207, dtype: object
# kinase_organism                                      INSR_Homo sapiens
# substrates_merged    ADRB2\tCALM1\tCALM2\tCALM3\tINSR\tCBL\tPIK3R1\...
# Name: 208, dtype: object
# kinase_organism                                 RSK_group_Homo sapiens
# substrates_merged    ESR1\tRPS6\tSRF\tCREB1\tFLNA\tCDKN1B\tTSC2\tGS...
# Name: 209, dtype: object
# kinase_organism                                     PRKG1_Homo sapiens
# substrates_merged    CREB1\tITPR1\tSPP1\tRYR1\tPLCB3\tRGS2\tCRIP2\t...
# Name: 210, dtype: object
# kinase_organism                                    MAP4K6_Homo sapiens
# substrates_merged    RBM7\tPKN2\tPRKCD\tTNIK\tTRAF2\tTNFAIP6\tSGOL2...
# Name: 211, dtype: object
# kinase_organism                                     MAPK1_Mus musculus
# substrates_merged    Sorbs3\tCebpb\tItpr1\tPpp1r9b\tCry2\tTnfrsf1a\...
# Name: 212, dtype: object
# kinase_organism                             CaM-KII_group_Homo sapiens
# substrates_merged    TH\tCREB1\tATP2A2\tCEBPB\tFLNA\tPEA15\tCFL2\tD...
# Name: 213, dtype: object
# kinase_organism                                    CAMK2G_Homo sapiens
# substrates_merged    ATF1\tCREM\tEGFR\tGRIA4\tGRIA1\tRRAD\tRYR1\tSP...
# Name: 214, dtype: object
# kinase_organism                                      MST1_Homo sapiens
# substrates_merged    MOBKL1A\tRAPGEF4\tPRDX6\tANXA2\tGTF2I\tTP53\tF...
# Name: 215, dtype: object
# kinase_organism                                     PDPK1_Homo sapiens
# substrates_merged    AKT1\tAKT2\tITGB3\tPRKCE\tPRKCD\tPRKCZ\tPKN1\t...
# Name: 216, dtype: object
# kinase_organism                                     PRKCZ_Homo sapiens
# substrates_merged    PSEN1\tRELA\tPRKCA\tPRKCD\tPRKCZ\tYWHAB\tCASP9...
# Name: 217, dtype: object
# kinase_organism                             CaM-KII_alpha_Homo sapiens
# substrates_merged    EGFR\tERBB2\tTH\tVIM\tETS1\tNOS1\tPLA2G4A\tCAM...
# Name: 218, dtype: object
# kinase_organism                                       CSK_Homo sapiens
# substrates_merged    CSK\tFYN\tGSN\tHCK\tLCK\tFGR\tLYN\tSRC\tPXN\tR...
# Name: 219, dtype: object
# kinase_organism                                      PKCa_Mus musculus
# substrates_merged    Rho\tPtpra\tVim\tAhr\tCrebbp\tLmna\tTnni3\tTnn...
# Name: 220, dtype: object
# kinase_organism                                     GSK3B_Mus musculus
# substrates_merged    Arhgap31\tDpysl2\tPten\tNotch2\tAxin1\tPrkce\t...
# Name: 221, dtype: object
# kinase_organism                                 PKC_delta_Homo sapiens
# substrates_merged    KRT8\tMET\tMUC1\tYWHAB\tIRS1\tIL6ST\tSTAT3\tEP...
# Name: 222, dtype: object
# kinase_organism                                 PKC_alpha_Mus musculus
# substrates_merged    Lmna\tVim\tPtpra\tCrebbp\tStk11\tRaf1\tRho\tAh...
# Name: 223, dtype: object
# kinase_organism                                    CSNK2B_Homo sapiens
# substrates_merged    BRCA1\tCSNK2B\tCTNNB1\tCDC34\tMME\tHOXB6\tIRS1...
# Name: 224, dtype: object
# kinase_organism                                     CK2a1_Homo sapiens
# substrates_merged    CASQ2\tSHOX\tHDAC3\tBIRC5\tKIF1C\tSNCG\tDDX58\...
# Name: 225, dtype: object
# kinase_organism                                       IRR_Homo sapiens
# substrates_merged    IGF2\tNOS3\tINSR\tSOS1\tPDGFD\tSOS2\tPIK3CG\tP...
# Name: 226, dtype: object
# kinase_organism                                      CDK5_Mus musculus
# substrates_merged    Ndel1\tDcx\tPak1\tStxbp1\tTh\tEzr\tMap2k1\tCac...
# Name: 227, dtype: object
# kinase_organism                                      GRK7_Homo sapiens
# substrates_merged    GRK1\tRAB8A\tRAB13\tADRB1\tNR2E3\tCXCR2\tCCR10...
# Name: 228, dtype: object
# kinase_organism                                     MARK1_Homo sapiens
# substrates_merged    TFAP2C\tCDC25C\tGRIK4\tARHGAP10\tSCRN1\tKIAA14...
# Name: 229, dtype: object
# kinase_organism                                CaMKIalpha_Homo sapiens
# substrates_merged    CAMK2B\tMYEF2\tGRIA1\tANXA6\tNOS1\tATF1\tPRKAR...
# Name: 230, dtype: object
# kinase_organism                                  Probable_Homo sapiens
# substrates_merged    CCNE2\tCOF1\tDAXX\tFADD\tFOXM1\tIKBE\tIL4RA\tK...
# Name: 231, dtype: object
# kinase_organism                                       HCK_Homo sapiens
# substrates_merged    STAT3\tCSF3R\tHCK\tBCR\tCBL\tPLCG1\tWAS\tPLCG2...
# Name: 232, dtype: object
# kinase_organism                                      JAK2_Homo sapiens
# substrates_merged    STAT3\tCTLA4\tEGFR\tEPOR\tJAK2\tRAF1\tSTAT1\tC...
# Name: 233, dtype: object
# kinase_organism                                   RPS6KA5_Homo sapiens
# substrates_merged    STAT3\tATF1\tCREB1\tNR4A1\tHMGN1\tTH\tETV1\tST...
# Name: 234, dtype: object
# kinase_organism                                      SGK3_Homo sapiens
# substrates_merged    KCNQ1\tGRIK2\tCTNNB1\tPLEK\tFOXO3\tTRPV5\tCACN...
# Name: 235, dtype: object
# kinase_organism                                      ABL1_Mus musculus
# substrates_merged    Abl1\tPdgfrb\tMyod1\tApp\tCbl\tCdk5\tCav1\tDok...
# Name: 236, dtype: object
# kinase_organism                                   CSNK1A1_Homo sapiens
# substrates_merged    CTNNB1\tCREM\tYWHAQ\tLGALS3\tHNRNPC\tTP53\tSLC...
# Name: 237, dtype: object
# kinase_organism                                      PKD3_Homo sapiens
# substrates_merged    IKBKG\tHDAC7\tSLC9A3R1\tGSK3A\tGOLGA4\tPLEK\tB...
# Name: 238, dtype: object
# kinase_organism                                     CHEK2_Homo sapiens
# substrates_merged    BRCA1\tCDC25A\tCDC25C\tE2F1\tMDM4\tCHEK2\tAATF...
# Name: 239, dtype: object
# kinase_organism                                       SLK_Homo sapiens
# substrates_merged    PRKCD\tSTK25\tASAP1\tPPP1R12A\tCSF1R\tKHDRBS1\...
# Name: 240, dtype: object
# kinase_organism                                      TLK1_Homo sapiens
# substrates_merged    CLSPN\tHIRA\tHIST1H1A\tPTGES3\tCHEK1\tINCENP\t...
# Name: 241, dtype: object
# kinase_organism                                       Lyn_Mus musculus
# substrates_merged    Hcls1\tCttn\tIrs2\tEfs\tBcar1\tDok2\tDbnl\tSyk...
# Name: 242, dtype: object
# kinase_organism                                    Haspin_Homo sapiens
# substrates_merged    HERC1\tUSP16\tKIF11\tCCNG2\tRCC2\tKCNJ11\tPLK1...
# Name: 243, dtype: object
# kinase_organism                                      MST1_Mus musculus
# substrates_merged    Hist1h2bn\tHist1h2bm\tHist1h2bb\tHist1h2bh\tHi...
# Name: 244, dtype: object
# kinase_organism                                  MAPKAPK3_Homo sapiens
# substrates_merged    MAPK12\tMAPK13\tASXL1\tMAPKAPK2\tEEF2\tMAP2K3\...
# Name: 245, dtype: object
# kinase_organism                                      MAPK_Mus musculus
# substrates_merged    ETS1\tJIP3\tMACS\tMAPK2\tTTP\tADA17\tDCX\tESR2...
# Name: 246, dtype: object
# kinase_organism                                      AKT1_Mus musculus
# substrates_merged    Chek1\tCdkn1b\tCreb1\tGsk3a\tTbc1d1\tPde3b\tTb...
# Name: 247, dtype: object
# kinase_organism                                      CLK3_Homo sapiens
# substrates_merged    SMG1\tCDC25A\tFANCM\tFANCD2\tSFN\tIMMT\tDSG1\t...
# Name: 248, dtype: object
# kinase_organism                                  Aurora B_Homo sapiens
# substrates_merged    BIRC5\tVIM\tHIST1H3J\tGFAP\tDES\tCENPA\tINCENP...
# Name: 249, dtype: object
# kinase_organism                                     CK2a1_Mus musculus
# substrates_merged    Ptprc\tCdh1\tSpi1\tPpm1a\tThra\tBid\tAscl1\tSt...
# Name: 250, dtype: object
# kinase_organism                                      PDK1_Homo sapiens
# substrates_merged    AKT1\tITGB3\tPDHA1\tPDK1\tPKN2\tAKT3\tRPS6KB1\...
# Name: 251, dtype: object
# kinase_organism                                      PKD2_Homo sapiens
# substrates_merged    APPL1\tSTOM\tMEF2D\tCSNK1D\tCSNK1E\tPLEK\tPKD1...
# Name: 252, dtype: object
# kinase_organism                                MAPK_group_Mus musculus
# substrates_merged    Bcl2l11\tKrt8\tTal1\tZfp36\tMarcks\tEts1\tPla2...
# Name: 253, dtype: object
# kinase_organism                                 SGK_group_Homo sapiens
# substrates_merged    FOXO3\tCREB1\tHTT\tGSK3B\tMAP3K3\tFOXO1\tNDRG1...
# Name: 254, dtype: object
# kinase_organism                                 CK2_alpha_Mus musculus
# substrates_merged    Bad\tHsph1\tBid\tPtprc\tSpi1\tPpm1a\tThra\tAsc...
# Name: 255, dtype: object
# kinase_organism                                 CK1gamma3_Homo sapiens
# substrates_merged    GLI3\tPPP1R14A\tIPMK\tGLI2\tGLI1\tRPS6\tYWHAB\...
# Name: 256, dtype: object
# kinase_organism                                 CK1alpha2_Homo sapiens
# substrates_merged    LRP6\tCDC25A\tPER2\tKCNIP3\tMDM4\tGLI3\tGLI2\t...
# Name: 257, dtype: object
# kinase_organism                                     GRK-2_Homo sapiens
# substrates_merged    ADRB2\tPDGFRB\tEZR\tSNCA\tTUBB3\tFPR1\tMC4R\tO...
# Name: 258, dtype: object
# kinase_organism                               GSK-3_group_Homo sapiens
# substrates_merged    MYC\tTP53\tJUN\tCREB1\tCCND1\tCTNNB1\tEIF2B5\t...
# Name: 259, dtype: object
# kinase_organism                                       LYN_Mus musculus
# substrates_merged    Tec\tLyn\tPrkcd\tBtk\tSyk\tLilrb3\tPag1\tLpxn\...
# Name: 260, dtype: object
# kinase_organism                               PKC_epsilon_Homo sapiens
# substrates_merged    MET\tGJA1\tGABRG2\tIQGAP1\tKRT18\tSLC4A3\tPRKC...
# Name: 261, dtype: object
# kinase_organism                                     PRKCQ_Homo sapiens
# substrates_merged    ICAM3\tIRS1\tMSN\tPRKCQ\tCHUK\tWIPF1\tIKBKB\tG...
# Name: 262, dtype: object
# kinase_organism                                     PRKCE_Homo sapiens
# substrates_merged    SLC4A3\tKRT18\tOPRD1\tPRKCE\tTRPV1\tGRM5\tCHAT...
# Name: 263, dtype: object
# kinase_organism                                 CK1_alpha_Homo sapiens
# substrates_merged    HNRNPC\tLGALS3\tYWHAQ\tYWHAZ\tFOXO1\tSNCA\tSLC...
# Name: 264, dtype: object
# kinase_organism                                      Pim3_Homo sapiens
# substrates_merged    CREBBP\tRAF1\tC16orf53\tBRD1\tCBX5\tNUP50\tSTA...
# Name: 265, dtype: object
# kinase_organism                                   RPS6KA3_Homo sapiens
# substrates_merged    CREB1\tESR1\tNR4A1\tKRT18\tMAPT\tHMGN2\tHMGN1\...
# Name: 266, dtype: object
# kinase_organism                                      SGK2_Homo sapiens
# substrates_merged    PDK1\tKCNQ1\tGRIK2\tSLC1A6\tTRPV5\tPDPK1\tNEDD...
# Name: 267, dtype: object
# kinase_organism                                       BTK_Homo sapiens
# substrates_merged    CD19\tBMX\tBTK\tWAS\tPLCG2\tSTAT5A\tGTF2I\tDAP...
# Name: 268, dtype: object
# kinase_organism                                     BCKDK_Homo sapiens
# substrates_merged    PDHA2\tTRAF4\tARAF\tBCKDHB\tCKB\tPDHX\tARID4B\...
# Name: 269, dtype: object
# kinase_organism                                     ZAP70_Homo sapiens
# substrates_merged    MUC1\tZAP70\tDUSP3\tSHC1\tLCP2\tLAT\tSH2B3\tGA...
# Name: 270, dtype: object
# kinase_organism                                  PKC_zeta_Homo sapiens
# substrates_merged    YWHAB\tIRS1\tGEM\tCASP9\tRELA\tPRKCZ\tADD1\tPP...
# Name: 271, dtype: object
# kinase_organism                                     CHEK1_Homo sapiens
# substrates_merged    CDC25A\tCDC25C\tRAD51\tTP53\tMDM4\tCLSPN\tTLK1...
# Name: 272, dtype: object
# kinase_organism                                       MAK_Homo sapiens
# substrates_merged    FARP2\tDES\tPPARGC1B\tPAK1IP1\tMAK16\tEVPL\tRP...
# Name: 273, dtype: object
# kinase_organism                                     DAPK3_Homo sapiens
# substrates_merged    HIST1H3J\tMYL9\tMDM2\tPPP1R14A\tDAPK3\tRPL13A\...
# Name: 274, dtype: object
# kinase_organism                                       RET_Homo sapiens
# substrates_merged    RET\tPLCG1\tMAPK1\tMAPK14\tPTK2\tMAPK8\tMAPK9\...
# Name: 275, dtype: object
# kinase_organism                                PKG1/cGK-I_Homo sapiens
# substrates_merged    RAP1B\tPDE5A\tRGS2\tCRIP2\tLASP1\tSF1\tFHOD1\t...
# Name: 276, dtype: object
# kinase_organism                                      JNK1_Mus musculus
# substrates_merged    Bcl2l11\tBcl2\tRxra\tElk3\tJdp2\tNfe2\tBad\tIt...
# Name: 277, dtype: object
# kinase_organism                                      PLK3_Homo sapiens
# substrates_merged    CHEK2\tTP53\tTOP2A\tATF2\tCDC25A\tCDC25C\tBCL2...
# Name: 278, dtype: object
# kinase_organism                                      JAK1_Homo sapiens
# substrates_merged    STAT3\tIL2RB\tIL10RA\tIRS1\tEIF2AK2\tTYK2\tSTA...
# Name: 279, dtype: object
# kinase_organism                                ROCK_group_Homo sapiens
# substrates_merged    VIM\tGFAP\tDES\tMSN\tRDX\tADD1\tLIMK1\tLIMK2\t...
# Name: 280, dtype: object
# kinase_organism                                      CDK2_Mus musculus
# substrates_merged    Mybl2\tMyod1\tMdm2\tUbtf\tMcm4\tE2f5\tMcm3ap\t...
# Name: 281, dtype: object
# kinase_organism                                      CDK1_Mus musculus
# substrates_merged    Nup210\tPak1\tMyod1\tIncenp\tPolr2a\tItpr1\tMc...
# Name: 282, dtype: object
# kinase_organism                                     RSK-2_Homo sapiens
# substrates_merged    CREB1\tCDKN1B\tMEF2C\tBAD\tFOS\tDAPK1\tATF4\tN...
# Name: 283, dtype: object
# kinase_organism                                      ERK1_Mus musculus
# substrates_merged    Fos\tEts2\tAtf2\tCebpb\tCanx\tElk1\tPla2g4a\tM...
# Name: 284, dtype: object
# kinase_organism                                     PRKDC_Homo sapiens
# substrates_merged    NR3C1\tHSP90AA1\tJUN\tRPA2\tTP53\tXPA\tSRF\tPR...
# Name: 285, dtype: object
# kinase_organism                                    DYRK1A_Homo sapiens
# substrates_merged    AMPH\tDNM1\tFOXO1\tSNCA\tSPRY2\tSF3B1\tDYRK1A\...
# Name: 286, dtype: object
# kinase_organism                                    ADRBK1_Homo sapiens
# substrates_merged    ADRA2A\tBDKRB2\tFPR1\tMC4R\tSNCA\tOPRD1\tRPLP2...
# Name: 287, dtype: object
# kinase_organism                                     HIPK1_Homo sapiens
# substrates_merged    DACH1\tHDAC4\tDAXX\tMYST3\tSUMO1\tNKX2-5\tBRD1...
# Name: 288, dtype: object
# kinase_organism                                    DNA-PK_Homo sapiens
# substrates_merged    NR3C1\tTP53\tJUN\tHSP90AA1\tSRF\tRPA2\tPRKDC\t...
# Name: 289, dtype: object
# kinase_organism                                     FYN_Mus musculus
# substrates_merged    Kit\tTxk\tCdk5\tPld2\tGrin2b\tPag1\tSkap2\tDlg2
# Name: 290, dtype: object
# kinase_organism                                     DAPK2_Homo sapiens
# substrates_merged    RASSF1\tCADM1\tBNIP3\tCEBPE\tMLC1\tMAPK3\tMAPK...
# Name: 291, dtype: object
# kinase_organism                                  Probable_Mus musculus
# substrates_merged    CD22\tI12R2\tIL4RA\tKIRR1\tMP2K6\tNFAM1\tSHC2\...
# Name: 292, dtype: object
# kinase_organism                                 PKB_group_Mus musculus
# substrates_merged    Irs1\tBad\tMap3k11\tPde3b\tGrb10\tBax\tFoxo1\t...
# Name: 293, dtype: object
# kinase_organism                                  MAPKAPK2_Mus musculus
# substrates_merged    Krt18\tHspb1\tRps6ka3\tLsp1\tZfp36\tDdit3\tHnr...
# Name: 294, dtype: object
# kinase_organism                                      GSK3_Homo sapiens
# substrates_merged    MITF\tMYC\tBCL3\tCCNE1\tBCAM\tSMAD3\tDPYSL3\tMAFA
# Name: 295, dtype: object
# kinase_organism                                     MAPK_Homo sapiens
# substrates_merged    DCX\tETS1\tGORS2\tGTF2I\tJIP3\tMACS\tMAPK2\tPPAT
# Name: 296, dtype: object
# kinase_organism                                    CSNK1D_Homo sapiens
# substrates_merged    CTNNB1\tGJA1\tCDK5\tSNCA\tTP53\tPSEN2\tPER2\tB...
# Name: 297, dtype: object
# kinase_organism                              Tyr-kinases_Mus musculus
# substrates_merged    ACHB\tACHD\tESR1\tFABPA\tFABPH\tLAT\tMYCS\tSHPS1
# Name: 298, dtype: object
# kinase_organism                                     PDHK3_Homo sapiens
# substrates_merged    MYBL2\tBCKDHB\tPDHA2\tTGFB1I1\tPPARA\tACTG2\tP...
# Name: 299, dtype: object
# kinase_organism                                  Aurora A_Homo sapiens
# substrates_merged    TP53\tHIST1H3J\tCDC25B\tBRCA1\tAURKA\tMBD3\tCE...
# Name: 300, dtype: object
# kinase_organism                                   AuroraC_Homo sapiens
# substrates_merged    TACC2\tEPN1\tZCCHC7\tSTK11IP\tCDCA8\tAURKB\tIN...
# Name: 301, dtype: object
# kinase_organism                                      NEK4_Homo sapiens
# substrates_merged    SSRP1\tCSN2\tTOB1\tBAG4\tITIH1\tDIXDC1\tDAXX\t...
# Name: 302, dtype: object
# kinase_organism                                   GSK3A_Homo sapiens
# substrates_merged    CREM\tHSF1\tMAPT\tEIF2B5\tGSK3A\tMCL1\tMYC\tJUN
# Name: 303, dtype: object
# kinase_organism                               CK2a_Homo sapiens
# substrates_merged    STC2\tABCA1\tC1R\tVTN\tMYCN\tJUN\tSSB\tCD5
# Name: 304, dtype: object
# kinase_organism                                      NEK3_Homo sapiens
# substrates_merged    DNAJC6\tPTPN3\tNCAPD2\tSUGT1\tPRLR\tCSN2\tPRL\...
# Name: 305, dtype: object
# kinase_organism                                   SYK_Mus musculus
# substrates_merged    Prkca\tBtk\tSyk\tTuba1a\tPrkcb\tSh3bp2\tPlcg1
# Name: 306, dtype: object
# kinase_organism                                   TBK1_Homo sapiens
# substrates_merged    IKBKB\tNFKBIA\tIRF5\tIRF3\tTMEM173\tIRF7\tOPTN
# Name: 307, dtype: object
# kinase_organism                                     JAK_Mus musculus
# substrates_merged    STA5A\tSTA5B\tSTAT1\tSTAT2\tSTAT3\tSTAT4\tSTAT6
# Name: 308, dtype: object
# kinase_organism                        ROCK2_Mus musculus
# substrates_merged    Vim\tEzr\tMsn\tRdx\tIrs1\tIrf4\tMyl9
# Name: 309, dtype: object
# kinase_organism                                     LKB1_Mus musculus
# substrates_merged    Mark2\tPrkaa1\tBrsk1\tSik1\tBrsk2\tPrkaa2\tStk11
# Name: 310, dtype: object
# kinase_organism                               Abl_Mus musculus
# substrates_merged    Abl1\tCav1\tCrk\tDok1\tApbb1\tMyod1\tJak2
# Name: 311, dtype: object
# kinase_organism                        Tyr-kinases_Homo sapiens
# substrates_merged    ACHB\tACHD\tFABPA\tFABPH\tITB7\tLAT\tSHPS1
# Name: 312, dtype: object
# kinase_organism                                 RSK-1_Homo sapiens
# substrates_merged    CEBPB\tIRS1\tBAD\tETV1\tESR2\tNFKBIB\tPPP1R3A
# Name: 313, dtype: object
# kinase_organism                               PKC_beta_Homo sapiens
# substrates_merged    TOP2A\tATF2\tLMNB1\tITGB2\tRPS6KB2\tFUS\tKCNC4
# Name: 314, dtype: object
# kinase_organism                                   CHK2_Homo sapiens
# substrates_merged    CHEK2\tTP53\tCDC25A\tCDC25C\tBRCA1\tE2F1\tMDM4
# Name: 315, dtype: object
# kinase_organism                                       ILK_Homo sapiens
# substrates_merged    AKT1\tILK\tPPP1R14A\tPPP1R14B\tPPP1R14C\tNACA\...
# Name: 316, dtype: object
# kinase_organism                                     PRKD1_Homo sapiens
# substrates_merged    PLCG1\tPRKD1\tEPAS1\tHDAC7\tHDAC5\tPPP1R14A\tK...
# Name: 317, dtype: object
# kinase_organism                               ITK_Homo sapiens
# substrates_merged    CD28\tPLCG1\tTEC\tBMX\tBTK\tITK\tSIGLEC10
# Name: 318, dtype: object
# kinase_organism                                 CHK1_Homo sapiens
# substrates_merged    TP73\tTP53\tCDC25A\tCDC25B\tMCM4\tTLK1\tMDM4
# Name: 319, dtype: object
# kinase_organism                                    IKBKB_Homo sapiens
# substrates_merged    IRS1\tNFKBIA\tNFKB1\tIKBKG\tNCOA3\tIKBKB\tNFKBIB
# Name: 320, dtype: object
# kinase_organism                              CaMKIgamma_Homo sapiens
# substrates_merged    FLRT3\tCDKN1C\tCCND2\tDUSP1\tRGS4\tDUSP6\tTNIP1
# Name: 321, dtype: object
# kinase_organism                               CK2_group_Mus musculus
# substrates_merged    Pten\tTnfaip1\tOdc1\tEef1d\tStip1\tAbcf1\tMef2c
# Name: 322, dtype: object
# kinase_organism                        TEC_Homo sapiens
# substrates_merged    FGF2\tTEC\tBMX\tBTK\tGRB10\tPTPN18
# Name: 323, dtype: object
# kinase_organism                           CaMKIdelta_Homo sapiens
# substrates_merged    KCNK2\tNOTCH2\tCDC123\tJAZF1\tCAMK2D\tCAMK1D
# Name: 324, dtype: object
# kinase_organism                       PTK2_Homo sapiens
# substrates_merged    ACTN1\tBMX\tPTK2\tTRIO\tPXN\tBCAR1
# Name: 325, dtype: object
# kinase_organism                          CaMK2a_Mus musculus
# substrates_merged    Myog\tGabrg2\tGabrb1\tPln\tCpeb1\tIl6st
# Name: 326, dtype: object
# kinase_organism                      IKK_group_Homo sapiens
# substrates_merged    IKBKB\tNFKB1\tNFKBIA\tIRS1\tRELA\tIRS2
# Name: 327, dtype: object
# kinase_organism                   CaMK2_group_Mus musculus
# substrates_merged    Vim\tCreb1\tPea15\tWee2\tSirt1\tMecp2
# Name: 328, dtype: object
# kinase_organism                          CAMK1_Homo sapiens
# substrates_merged    ATF1\tNOS1\tSYN1\tCAMK1\tEIF4G3\tHDAC5
# Name: 329, dtype: object
# kinase_organism                           FER_Homo sapiens
# substrates_merged    JUP\tPECAM1\tFER\tCTNNB1\tSTAT3\tCTTN
# Name: 330, dtype: object
# kinase_organism                         MAP2K_group_Homo sapiens
# substrates_merged    MAPK3\tMAPK1\tMAPK9\tMAP2K1\tMAPK14\tMAPK10
# Name: 331, dtype: object
# kinase_organism                               PKG1_Mus musculus
# substrates_merged    Ryr1\tGabrb1\tVasp\tLasp1\tSmtnl1\tPpp1r17
# Name: 332, dtype: object
# kinase_organism                         PKC_theta_Homo sapiens
# substrates_merged    WIPF1\tIRS1\tICAM3\tPRKCQ\tSTK39\tRASGRP3
# Name: 333, dtype: object
# kinase_organism                           VRK1_Homo sapiens
# substrates_merged    BANF1\tTP53\tJUN\tATF2\tCOIL\tHIST1H3J
# Name: 334, dtype: object
# kinase_organism                            AKT2_Mus musculus
# substrates_merged    Clk2\tCreb1\tPde3b\tAcly\tFoxo1\tStxbp4
# Name: 335, dtype: object
# kinase_organism                      GSK-3_beta_Mus musculus
# substrates_merged    Axin1\tNotch2\tCebpb\tMdm2\tCcnd1\tCry2
# Name: 336, dtype: object
# kinase_organism                                 p38a_Mus musculus
# substrates_merged    Atf2\tStat4\tMapkapk2\tDlx5\tSiah2\tMapkapk3
# Name: 337, dtype: object
# kinase_organism                             AURKB_Homo sapiens
# substrates_merged    CENPA\tDES\tINCENP\tRACGAP1\tNSUN2\tSEPT1
# Name: 338, dtype: object
# kinase_organism                         HIPK2_Mus musculus
# substrates_merged    Hmga1\tPdx1\tPax6\tCtnnb1\tRunx1\tPml
# Name: 339, dtype: object
# kinase_organism                             MAPK3_Mus musculus
# substrates_merged    Cebpb\tElk1\tPla2g4a\tPgr\tEts2\tMapkapk2
# Name: 340, dtype: object
# kinase_organism                              CAMK2B_Homo sapiens
# substrates_merged    COL4A3\tGRIN2B\tGRIN2A\tETS1\tPLCB3\tCAMK2B
# Name: 341, dtype: object
# kinase_organism                     CDK_group_Mus musculus
# substrates_merged    Abl1\tLmna\tVim\tStmn1\tCables1\tRrm2
# Name: 342, dtype: object
# kinase_organism                             CHUK_Homo sapiens
# substrates_merged    NFKB1\tRELA\tNCOA3\tIKBKB\tNFKBIB\tPIAS1
# Name: 343, dtype: object
# kinase_organism                          PRKAA1_Homo sapiens
# substrates_merged    GRIK2\tRAF1\tPFKFB2\tACACA\tMTOR\tEEF2K
# Name: 344, dtype: object
# kinase_organism                        SGK1_Mus musculus
# substrates_merged    Map3k3\tNdrg1\tNedd4l\tNdrg2\tFoxo1
# Name: 345, dtype: object
# kinase_organism                  MAPK8_Mus musculus
# substrates_merged    Bcl2l11\tBad\tBcl2\tElk3\tItch
# Name: 346, dtype: object
# kinase_organism            CaM-KII_alpha_Mus musculus
# substrates_merged    Myog\tGabrg2\tGabrb1\tIl6st\tPln
# Name: 347, dtype: object
# kinase_organism                        FGFR1_Homo sapiens
# substrates_merged    FGFR1\tRPS6KA3\tBCAR1\tCTTN\tSYNCRIP
# Name: 348, dtype: object
# kinase_organism                    AKT2_Homo sapiens
# substrates_merged    ESR1\tFOXO4\tXIAP\tCHUK\tAKT1S1
# Name: 349, dtype: object
# kinase_organism              CK1_group_Mus musculus
# substrates_merged    Eif6\tMapt\tDnmt1\tGja1\tFoxo1
# Name: 350, dtype: object
# kinase_organism                     PRKAA2_Homo sapiens
# substrates_merged    PFKFB2\tACACA\tHNF4A\tACACB\tEEF2K
# Name: 351, dtype: object
# kinase_organism                    CaM-KIV_Homo sapiens
# substrates_merged    CREB1\tEP300\tCREBBP\tHDAC4\tHDAC5
# Name: 352, dtype: object
# kinase_organism              PKB/AKT1_Homo sapiens
# substrates_merged    ARK5\tEDG1\tFOXO1\tIKKA\tPTN1
# Name: 353, dtype: object
# kinase_organism                     ATM_Mus musculus
# substrates_merged    Chek1\tTp53\tH2afx\tTtc5\tStk11
# Name: 354, dtype: object
# kinase_organism                    FAK_Homo sapiens
# substrates_merged    WASL\tACTN1\tPXN\tPTK2\tSH3GL1
# Name: 355, dtype: object
# kinase_organism                      PKCd_Homo sapiens
# substrates_merged    PLSCR1\tEGFR\tITGB2\tEIF2S1\tKRT8
# Name: 356, dtype: object
# kinase_organism                         PAK1_Mus musculus
# substrates_merged    Stat5a\tDynll1\tBad\tMapk4\tPpp1r14a
# Name: 357, dtype: object
# kinase_organism                 RPS6KB1_Homo sapiens
# substrates_merged    MAPT\tMTOR\tSTK11\tEIF4B\tEEF2K
# Name: 358, dtype: object
# kinase_organism                IKK_alpha_Homo sapiens
# substrates_merged    NFKB1\tCCND1\tRELA\tNCOR2\tNFKB2
# Name: 359, dtype: object
# kinase_organism                       LCK_Mus musculus
# substrates_merged    Ctla4\tVav1\tPrkcd\tPecam1\tPtk2b
# Name: 360, dtype: object
# kinase_organism               CSNK1E_Homo sapiens
# substrates_merged    APC\tCSNK1E\tBID\tPER2\tPER3
# Name: 361, dtype: object
# kinase_organism               Csk_Homo sapiens
# substrates_merged    FYN\tLYN\tFGR\tSRC\tPTPRC
# Name: 362, dtype: object
# kinase_organism                      JAK2_Mus musculus
# substrates_merged    Ctla4\tStat1\tLepr\tArhgef1\tJak2
# Name: 363, dtype: object
# kinase_organism                       PDK1_Mus musculus
# substrates_merged    Prkaca\tMapt\tRps6ka3\tAkt1\tTssk3
# Name: 364, dtype: object
# kinase_organism                       JAK_Homo sapiens
# substrates_merged    STA5B\tSTAT2\tSTAT3\tSTAT4\tSTAT6
# Name: 365, dtype: object
# kinase_organism               RSK_group_Mus musculus
# substrates_merged    Bad\tCebpb\tStk11\tTnni3\tCreb1
# Name: 366, dtype: object
# kinase_organism                    STK11_Homo sapiens
# substrates_merged    PTEN\tSTK11\tMARK1\tSTRADA\tSNRK
# Name: 367, dtype: object
# kinase_organism                    JNK_group_Homo sapiens
# substrates_merged    NR3C1\tBCL2L11\tELK3\tHSF1\tMAPK8IP1
# Name: 368, dtype: object
# kinase_organism                     EGFR_Mus musculus
# substrates_merged    Pip5k1c\tPcna\tEps15\tEgfr\tGab1
# Name: 369, dtype: object

# %% [markdown]
# ## Write info into a separate GMT file

# %%
#Transfer tab-separated info into a new txt file
with open('Combined.gmt', 'w') as openfile:
    for index in Combined_num:
        openfile.write(str(Combined_num[index]) + '\n')
