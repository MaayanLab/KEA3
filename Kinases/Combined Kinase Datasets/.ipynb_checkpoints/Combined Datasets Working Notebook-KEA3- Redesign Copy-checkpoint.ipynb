# %% [markdown]
# # Combined .GMT File
# This notebook contains code that will concatenate all of the .gmt files created for seven databases (RegPhos, NetworKIN, Swiss-Prot, PhosphoELM, PhosphoSite, HPRD, and MINT) into a single .gmt file. It will also show a distribution for the number of targets per kinase for this combined file. For the reference column of this file, citations to the paper corresponding to the database will be provided in cases during which the data does not have a pubmed id number. Otherwise, the PubMed id will be displayed.

# %% [markdown]
# ## Import and Run Necessary Files

# %%
# %run /home/maayanlab/Desktop/Projects/KEA3/Scripts/init.ipy

# %% [markdown]
# ## Retrieving and Downloading all .GMT files

# %%
HPRD = pd.read_table("~/Desktop/Projects/KEA3/HPRD/Uncondensed_HPRD.txt", header = None)

NetworKIN = pd.read_table("~/Desktop/Projects/KEA3/NetworKIN/Uncondensed_NetworKIN.txt", header = None)

PhosphoELM = pd.read_table("~/Desktop/Projects/KEA3/PhosphoELM/Uncondensed_PhosphoELM.txt", header = None)

PhosphoSite = pd.read_table("~/Desktop/Projects/KEA3/PhosphoSite/Uncondensed_PhosphoSite.txt", header = None)

RP_Hum = pd.read_table("~/Desktop/Projects/KEA3/RegPhos/Uncondensed_RegPhos_human.txt", header = None)

RP_Mouse = pd.read_table("~/Desktop/Projects/KEA3/RegPhos/Uncondensed_RegPhos_mouse.txt", header = None)

# %%
HPRD.insert(3, 3, 'HPRD')

NetworKIN.insert(3, 3, 'NetworKIN')

PhosphoELM.insert(3, 3, 'Phospho.ELM')

RP_Hum.insert(3, 3, 'RegPhos')

RP_Mouse.insert(3, 3, 'RegPhos')

# %% [markdown]
# ## Concatenate all GMT Dataframes into a Single Dataframe
# Also removes any duplicates or NAs that may be present in the newly created dataframe.

# %%
#Create a list of all of the dataframe
c = [HPRD, NetworKIN, PhosphoELM, PhosphoELM, RP_Hum, RP_Mouse]

#Concatenate all of the rows in the dataframes
combined = pd.concat(c)

#Assign column names
combined.columns = ['kinase_organism', 'substrate', 'pubmed_id', 'resource_name']

#Drop any duplicate rows in the dataframe
combined.drop_duplicates(inplace = True)

combined.dropna(inplace = True)

# %%
#View dataframe of combined kinase-substrate interactions
combined
# Out:
#                 kinase_organism substrate  \
# 0             PTK2_Homo sapiens     ACTN1
# 1            FGFR3_Homo sapiens     STAT3
# 2            FGFR4_Homo sapiens     STAT3
# 3              HCK_Homo sapiens     STAT3
# 4             JAK1_Homo sapiens     STAT3
# 5             JAK2_Homo sapiens     STAT3
# 6            MAPK1_Homo sapiens     STAT3
# 7            PRKCD_Homo sapiens     STAT3
# 8              SRC_Homo sapiens     STAT3
# 9            MAPK8_Homo sapiens     STAT3
# 10           MAPK3_Homo sapiens     STAT3
# 11         RPS6KA5_Homo sapiens     STAT3
# 12           EPHA3_Homo sapiens     STAT3
# 13           PRKCD_Homo sapiens      ADD1
# 14          PRKACA_Homo sapiens      ADD1
# 15           ROCK1_Homo sapiens      ADD1
# 16           PRKCD_Homo sapiens      ADD2
# 17          PRKACA_Homo sapiens      ADD2
# 18          ADRBK1_Homo sapiens    ADRA2A
# 19           PRKCD_Homo sapiens    ADRA2A
# 20           PRKCA_Homo sapiens    ADRA1B
# 21            CDK5_Homo sapiens     PSEN1
# 22           PRKCZ_Homo sapiens     PSEN1
# 23          PRKACA_Homo sapiens     PSEN1
# 24           GSK3B_Homo sapiens     PSEN1
# 25            CDK5_Homo sapiens       APP
# 26           GSK3B_Homo sapiens       APP
# 27           BACE2_Homo sapiens       APP
# 28            CDK1_Homo sapiens     APLP2
# 29           PRKCA_Homo sapiens     APLP2
# ..                          ...       ...
# 718         MAP2K7_Mus musculus     Mapk9
# 719         MAP2K4_Mus musculus     Mapk9
# 720           CDC2_Mus musculus    Incenp
# 721           CDK2_Mus musculus    Mcm3ap
# 722           AKT1_Mus musculus     Gsk3b
# 723           RSK2_Mus musculus     Gsk3b
# 724           SGK3_Mus musculus     Gsk3b
# 725          PKACa_Mus musculus     Gsk3b
# 726           AKT2_Mus musculus    Stxbp4
# 727            SRC_Mus musculus      Cav2
# 728      PKB_group_Mus musculus     Foxo4
# 729          PKACa_Mus musculus     Kcnd2
# 730           IKKb_Mus musculus    Nfkbia
# 731           IKKe_Mus musculus    Nfkbia
# 732          CK2a1_Mus musculus    Nfkbia
# 733     AMPK_group_Mus musculus      Gys1
# 734      SRC_group_Mus musculus      Gab2
# 735          STLK3_Mus musculus     Stk39
# 736            SRC_Mus musculus     Trip6
# 737      PKA_group_Mus musculus    Snapin
# 738           PKCt_Mus musculus     Pdpk1
# 739    CaMK2_group_Mus musculus     Mecp2
# 740           PKG1_Mus musculus   Ppp1r17
# 741  autocatalysis_Mus musculus   Eif2ak1
# 742    CaMK1_group_Mus musculus     Hdac5
# 743      PKD_group_Mus musculus     Hdac5
# 744           PKD1_Mus musculus     Hdac5
# 745     AMPK_group_Mus musculus     Hdac5
# 746  autocatalysis_Mus musculus     Stk25
# 747      PKA_group_Mus musculus     Itpr2
#
#                                              pubmed_id resource_name
# 0                                    11369769,16291744          HPRD
# 1    11940572,11294897,10918587,12244095,11350938,1...          HPRD
# 2    11940572,11294897,10918587,12244095,11350938,1...          HPRD
# 3    11940572,11294897,10918587,12244095,11350938,1...          HPRD
# 4    11940572,11294897,10918587,12244095,11350938,1...          HPRD
# 5    11940572,11294897,10918587,12244095,11350938,1...          HPRD
# 6    11350938,10521505,9343414,10446219,12576423,14...          HPRD
# 7    11350938,10521505,9343414,10446219,12576423,14...          HPRD
# 8    11940572,11294897,10918587,12244095,11350938,1...          HPRD
# 9    11350938,10521505,9343414,10446219,12576423,14...          HPRD
# 10   11350938,10521505,9343414,10446219,12576423,14...          HPRD
# 11   11350938,10521505,9343414,10446219,12576423,14...          HPRD
# 12   11940572,11294897,10918587,12244095,11350938,1...          HPRD
# 13                                     8810272,9679146          HPRD
# 14                            8810272,8810272,18669648          HPRD
# 15                                            10209029          HPRD
# 16   9679146,8810272,19664994,18452278,9679146,8810272          HPRD
# 17   9679146,8810272,19664994,18452278,9679146,8810272          HPRD
# 18                            7876239,7876239,19651622          HPRD
# 19                                            11732925          HPRD
# 20                                             9353340          HPRD
# 21                                            12056836          HPRD
# 22                                            14576165          HPRD
# 23                                            14576165          HPRD
# 24                                            11104755          HPRD
# 25                           8764598,10936190,15178331          HPRD
# 26                           8764598,10936190,15178331          HPRD
# 27                           8764598,10936190,15178331          HPRD
# 28                                             9109675          HPRD
# 29                                             9109675          HPRD
# ..                                                 ...           ...
# 718                                           18034455       RegPhos
# 719                                  17242355,18034455       RegPhos
# 720                                           16378098       RegPhos
# 721                                           11526238       RegPhos
# 722                                           22057101       RegPhos
# 723                                           22057101       RegPhos
# 724                                           22057101       RegPhos
# 725       17052453,17141160,16522636,15845746,11035810       RegPhos
# 726                                           15753124       RegPhos
# 727                                           12091389       RegPhos
# 728                                           14690436       RegPhos
# 729                         10681507,20045463,10681507       RegPhos
# 730                           9859996,9990853,10097128       RegPhos
# 731                                           10421793       RegPhos
# 732                                            8668171       RegPhos
# 733                                           15561936       RegPhos
# 734                                   12819203,9885561       RegPhos
# 735                                           16382158       RegPhos
# 736                                           15988003       RegPhos
# 737                                           11283605       RegPhos
# 738                                           19047061       RegPhos
# 739                                           17046689       RegPhos
# 740                                            9920894       RegPhos
# 741                                           12767237       RegPhos
# 742                                  17468767,21454484       RegPhos
# 743                                  17468767,21454484       RegPhos
# 744                                  17468767,21454484       RegPhos
# 745                                  17468767,21454484       RegPhos
# 746                                  19131326,19367708       RegPhos
# 747                                           19608738       RegPhos
#
# [109336 rows x 4 columns]

# %% [markdown]
# ## Set Index by 'kinase_organism' Column and Group Proteins by Kinase
# Also, creating a copy of 'combined' to be used later in also creating a combined .SIG file

# %%
#Create a dataframe copy of 'combined' known as 'df'
df = combined.copy()

combined.drop("pubmed_id", axis = 1, inplace = True)

combined.drop_duplicates(inplace = True)

#Set index of the dataframe as 'kinase_organism'
combined.set_index('kinase_organism', inplace = True)

#Combine rows according to same index 'kinase_organism'
kin = combined.groupby('kinase_organism').agg(lambda x: tuple(x))

# %%
#Confirm that 'df' is a copy of 'combined' and is unchanged by setting the index
df.head()
# Out:
#       kinase_organism substrate  \
# 0   PTK2_Homo sapiens     ACTN1
# 1  FGFR3_Homo sapiens     STAT3
# 2  FGFR4_Homo sapiens     STAT3
# 3    HCK_Homo sapiens     STAT3
# 4   JAK1_Homo sapiens     STAT3
#
#                                            pubmed_id resource_name
# 0                                  11369769,16291744          HPRD
# 1  11940572,11294897,10918587,12244095,11350938,1...          HPRD
# 2  11940572,11294897,10918587,12244095,11350938,1...          HPRD
# 3  11940572,11294897,10918587,12244095,11350938,1...          HPRD
# 4  11940572,11294897,10918587,12244095,11350938,1...          HPRD

# %%
#View new dataframe
kin
# Out:
#                                                                       substrate  \
# kinase_organism
# AAK1_Homo sapiens                      (NUMB, AP1M1, AP2M1, NUMB, AP2M1, AP1M1)
# ABL1_Homo sapiens             (CD19, CDK5, JAK2, MAPT, CRK, MDM2, JUN, PTPN6...
# ABL1_Mus musculus             (Abl1, Pdgfrb, Myod1, App, Cbl, Cdk5, Cav1, Do...
# ABL2_Homo sapiens                                              (CAT, CRK, GPX1)
# ABL2_Mus musculus                                            (Pdgfrb, Arhgap35)
# ABL_Homo sapiens                                        (PLSCR1, CDKN1B, ROBO1)
# ABL_Mus musculus                                                        (Cdv3,)
# ACK_Homo sapiens                                                        (WASL,)
# ACK_Mus musculus                                                   (Akt1, Wasl)
# ACTR2B_Homo sapiens           (PPARA, RELA, AHSG, SNIP1, TJP1, NEDD4L, SOX9,...
# ACTR2_Homo sapiens            (LCK, FYN, PEX1, NEDD4L, AHSG, EP300, RND3, SL...
# ACVR1B_Homo sapiens                                                    (SMAD2,)
# ACVR1_Homo sapiens                                                     (SMAD1,)
# ADRBK1_Homo sapiens           (ADRA2A, BDKRB2, FPR1, MC4R, SNCA, OPRD1, RPLP...
# ADRBK2_Homo sapiens                                       (BDKRB2, OPRM1, CCR5)
# AKT1_Homo sapiens             (BRCA1, CDKN1A, CREB1, ESR1, FOXO1, GATA2, NR4...
# AKT1_Mus musculus             (Chek1, Cdkn1b, Creb1, Gsk3a, Tbc1d1, Pde3b, T...
# AKT2_Homo sapiens             (ESR1, FOXO4, XIAP, CHUK, AKT1S1, CHUK, ESR1, ...
# AKT2_Mus musculus                     (Clk2, Creb1, Pde3b, Acly, Foxo1, Stxbp4)
# ALK4_Homo sapiens                                                       (TDP2,)
# ALK_Homo sapiens                  (ALK, STAT3, ALK, ZC3HC1, STAT3, ZC3HC1, ALK)
# AMPK_group_Homo sapiens       (IRS1, KPNA2, EP300, EEF2K, PFKFB2, HNF4A, PRK...
# AMPK_group_Mus musculus       (Irs1, Mtor, Ppargc1a, Ulk1, Tp53, Hist1h2bn, ...
# AMPKa1_Homo sapiens           (PPARA, STRADA, FASN, MLXIPL, GRIK2, PROX1, TN...
# AMPKa2_Homo sapiens           (RIPK2, SIK2, APPL1, NOS1, TRIP6, NOS2, PARP1,...
# ARAF_Homo sapiens             (MAP2K1, PIK3C2A, SRC, MPP1, LNPEP, FOS, MAPK1...
# ARG_Homo sapiens                                            (PSMA7, SIVA1, CAT)
# ATM_Homo sapiens              (BRCA1, CREB1, MDM2, E2F1, ABL1, TP53, FANCD2,...
# ATM_Mus musculus                       (H2afx, Chek1, Tp53, H2afx, Ttc5, Stk11)
# ATR_Homo sapiens              (BRCA1, E2F1, TP53, XPA, CHEK1, CHEK2, RAD17, ...
# ...                                                                         ...
# Wnk1_Homo sapiens                                                      (OXSR1,)
# Wnk1_Mus musculus                                                (Syt2, Nedd4l)
# Wnk4_Mus musculus                                                     (Nedd4l,)
# YES1_Homo sapiens                                          (CD46, YES1, CDKN1B)
# YES_Mus musculus                                                        (Yes1,)
# YSK1_Homo sapiens             (STK11, MBP, MAP2K3, STK4, MOBKL1A, PRPF31, SL...
# Yes_Homo sapiens              (GMFB, PAFAH1B1, GMFG, DDX55, NTHL1, GMPR, HPS...
# Yes_Mus musculus                                                        (Yes1,)
# ZAP70_Homo sapiens            (MUC1, ZAP70, DUSP3, SHC1, LCP2, LAT, SH2B3, G...
# ZAP70_Mus musculus                                                   (Lat, Lat)
# ZRANB2_Homo sapiens                                            (ZRANB2, ZRANB2)
# autocatalysis_Homo sapiens    (PIK3CD, STK25, CASK, PDPK1, DAPK3, MAP3K7, RI...
# autocatalysis_Mus musculus    (Epha8, Map3k5, Clk2, Nlk, Abl1, Prkaca, Lck, ...
# caMLCK_Mus musculus                                                     (Myl9,)
# host_Mus musculus                                                      (Nedd4,)
# inisoform HMG-I_Mus musculus                                           (Hmga1,)
# isoform HMG-Y_Mus musculus                                             (Hmga1,)
# mTOR_Homo sapiens                            (RPS6KB1, MTOR, EIF4EBP1, RPS6KB2)
# mTOR_Mus musculus                                                       (Akt1,)
# p38_group_Homo sapiens                       (DDIT3, PPARGC1A, DDIT3, PPARGC1A)
# p38a_Mus musculus                (Atf2, Stat4, Mapkapk2, Dlx5, Siah2, Mapkapk3)
# p38b_Mus musculus                                 (Mapkapk5, Prkce, Atf2, Atf7)
# p38d_Mus musculus                                                      (Prkd1,)
# p38g_Mus musculus                                                       (Atf2,)
# p70S6K_Homo sapiens           (PPP2R5C, BAD, PRKAA2, CSNK2A1, LYN, CCND1, AK...
# p70S6K_Mus musculus                                                      (Bad,)
# p70S6K_group_Homo sapiens                            (RPS6, EEF2K, EEF2K, RPS6)
# p70S6K_group_Mus musculus                                          (Lmna, Lmna)
# p70S6Kb_Homo sapiens          (RPTOR, LYN, TSC2, BRCA1, AKT2, SYK, PDK1, BTK...
# smMLCK_Homo sapiens                                                   (MYL12B,)
#
#                                                                   resource_name
# kinase_organism
# AAK1_Homo sapiens             (Phospho.ELM, Phospho.ELM, Phospho.ELM, RegPho...
# ABL1_Homo sapiens             (HPRD, HPRD, HPRD, HPRD, HPRD, HPRD, HPRD, HPR...
# ABL1_Mus musculus             (RegPhos, RegPhos, RegPhos, RegPhos, RegPhos, ...
# ABL2_Homo sapiens                                            (HPRD, HPRD, HPRD)
# ABL2_Mus musculus                                            (RegPhos, RegPhos)
# ABL_Homo sapiens                                    (RegPhos, RegPhos, RegPhos)
# ABL_Mus musculus                                                     (RegPhos,)
# ACK_Homo sapiens                                                     (RegPhos,)
# ACK_Mus musculus                                             (RegPhos, RegPhos)
# ACTR2B_Homo sapiens           (NetworKIN, NetworKIN, NetworKIN, NetworKIN, N...
# ACTR2_Homo sapiens            (NetworKIN, NetworKIN, NetworKIN, NetworKIN, N...
# ACVR1B_Homo sapiens                                                     (HPRD,)
# ACVR1_Homo sapiens                                                      (HPRD,)
# ADRBK1_Homo sapiens           (HPRD, HPRD, HPRD, HPRD, HPRD, HPRD, HPRD, HPR...
# ADRBK2_Homo sapiens                                          (HPRD, HPRD, HPRD)
# AKT1_Homo sapiens             (HPRD, HPRD, HPRD, HPRD, HPRD, HPRD, HPRD, HPR...
# AKT1_Mus musculus             (RegPhos, RegPhos, RegPhos, RegPhos, RegPhos, ...
# AKT2_Homo sapiens             (HPRD, HPRD, HPRD, HPRD, HPRD, RegPhos, RegPho...
# AKT2_Mus musculus             (RegPhos, RegPhos, RegPhos, RegPhos, RegPhos, ...
# ALK4_Homo sapiens                                                    (RegPhos,)
# ALK_Homo sapiens              (HPRD, Phospho.ELM, Phospho.ELM, Phospho.ELM, ...
# AMPK_group_Homo sapiens       (Phospho.ELM, Phospho.ELM, Phospho.ELM, Phosph...
# AMPK_group_Mus musculus       (Phospho.ELM, Phospho.ELM, RegPhos, RegPhos, R...
# AMPKa1_Homo sapiens           (NetworKIN, NetworKIN, NetworKIN, NetworKIN, N...
# AMPKa2_Homo sapiens           (NetworKIN, NetworKIN, NetworKIN, NetworKIN, N...
# ARAF_Homo sapiens             (HPRD, NetworKIN, NetworKIN, NetworKIN, Networ...
# ARG_Homo sapiens                                    (RegPhos, RegPhos, RegPhos)
# ATM_Homo sapiens              (HPRD, HPRD, HPRD, HPRD, HPRD, HPRD, HPRD, HPR...
# ATM_Mus musculus              (Phospho.ELM, RegPhos, RegPhos, RegPhos, RegPh...
# ATR_Homo sapiens              (HPRD, HPRD, HPRD, HPRD, HPRD, HPRD, HPRD, HPR...
# ...                                                                         ...
# Wnk1_Homo sapiens                                                    (RegPhos,)
# Wnk1_Mus musculus                                            (RegPhos, RegPhos)
# Wnk4_Mus musculus                                                    (RegPhos,)
# YES1_Homo sapiens                                            (HPRD, HPRD, HPRD)
# YES_Mus musculus                                                     (RegPhos,)
# YSK1_Homo sapiens             (NetworKIN, NetworKIN, NetworKIN, NetworKIN, N...
# Yes_Homo sapiens              (NetworKIN, NetworKIN, NetworKIN, NetworKIN, N...
# Yes_Mus musculus                                                 (Phospho.ELM,)
# ZAP70_Homo sapiens            (HPRD, HPRD, HPRD, HPRD, HPRD, HPRD, HPRD, HPR...
# ZAP70_Mus musculus                                       (Phospho.ELM, RegPhos)
# ZRANB2_Homo sapiens                                             (HPRD, RegPhos)
# autocatalysis_Homo sapiens    (RegPhos, RegPhos, RegPhos, RegPhos, RegPhos, ...
# autocatalysis_Mus musculus    (RegPhos, RegPhos, RegPhos, RegPhos, RegPhos, ...
# caMLCK_Mus musculus                                                  (RegPhos,)
# host_Mus musculus                                                    (RegPhos,)
# inisoform HMG-I_Mus musculus                                         (RegPhos,)
# isoform HMG-Y_Mus musculus                                           (RegPhos,)
# mTOR_Homo sapiens             (Phospho.ELM, Phospho.ELM, Phospho.ELM, Phosph...
# mTOR_Mus musculus                                                (Phospho.ELM,)
# p38_group_Homo sapiens             (Phospho.ELM, Phospho.ELM, RegPhos, RegPhos)
# p38a_Mus musculus             (RegPhos, RegPhos, RegPhos, RegPhos, RegPhos, ...
# p38b_Mus musculus                          (RegPhos, RegPhos, RegPhos, RegPhos)
# p38d_Mus musculus                                                    (RegPhos,)
# p38g_Mus musculus                                                    (RegPhos,)
# p70S6K_Homo sapiens           (NetworKIN, NetworKIN, NetworKIN, NetworKIN, N...
# p70S6K_Mus musculus                                                  (RegPhos,)
# p70S6K_group_Homo sapiens          (Phospho.ELM, Phospho.ELM, RegPhos, RegPhos)
# p70S6K_group_Mus musculus                                (Phospho.ELM, RegPhos)
# p70S6Kb_Homo sapiens          (NetworKIN, NetworKIN, NetworKIN, NetworKIN, N...
# smMLCK_Homo sapiens                                                  (RegPhos,)
#
# [884 rows x 2 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Calculate Number of Protein Targets for each Kinase and Sort in Descending Order

# %%
# Create column representing counts of protein targets per kinase
kin['kinase_substrate_num'] = [len(lst) for kinase, lst in kin['substrate'].iteritems()]

# Sort kinases from max to min according to number of protein targets each has
kin.sort_values(by = ['kinase_substrate_num'], ascending= False, inplace=True)

# View dataframe
kin.head()
# Out:
#                                                           substrate  \
# kinase_organism
# HCK_Homo sapiens  (STAT3, CSF3R, HCK, BCR, CBL, PLCG1, WAS, PLCG...
# Lck_Homo sapiens  (GMFG, GMFB, PAFAH1B1, DDX55, NTHL1, HPSE, GMP...
# BTK_Homo sapiens  (CD19, BMX, BTK, WAS, PLCG2, STAT5A, GTF2I, DA...
# Lyn_Homo sapiens  (GMFB, GMFG, PAFAH1B1, DDX55, NTHL1, GMPR, HPS...
# Fyn_Homo sapiens  (GMFB, GMFG, PAFAH1B1, DDX55, NTHL1, GMPR, HPS...
#
#                                                       resource_name  \
# kinase_organism
# HCK_Homo sapiens  (HPRD, HPRD, HPRD, HPRD, HPRD, HPRD, HPRD, HPR...
# Lck_Homo sapiens  (NetworKIN, NetworKIN, NetworKIN, NetworKIN, N...
# BTK_Homo sapiens  (HPRD, HPRD, HPRD, HPRD, HPRD, HPRD, HPRD, HPR...
# Lyn_Homo sapiens  (NetworKIN, NetworKIN, NetworKIN, NetworKIN, N...
# Fyn_Homo sapiens  (NetworKIN, NetworKIN, NetworKIN, NetworKIN, N...
#
#                   kinase_substrate_num
# kinase_organism
# HCK_Homo sapiens                  3626
# Lck_Homo sapiens                  3618
# BTK_Homo sapiens                  3617
# Lyn_Homo sapiens                  3615
# Fyn_Homo sapiens                  3614

# %% [markdown]
# ## Display a Histogram Showing the Distribution of the Number of Kinase Targets

# %%
# Create histogram displaying the distribution of the number
#targets per kinase
kin.plot.hist(by = 'kinase_substrate_num', bins = 100)

#Show histogram
plt.show()

# %% [markdown]
# ## Filter Kinases by the Number of Kinase Targets They Have
# If they have fewer than five or more than 2000, they will be filtered out of the dataframe.

# %%
#Create list of indexes(kinase names) for kinases with fewer than five substrates
sig_key = [index for index, rowData in kin.kinase_substrate_num.iteritems() if rowData < 5 or rowData > 2000]

#Set indices for dataframe 'kin' of kinases with five or more substrates
#indices will also filter out kinases with more than 2000 substrates
indices = [index for index in kin.index if index not in sig_key]

#Create dataframe of all kinases
sig = df.set_index('kinase_organism')

sig.reset_index(inplace = True)

#Rename columns of this dataframe to match .sig format
colnames = ['Source', 'Substrate', 'PubMed_ID', 'Resource']
sig.columns = colnames

# %%
#Remove kinases with fewer than five substrates or 
#more than 2000 substrates in 'kin'
kin = kin.loc[indices]

# %%
stat_df = df.set_index('kinase_organism').loc[indices]

df.reset_index(inplace = True)

df.head()
# Out:
#    index     kinase_organism substrate  \
# 0      0   PTK2_Homo sapiens     ACTN1
# 1      1  FGFR3_Homo sapiens     STAT3
# 2      2  FGFR4_Homo sapiens     STAT3
# 3      3    HCK_Homo sapiens     STAT3
# 4      4   JAK1_Homo sapiens     STAT3
#
#                                            pubmed_id
# 0                                  11369769,16291744
# 1  11940572,11294897,10918587,12244095,11350938,1...
# 2  11940572,11294897,10918587,12244095,11350938,1...
# 3  11940572,11294897,10918587,12244095,11350938,1...
# 4  11940572,11294897,10918587,12244095,11350938,1...

# %%
kin.head()
# Out:
#                                                                substrate  \
# kinase_organism
# FRK_Homo sapiens       (DNAJC1, PTPRN, DLX2, B3GALT4, OXR1, SYNGR2, M...
# PKCzeta_Homo sapiens   (F2R, CRKL, SORBS1, TSC1, DNM1, RPTN, PGM2L1, ...
# MAPK1_Homo sapiens     (STAT3, CD19, SLC9A1, ARRB1, GJA1, ESR1, NR3C1...
# PKAalpha_Homo sapiens  (SFN, DCP1A, RBM10, MAP3K8, ELF3, POLR2A, BCL2...
# CDK1_Homo sapiens      (APLP2, CALD1, CSNK2A1, CSNK2B, CUX1, CDK1, CD...
#
#                        kinase_substrate_num
# kinase_organism
# FRK_Homo sapiens                       1739
# PKCzeta_Homo sapiens                   1721
# MAPK1_Homo sapiens                     1584
# PKAalpha_Homo sapiens                  1228
# CDK1_Homo sapiens                      1131

# %%
genes_term = kin.kinase_substrate_num

len(genes_term)
# Out:
# 347

# %%
sum(genes_term)
# Out:
# 31831

# %%
avg_num_terms = genes_term.mean(axis = 0)
avg_num_terms
# Out:
# 91.73198847262248

# %%
#For inclusion on website as a statistic, calculate 
#the number of unique genes represented in the subset of the
#sig of kinases with 5 or more genes
stat_df.drop('pubmed_id', axis = 1, inplace = True)

stat_df.drop_duplicates(inplace = True)

len(stat_df.substrate.unique())
# Out:
# 5700

# %%
#For inclusion on website as a statistic, calculate 
#the total number of unique terms for the dataset

kinases = pd.Series([index.split('_', 2)[0] for index in kin.index])

stat_df.reset_index(inplace = True)

all_terms = pd.concat([kinases, stat_df.substrate], axis = 0)
len(all_terms.unique())
# Out:
# 5850

# %% [markdown]
# ## Create .SIG File by Formatting 'df' to sig file format

# %%
sig.head()
# Out:
#                Source Substrate  \
# 0   PTK2_Homo sapiens     ACTN1
# 1  FGFR3_Homo sapiens     STAT3
# 2  FGFR4_Homo sapiens     STAT3
# 3    HCK_Homo sapiens     STAT3
# 4   JAK1_Homo sapiens     STAT3
#
#                                            PubMed_ID Resource
# 0                                  11369769,16291744     HPRD
# 1  11940572,11294897,10918587,12244095,11350938,1...     HPRD
# 2  11940572,11294897,10918587,12244095,11350938,1...     HPRD
# 3  11940572,11294897,10918587,12244095,11350938,1...     HPRD
# 4  11940572,11294897,10918587,12244095,11350938,1...     HPRD

# %%
lst = []
for index in sig.index:
    lst.append(tuple(sorted(tuple((sig.ix[index,'Source'], sig.ix[index, 'Substrate'])))))
sig['interactions'] = lst

sig['PubMed_ID'] = sig['PubMed_ID'].astype(str)

for i,interact in enumerate(sig['interactions'].unique()):
    ref = (',').join(sig.ix[sig[sig['interactions'] == interact].index, 'PubMed_ID'])
    sig.ix[sig[sig['interactions'] == interact].index[0], 'PubMed_ID'] = ref
    sig.drop(sig[sig['interactions'] == interact].index[1:], inplace=True)
    
sig.drop('interactions', axis = 1, inplace = True)
sig.head()
# Out:
# /home/maayanlab/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Insert first four columns for .sig file format (NaNs)
sig.insert(1, 'NA-1', str(np.nan))
sig.insert(2, 'NA-2', str(np.nan))
sig.insert(3, 'NA-3', str(np.nan))
sig.insert(4, 'NA-4', str(np.nan))

#Insert next four columns for .sig file format (NaNs)
sig.insert(6, 'NA-5', str(np.nan))
sig.insert(7, 'NA-6', str(np.nan))
sig.insert(8, 'NA-7', str(np.nan))
sig.insert(9, 'NA-8', str(np.nan))

#Insert column corresponding to sign (with '?' because it is unknown)
sig.insert(10, 'Sign', '?')

#Insert column specifying interaction type as phosphorylation
sig.insert(11, 'Interaction', 'Phosphorylation')

#View dataframe
sig.head()
# Out:
#                Source NA-1 NA-2 NA-3 NA-4 Substrate NA-5 NA-6 NA-7 NA-8 Sign  \
# 0   PTK2_Homo sapiens  nan  nan  nan  nan     ACTN1  nan  nan  nan  nan    ?
# 1  FGFR3_Homo sapiens  nan  nan  nan  nan     STAT3  nan  nan  nan  nan    ?
# 2  FGFR4_Homo sapiens  nan  nan  nan  nan     STAT3  nan  nan  nan  nan    ?
# 3    HCK_Homo sapiens  nan  nan  nan  nan     STAT3  nan  nan  nan  nan    ?
# 4   JAK1_Homo sapiens  nan  nan  nan  nan     STAT3  nan  nan  nan  nan    ?
#
#        Interaction                                          PubMed_ID
# 0  Phosphorylation                                  11369769,16291744
# 1  Phosphorylation  11940572,11294897,10918587,12244095,11350938,1...
# 2  Phosphorylation  11940572,11294897,10918587,12244095,11350938,1...
# 3  Phosphorylation  11940572,11294897,10918587,12244095,11350938,1...
# 4  Phosphorylation  11940572,11294897,10918587,12244095,11350938,1...

# %%
#Create dictionary 'sigd' with index numbers as keys
sigd = dict([(key, '') for key in sig.index])

# loop through rows with iterrows()
for index, rowData in sig.iterrows():
    line = ('\t'.join(rowData))
    sigd[index] = line
    
#Transfer tab-separated info into a new txt file
#Make sure to include in ReadMe corresponding column names
with open('Combined_Resource.sig', 'w') as openfile:
    for index in sigd:
        openfile.write(sigd[index] + '\n')

# %% [markdown]
# # Create Combined .GMT File

# %% [markdown]
# ## Create Dictionary of Row Data to be Included in the Final .GMT

# %%
#Reset index of the dataframe
kin.reset_index(inplace = True)

#create column 'acc_merged' in which all 'acc' elements are joined by a \t symbol
kin['substrates_merged'] = ['\t'.join(x) for x in kin['substrate']]

#drop the now-unneccesary column 'Substrates'
kin.drop('substrate', axis=1, inplace = True)

# %%
kin.head()
# Out:
#          kinase_organism  kinase_substrate_num  \
# 0       FRK_Homo sapiens                  1739
# 1   PKCzeta_Homo sapiens                  1721
# 2     MAPK1_Homo sapiens                  1584
# 3  PKAalpha_Homo sapiens                  1228
# 4      CDK1_Homo sapiens                  1131
#
#                                    substrates_merged
# 0  DNAJC1\tPTPRN\tDLX2\tB3GALT4\tOXR1\tSYNGR2\tMY...
# 1  F2R\tCRKL\tSORBS1\tTSC1\tDNM1\tRPTN\tPGM2L1\tS...
# 2  STAT3\tCD19\tSLC9A1\tARRB1\tGJA1\tESR1\tNR3C1\...
# 3  SFN\tDCP1A\tRBM10\tMAP3K8\tELF3\tPOLR2A\tBCL2\...
# 4  APLP2\tCALD1\tCSNK2A1\tCSNK2B\tCUX1\tCDK1\tCDC...

# %% [markdown]
# ## Gain Data Regarding Only Human and Mouse Samples
# Do so before dropping the column related to the number of genes per kinase

# %%
human_indices = []

#select indices only pertaining to kinases of humans
for index, rowData in kin.kinase_organism.iteritems():
    if '_' in rowData:
        count = rowData.count('_')
        lst = rowData.split('_', count)
        if 'Homo sapiens' in lst:
            human_indices = human_indices + [index]
            
human = kin.loc[human_indices]

human.drop_duplicates(inplace = True)

# %%
human.head()
# Out:
#          kinase_organism  kinase_substrate_num  \
# 0       FRK_Homo sapiens                  1739
# 1   PKCzeta_Homo sapiens                  1721
# 2     MAPK1_Homo sapiens                  1584
# 3  PKAalpha_Homo sapiens                  1228
# 4      CDK1_Homo sapiens                  1131
#
#                                    substrates_merged
# 0  DNAJC1\tPTPRN\tDLX2\tB3GALT4\tOXR1\tSYNGR2\tMY...
# 1  F2R\tCRKL\tSORBS1\tTSC1\tDNM1\tRPTN\tPGM2L1\tS...
# 2  STAT3\tCD19\tSLC9A1\tARRB1\tGJA1\tESR1\tNR3C1\...
# 3  SFN\tDCP1A\tRBM10\tMAP3K8\tELF3\tPOLR2A\tBCL2\...
# 4  APLP2\tCALD1\tCSNK2A1\tCSNK2B\tCUX1\tCDK1\tCDC...

# %%
avg_num_terms = human.kinase_substrate_num.mean(axis = 0)
avg_num_terms
# Out:
# 106.61092150170649

# %%
#For inclusion on website as a statistic, calculate 
#the number of unique genes represented in the subset of the
#sig of kinases with 5 or more genes
df_human_indices = []

#select indices only pertaining to kinases of humans
for index, rowData in df.kinase_organism.iteritems():
    if '_' in rowData:
        count = rowData.count('_')
        lst = rowData.split('_', count)
        if 'Homo sapiens' in lst:
            df_human_indices = df_human_indices + [index]

stat_df = df.loc[df_human_indices]

# %%
stat_df.head()
# Out:
#    index     kinase_organism substrate  \
# 0      0   PTK2_Homo sapiens     ACTN1
# 1      1  FGFR3_Homo sapiens     STAT3
# 2      2  FGFR4_Homo sapiens     STAT3
# 3      3    HCK_Homo sapiens     STAT3
# 4      4   JAK1_Homo sapiens     STAT3
#
#                                            pubmed_id
# 0                                  11369769,16291744
# 1  11940572,11294897,10918587,12244095,11350938,1...
# 2  11940572,11294897,10918587,12244095,11350938,1...
# 3  11940572,11294897,10918587,12244095,11350938,1...
# 4  11940572,11294897,10918587,12244095,11350938,1...

# %%
#For inclusion on website as a statistic, calculate 
#the number of unique genes represented in the subset of the
#sig of kinases with 5 or more genes
stat_df.drop('pubmed_id', axis = 1, inplace = True)

stat_df.drop_duplicates(inplace = True)

len(stat_df.substrate.unique())
# Out:
# 6828

# %%
mouse_indices = []

#select indices only pertaining to kinases of mice
for index, rowData in kin.kinase_organism.iteritems():
    if 'Mus musculus' in rowData.split('_', 2)[1]:
        mouse_indices = mouse_indices + [index]
    if '_' in rowData:
        count = rowData.count('_')
        lst = rowData.split('_', count)
        if 'Mus musculus' in lst:
            mouse_indices = mouse_indices + [index]

mouse = kin.loc[mouse_indices]

mouse.drop_duplicates(inplace = True)
# Out:
# /home/maayanlab/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
avg_num_terms = mouse.kinase_substrate_num.mean(axis = 0)
avg_num_terms
# Out:
# 11.0

# %%
#For inclusion on website as a statistic, calculate 
#the number of unique genes represented in the subset of the
#sig of kinases with 5 or more genes
#For inclusion on website as a statistic, calculate 
#the number of unique genes represented in the subset of the
#sig of kinases with 5 or more genes
df_mouse_indices = []

#select indices only pertaining to kinases of mice
for index, rowData in df.kinase_organism.iteritems():
    if '_' in rowData:
        count = rowData.count('_')
        lst = rowData.split('_', count)
        if 'Mus musculus' in lst:
            df_mouse_indices = df_mouse_indices + [index]

stat_df = df.loc[df_mouse_indices]

stat_df.drop('pubmed_id', axis = 1, inplace = True)

stat_df.drop_duplicates(inplace = True)

len(stat_df.substrate.unique())
# Out:
# 415

# %%
#For inclusion on website as a statistic, calculate 
#the total number of unique terms for the dataset
k = []

for index, rowData in mouse.kinase_organism.iteritems():
    if '_' in rowData:
        count = rowData.count('_')
        lst = rowData.split('_', count)
        if len(lst) == 2:
            k = k + [lst[0]]
        if len(lst) == 3:
            k = k + ['_'.join([lst[0], lst[1]])]

kinases = pd.Series(k)

all_terms = pd.concat([kinases, stat_df.substrate], axis = 0)
len(all_terms.unique())
# Out:
# 468

# %%
#For inclusion on website as a statistic, calculate 
#the total number of unique terms for the dataset
k = []

for index, rowData in mouse.kinase_organism.iteritems():
    if '_' in rowData:
        count = rowData.count('_')
        lst = rowData.split('_', count)
        if len(lst) == 2:
            k = k + [lst[0]]
        if len(lst) == 3:
            k = k + ['_'.join([lst[0], lst[1]])]

kinases = pd.Series(k)

all_terms = pd.concat([kinases, stat_df.substrate], axis = 0)
len(all_terms.unique())
# Out:
# 468

# %% [markdown]
# ## Formatting Final Combined Kin File for GMT format

# %%
#also drop the data-exploratory column 'kinase_substrate_num'
kin.drop('kinase_substrate_num', axis=1, inplace = True)

# %%
#Create dictionary 'Combined' with index numbers as keys
Combined_num = dict([(key, '') for key in kin.index])

# loop through rows with iterrows()
for index, rowData in kin.iterrows():
    line = ('\t'.join(rowData))
    Combined_num[index] = line

# %% [markdown]
# ## Write info into a separate GMT file

# %%
#Transfer tab-separated info into a new txt file
with open('Combined.gmt', 'w') as openfile:
    for index in Combined_num:
        openfile.write(str(Combined_num[index]) + '\n')

# %% [markdown]
# # Separate GMT into a Combined_Mouse and Combined_Human format
# This separation is necessary for later creation of a GMT file that ranks the genes associated with each kinase according to their level of co-expression. The code to perform this process relies on the use of separate expression matrices for the human and mouse samples, which therefore requires that the human and mouse samples be separated here.

# %%
#also drop the data-exploratory column 'kinase_substrate_num'
human.drop('kinase_substrate_num', axis=1, inplace = True)

Combined_hum = dict([(key, '') for key in human.index])

for index, rowData in human.iterrows():
    line = ('\t'.join(rowData))
    Combined_hum[index] = line
    
with open('Combined_human.gmt', 'w') as openfile:
    for index in Combined_hum:
        openfile.write(str(Combined_hum[index]) + '\n')

# %%
#also drop the data-exploratory column 'kinase_substrate_num'
mouse.drop('kinase_substrate_num', axis=1, inplace = True)

Combined_m = dict([(key, '') for key in mouse.index])

for index, rowData in mouse.iterrows():
    line = ('\t'.join(rowData))
    Combined_m[index] = line
    
with open('Combined_mouse.gmt', 'w') as openfile:
    for index in Combined_m:
        openfile.write(str(Combined_m[index]) + '\n')
# Out:
# /home/maayanlab/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
