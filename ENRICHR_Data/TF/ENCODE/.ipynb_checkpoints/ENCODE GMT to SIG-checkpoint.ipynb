# %% [markdown]
# ## ENCODE GMT to SIG File Conversion
#
# This script will take an input of an ENCODE (from any year) and transform it into the SIG file format. Make sure to carefully match the ENCODE version you are using to the SIG file version you are outputting.

# %%
# %run /home/maayanlab/Desktop/Projects/KEA3/Scripts/init.ipy

# %%
#this maximum set according to the max column value indicated to me by Ariel
colnames = ['']*7001
colnames

ENCODE = pd.read_table('ENCODE_TF_ChIP-seq_2014.txt', names = colnames)

subset = ENCODE.copy()

subset.dropna(how = 'all', inplace = True)

subset.replace(np.nan, '', inplace = True)

subset.head()
# Out:
#                 .1                .2                  .3                .4  \
# 0      PML_K562     CASP8AP2,1.06698   NIPSNAP3B,1.15557    FNBP4,0.882088
# 1       P300_H1         ATE1,1.15142     POLR2J4,1.15142      FRS3,1.11944
# 2  RFX5_HELA-S3          BAD,1.16495        DHDH,1.20651     RC3H2,1.16763
# 3  E2F4_GM12878      POLR2J4,1.02102        ENDOG,1.1556  CASP8AP2,1.13748
# 4     SP1_HEPG2     CASP8AP2,1.12088  LOC613038,0.775104     FNBP4,1.15687
#
#                   .5                .6               .7                .8  \
# 0        BAD,1.10678   BTBD19,0.297881  WDR83OS,1.15557  KIAA1586,1.15557
# 1     LNPEP,0.740748  C12ORF73,1.15142     FRS2,1.15142    PRKAB2,1.15142
# 2     PRKAB1,1.16093   MIR3917,1.20651   NECAP1,1.20651       SCD,1.20651
# 3      FNBP4,1.16466      BAD,0.856672    RC3H2,1.04172    LNPEP,0.600447
# 4  LOC613037,0.29693   BTBD19,0.457607      BAD,1.15687     RC3H2,1.04247
#
#                  .9  ...  .6991 .6992 .6993 .6994 .6995 .6996 .6997 .6998  \
# 0     LNPEP,1.12733  ...
# 1      ISL2,1.07978  ...
# 2     LAS1L,1.20651  ...
# 3  C12ORF73,1.16466  ...
# 4    LNPEP,0.575865  ...
#
#   .6999 .7000
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 7001 columns]

# %%
for column in subset:
    for index, row in subset['%s' %column].iteritems():
        s = row
        if ',' in s:
            s = s.split(',', 1)[0]
        subset.loc[index, '%s' %column] = s

subset.head()
# Out:
#                 .1        .2         .3        .4         .5        .6  \
# 0      PML_K562     CASP8AP2  NIPSNAP3B     FNBP4        BAD    BTBD19
# 1       P300_H1         ATE1    POLR2J4      FRS3      LNPEP  C12ORF73
# 2  RFX5_HELA-S3          BAD       DHDH     RC3H2     PRKAB1   MIR3917
# 3  E2F4_GM12878      POLR2J4      ENDOG  CASP8AP2      FNBP4       BAD
# 4     SP1_HEPG2     CASP8AP2  LOC613038     FNBP4  LOC613037    BTBD19
#
#         .7        .8        .9  ...  .6991 .6992 .6993 .6994 .6995 .6996  \
# 0  WDR83OS  KIAA1586     LNPEP  ...
# 1     FRS2    PRKAB2      ISL2  ...
# 2   NECAP1       SCD     LAS1L  ...
# 3    RC3H2     LNPEP  C12ORF73  ...
# 4      BAD     RC3H2     LNPEP  ...
#
#   .6997 .6998 .6999 .7000
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 7001 columns]

# %%
#loop through each row of the data frame
#make the index ('') the dataframe's key
#make each item of rowData into part of a list
#store this list as a value for the index key of the dictionary


#Once the dictionary is completed, we can use the dictionary to drop values which are NaN from the
#list (or can have used list comprehension beforehand to filter the list and 
#keep NaNs from becoming values in the dataframe)

subset.set_index('', inplace = True)

d = {}

for index, rowData in subset.iterrows():
    lst = []
    sr = pd.Series(rowData)
    for i in range(0, len(sr)):
        if sr[i] == '':
            lst = lst + [i]
    sr.drop(sr.index[lst], inplace = True)
    d[index] = [sr.values]

d
# Out:
# {'AP-2alpha_HELA-S3': [array(['STARD4', 'SND1', 'LRRC37A3', 'UNC13D', 'PRELID2', 'C20ORF29',
#          'SOX15', 'SLC50A1', 'CD3EAP', 'FRS3', 'C20ORF195', 'FRS2', 'LNPEP',
#          'C12ORF75', 'ISL2', 'RNF224', 'TEC', 'DEPDC1B', 'FLJ33630', 'ETHE1',
#          'HNRNPC', 'HNRNPD', 'LETMD1', 'ASF1B', 'ZNF155', 'NLRX1', 'SGMS1',
#          'THYN1', 'SERPINE1', 'TESK1', 'RPL12', 'LOC284454', 'DCAF6',
#          'ADCY9', 'TOB2', 'TIPARP-AS1', 'MUC1', 'GMDS', 'LOC100507250',
#          'CYP1B1', 'HES1', 'HES4', 'SF3B2', 'CNOT6L', 'ATG3', 'PRR11',
#          'PROSER1', 'ZNF143', 'HEMK1', 'KLF13', 'DMPK', 'FZD5', 'PLK3',
#          'KLF10', 'NR1D1', 'WDR53', 'INO80', 'C12ORF52', 'HCFC2', 'PTP4A2',
#          'ABTB2', 'FAM160A2', 'FERMT2', 'RNF207', 'SFXN4', 'PSME2',
#          'CCDC169-SOHLH2', 'SNAI1', 'ZNF498', 'NAA40', 'CFD', 'PLEK2',
#          'CDCA7', 'PLEKHA8P1', 'BAZ2A', 'LYPD3', 'ZNF24', 'C3', 'SMC3',
#          'FAM120AOS', 'HSPH1', 'FAM134C', 'EPB41L2', 'ZC3H12C', 'ZNF280D',
#          'KCNMB4', 'PLAC2', 'JUNB', 'ZNF248', 'ZNF488', 'WDR37', 'ANXA2',
#          'RDX', 'NSUN6', 'ANXA6', 'WNT9A', 'IFT122', 'TMCO4', 'JOSD1', 'H19',
#          'ITPKC', 'TMEM37', 'NSA2', 'MMP15', 'GPRC5C', 'SLCO4A1', 'CENPJ',
#          'ITPKA', 'TRMT6', 'PQLC3', 'CLCF1', 'EXOC5', 'REL', 'LIMS1',
#          'RAPGEF6', 'LOC389791', 'MBLAC1', 'RNF145', 'EXD3', 'GRAMD1A',
#          'TINAGL1', 'ABHD5', 'WFIKKN1', 'CLTA', 'GPT', 'SHB', 'CYB561D1',
#          'MED16', 'SLC7A2', 'KIAA0284', 'LOC100131208', 'EXTL2', 'ATXN2',
#          'C14ORF182', 'MED11', 'RHPN2', 'PBK', 'JARID2', 'LOC440028',
#          'TEAD1', 'CEP57', 'FAM160B1', 'TPRA1', 'CCDC162P', 'MBD4', 'ATAD1',
#          'ANKHD1-EIF4EBP3', 'TTC7A', 'NOC3L', 'FMO4', 'NFIA', 'TUBB4B',
#          'MIR24-2', 'ERP44', 'SOLH', 'FAM200B', 'COL4A3', 'NMNAT1', 'APEX2',
#          'JKAMP', 'CKS2', 'PRKRIR', 'ZNF337', 'SLC29A1', 'GCHFR', 'INHA',
#          'TRUB2', 'ZNF573', 'STAG3L4', 'C15ORF38-AP3S2', 'NDUFA10', 'GSTP1',
#          'GCNT2', 'MYPN', 'ING2', 'SMG7', 'EEA1', 'PTGS2', 'C16ORF72',
#          'FADS3', 'FLJ16341', 'ZNF449', 'RNF130', 'PKM2', 'C11ORF46',
#          'IKBKG', 'TMEM14A', 'SETD2', 'ZNF566', 'JAK2', 'MAP3K3', 'SEPT10',
#          'CD164', 'IST1', 'CEP112', 'S100A2', 'S100A1', 'C11ORF61',
#          'ANKRD24', 'BET3L', 'MIR933', 'PNRC1', 'NEAT1', 'PNRC2', 'C1ORF63',
#          'MELK', 'STIM1', 'MSH3', 'CNOT3', 'PKP3', 'ZNF318', 'ZNF438',
#          'PKP2', 'ZYX', 'DHCR7', 'SLC25A35', 'FKBP7', 'CHRM1', 'KANK1',
#          'ANKRD36', 'ZBTB26', 'DGKD', 'UBE2D3', 'SRSF1', 'LINC00482', 'URM1',
#          'PDCD6', 'DLST', 'TNC', 'PARK7', 'RBMXL1', 'BZW2', 'CASC2',
#          'FAM214A', 'RNF31', 'SLC9A2', 'FAM105A', 'DSCR3', 'RNU11', 'NACC1',
#          'LCNL1', 'RUVBL2', 'CEP250', 'SLC25A42', 'HMGN4', 'PHLDA2',
#          'ZNF302', 'LINC00235', 'C11ORF67', 'SH2B3', 'SLC16A5', 'PMS2',
#          'SLC16A6', 'STOX1', 'LINC00479', 'WHSC1L1', 'LOC550112', 'CPA4',
#          'ZNF783', 'TRAPPC4', 'CERS5', 'PIAS4', 'MAP2K1', 'NEK8', 'OSBPL2',
#          'LSM1', 'MAFA', 'NFKB1', 'ABHD15', 'FRMD3', 'DALRD3', 'GGCT',
#          'PITPNM1', 'TRAF4', 'CDC42EP4', 'FSCN2', 'BCL2L1', 'SPIRE2',
#          'MAP3K11', 'TSNAX-DISC1', 'LOC144571', 'ZNF775', 'RAB5B', 'RAD9A',
#          'GLYR1', 'OSBPL1A', 'MDM2', 'LRRC59', 'CBFB', 'C11ORF95',
#          'C15ORF62', 'LOC100129518', 'GSTT1', 'PKMYT1', 'C1ORF213',
#          'RHOBTB2', 'VTN', 'SESN1', 'BAG5', 'ABHD11', 'NIPBL', 'BAG3',
#          'MED31', 'C6ORF228', 'G3BP1', 'C1QTNF6', 'CLCA2', 'SLC38A9', 'PIM3',
#          'SH2D6', 'PRRT2', 'GPX1', 'REXO1', 'SNORD12C', 'KSR1', 'AVPR2',
#          'RFC1', 'MSL3', 'GPR97', 'OSGIN1', 'LOC644656', 'PARD3B',
#          'C15ORF58', 'CUL4A', 'ARMC12', 'ZNF639', 'ZNF638', 'RMND1', 'CDK2',
#          'BCL3', 'ETF1', 'C8ORF73', 'LCOR', 'SERPINI1', 'SMCR8', 'PPP1R12C',
#          'PSMG1', 'LOC257396', 'METAP2', 'BCAR1', 'SOS1', 'SEH1L', 'DLX4',
#          'LOC100505839', 'ST20-MTHFS', 'ITPR3', 'FBXO46', 'FBXO44', 'ITPR1',
#          'RIC8B', 'C15ORF38', 'LOC728752', 'MIR4767', 'PPP6R2', 'DENND3',
#          'DNAJB5', 'ATP5E', 'C21ORF91', 'KIAA0319', 'CD300LG', 'SKIL',
#          'TRIM45', 'UBE2F-SCLY', 'RUSC1-AS1', 'PAAF1', 'GCN1L1', 'LINC00111',
#          'PLEKHG2', 'LINC00112', 'NDUFA4', 'MID1IP1', 'PAPD4', 'RPRD2',
#          'GFER', 'C1ORF86', 'TPD52L2', 'BPGM', 'CDC40', 'MRVI1-AS1', 'KLF3',
#          'P2RX6', 'PFKL', 'PPM1D', 'IMPDH1', 'KCTD11', 'POLR1C', 'MIR4515',
#          'P2RX1', 'POLR1E', 'C8ORF51', 'KCTD15', 'LOC100130880', 'SLC25A10',
#          'C3ORF23', 'C8ORF55', 'ANAPC2', 'GAPDH', 'TPT1', 'LOC100506710',
#          'CDCA7L', 'ITGB1', 'HDAC4', 'SH2D4A', 'DYSF', 'KIAA0895L', 'SRI',
#          'PTEN', 'C1ORF131', 'PPM1K', 'HDAC7', 'C1ORF135', 'ADAMTS5',
#          'DCAF17', 'HECTD1', 'MIR3656', 'LOC100287036', 'TRIM25', 'FBXO4',
#          'ERC1', 'FLAD1', 'MIR3654', 'ITGB8', 'PCBD2', 'MMAA', 'DCAF11',
#          'HNRNPA3', 'C3ORF37', 'SLC12A3', 'SLC35A5', 'DUT', 'IFRD1',
#          'FAM76A', 'ACSL3', 'ARL16', 'PLEKHA3', 'SS18L2', 'SLC12A2',
#          'ENTPD8', 'MFSD12', 'MAPK8IP3', 'MTUS1', 'CDC20', 'FNDC5',
#          'SPATA12', 'PPP1R3C', 'CTH', 'SLPI', 'FAM76B', 'OBSL1', 'MGC27382',
#          'SIK1', 'STX16', 'GEMIN8P4', 'PKD2L2', 'ARNTL', 'HERC5', 'PDCD10',
#          'RPL36AL', 'FZR1', 'NIPAL1', 'DHX35', 'NIPAL3', 'CHEK2', 'CPNE2',
#          'HMCN1', 'MIR4687', 'KIAA0913', 'N4BP2', 'EXOSC1', 'TRMT1L', 'BROX',
#          'ALG6', 'XRCC4', 'ALG3', 'RASSF8', 'IGFL4', 'CSNK1E', 'PARP16',
#          'PTK2', 'AIMP2', 'CCDC88C', 'ZZZ3', 'SNHG15', 'CEP57L1', 'MIR4674',
#          'LOC100505783', 'RPS25', 'CCNO', 'SLC22A4', 'ECI1', 'ARL6IP1',
#          'DKFZP761E198', 'CSTF3', 'PITPNB', 'TMTC3', 'MTMR9LP', 'RCBTB1',
#          'PWP2', 'C14ORF93', 'ZBTB5', 'ART5', 'RPS16', 'MT2A', 'GOLGA5',
#          'NEDD8-MDP1', 'RUSC2', 'CYP4V2', 'MBTD1', 'MIR4669', 'ANKH', 'PPAT',
#          'CSTF2', 'ZBED5', 'PSENEN', 'ACAD8', 'SFTPC', 'TSNAX', 'TSC22D2',
#          'TSC22D1', 'NMI', 'AKR1A1', 'PRPF40A', 'NME6', 'RHOG', 'C1ORF201',
#          'PPPDE1', 'BST2', 'NME7', 'KRT17', 'KRT16', 'MIR17HG', 'KRT15',
#          'FUBP3', 'RNU6ATAC', 'MEGF9', 'DEPDC5', 'SYNC', 'LOC100507501',
#          'AVPI1', 'TRAM2', 'DHX8', 'SLC35F3', 'CITED4', 'MIR3199-2', 'ACY1',
#          'SLC44A1', 'TOP2A', 'NEDD8', 'MLL', 'ACACA', 'C8G', 'SNX5',
#          'MAP1LC3B', 'NEU1', 'RRAS', 'ANKRD1', 'SNX8', 'CLIC3', 'MIR191',
#          'NQO1', 'MPP5', 'C17ORF48', 'GAA', 'ORMDL1', 'ZDHHC12', 'MYO9A',
#          'THOC5', 'MIB1', 'RANBP9', 'ZNF487P', 'DPY19L3', 'KIF26A',
#          'HNRNPH1', 'HNRNPH2', 'CANX', 'DNASE1L3', 'CARS2', 'LOC253039',
#          'IL20', 'INVS', 'PRIM2', 'TRAF3IP1', 'PTGER4', 'PRICKLE3', 'ZDHHC7',
#          'PRICKLE4', 'SLC20A1', 'CST9', 'GNAI1', 'ARNTL2', 'AKAP11',
#          'EPB41L4B', 'RSRC1', 'SDF4', 'FAM3C', 'CD59', 'GIT1', 'SPINK4',
#          'UBE2F', 'ZNF76', 'UBE2A', 'LIFR', 'ATP1B3', 'ANKHD1', 'DOK1',
#          'ZNFX1', 'TBL1XR1', 'XK', 'UEVLD', 'LOC286467', 'FLJ35776',
#          'FAM173B', 'EHBP1L1', 'PMS2P4', 'LOC100302401', 'UCA1', 'AMOTL2',
#          'PDE7A', 'ZSCAN2', 'ZFAND5', 'MIR3191', 'CCBL2', 'LOC100507410',
#          'HSF2', 'STX16-NPEPL1', 'KIAA2018', 'GPC1', 'TCTEX1D4', 'COTL1',
#          'CAPN2', 'NDUFV3', 'AZI2', 'GAS2L1', 'OPN3', 'UTP15', 'SLC30A7',
#          'UTP18', 'PCID2', 'MIR27A', 'SSH3', 'SMAD6', 'SYT7', 'PAN3',
#          'NR4A3', 'IFT20', 'TMEM2', 'ABCA11P', 'DLG4', 'MAP7D1', 'DYNLRB2',
#          'MXD3', 'FGFR4', 'MIR3622B', 'SAE1', 'HOMEZ', 'LZIC', 'WWC2',
#          'KLHL11', 'C2ORF28', 'LPP', 'C20ORF141', 'PDS5B', 'LOC286135',
#          'CALHM3', 'LOC100288842', 'BCL9L', 'PDZD9', 'USP25', 'RBM15',
#          'MIR181C', 'ABCC2', 'MIR181D', 'HSPA5', 'CBX4', 'C14ORF45',
#          'PPP2R5B', 'ABHD14B', 'DAK', 'PJA2', 'HIGD2B', 'IRF1', 'ELF3',
#          'ACOX1', 'NDUFS6', 'AKT1S1', 'COL7A1', 'NDUFS2', 'RGNEF', 'TMEM45A',
#          'NNMT', 'AGPAT9', 'PMEL', 'CKS1B', 'AGAP3', 'MTIF3', 'PIK3R2',
#          'PLD2', 'AGPAT2', 'DPP3', 'STK4', 'ST7-OT4', 'PHTF1', 'HEBP2',
#          'MKNK1', 'SNAPC3', 'UBE2Q1', 'BCL7C', 'LOC100507217', 'DACT3',
#          'FAM83A', 'BDKRB2', 'APOPT1', 'LOC100286844', 'MGC16703', 'FAHD1',
#          'CXADR', 'MIR23A', 'ZNF181', 'C9ORF23', 'OXSR1', 'SHCBP1',
#          'C4ORF21', 'KCTD7', 'WEE1', 'RPIA', 'FMNL1', 'LOC729013', 'DDIT4',
#          'TOMM70A', 'SUGT1', 'MAN1B1', 'LNX2', 'SPRY2', 'RBM47', 'SSBP4',
#          'LOC100507127', 'TRIB1', 'RBM28', 'NUP107', 'CCDC169', 'MIR3926-2',
#          'EHMT1', 'LDB3', 'SLC22A18AS', 'CLCN4', 'RABEPK', 'NT5DC1',
#          'RPS6KA4', 'ADD1', 'MAPK9', 'PPP2R1B', 'NT5DC3', 'BNIP2', 'LRIG2',
#          'TAS1R3', 'ZNF169', 'NPTN', 'RBM34'], dtype=object)],
#  'AP-2gamma_HELA-S3': [array(['STARD4', 'SND1', 'C20ORF29', 'RFX3', 'FRS3', 'FRS2', 'C20ORF195',
#          'HSPE1', 'C12ORF75', 'ISL2', 'SCAMP1', 'GATAD2B', 'RNF224', 'SCD',
#          'TMEM126B', 'MTMR4', 'TESK1', 'TOB2', 'MUC1', 'GMDS',
#          'LOC100507250', 'TMEM68', 'STOM', 'HES1', 'ATG3', 'KLF12',
#          'PROSER1', 'HEMK1', 'KLF13', 'CYP4F3', 'KLF10', 'FLJ33534',
#          'ERLIN1', 'C12ORF52', 'NR2F6', 'FERMT2', 'MLLT10', 'SFXN4', 'PSME2',
#          'CCDC169-SOHLH2', 'NMT1', 'ZNF498', 'CDCA7', 'LOC100506190',
#          'BAZ2A', 'LYPD3', 'ZNF25', 'C20ORF11', 'C3', 'HSPH1', 'FAM134C',
#          'SCGB1D2', 'C19ORF33', 'ZC3H12C', 'KCNMB4', 'ZNF248', 'PLEKHM1P',
#          'ZNF488', 'C5ORF55', 'ZNF484', 'USP9X', 'RMI1', 'NSUN6', 'MYOF',
#          'SAMD4B', 'IFT122', 'WNT9A', 'TMCO4', 'JOSD1', 'VWA5A', 'GPRC5A',
#          'MMP15', 'GPRC5C', 'LYRM4', 'BHLHE40', 'MTCP1NB', 'RAPGEF6',
#          'LIMS1', 'TMEM106B', 'EXD3', 'WFIKKN1', 'GPR20', 'SLC7A2',
#          'KIAA0284', 'LOC100288181', 'HSPE1-MOB4', 'LOC100507299', 'ATXN2',
#          'LOC100131208', 'PANX1', 'EXTL2', 'MED11', 'CCDC162P', 'MBD4',
#          'GPR39', 'ATAD1', 'ZNF221', 'GPR37', 'DYNLL1', 'UTP3', 'NOC3L',
#          'MIR24-2', 'SPSB3', 'FAM200B', 'LARS2', 'APEX2', 'CKS2', 'PRKRIR',
#          'SLC29A2', 'SLC29A1', 'ZNF213', 'TRUB2', 'STAG3L4', 'GSTP1', 'MYPN',
#          'EEA1', 'PTGS2', 'HEY2', 'HEY1', 'SMPD1', 'FLJ16341', 'ZNF449',
#          'PKM2', 'IKBKG', 'JAK2', 'MAP3K3', 'SEPT10', 'MYLIP', 'CORO2A',
#          'S100A2', 'S100A1', 'C11ORF61', 'MIR933', 'NEAT1', 'PKP3', 'ZNF438',
#          'PKP2', 'SLC25A35', 'SRSF9', 'C11ORF58', 'KANK1', 'ZBTB26', 'ROCK2',
#          'UBE2D3', 'SRRT', 'ODC1', 'URM1', 'PDCD6', 'RBMXL1', 'CASC2',
#          'SLC9A2', 'LCNL1', 'HAS2', 'RUVBL2', 'CEP250', 'SLC25A42', 'STX4',
#          'C11ORF67', 'SH2B3', 'ATP9B', 'PMS2', 'SLC16A6', 'MAP3K6', 'CPA4',
#          'PIAS4', 'CERS5', 'SLC38A2', 'NEK8', 'B3GALT6', 'NFKB1', 'FRMD3',
#          'STK24', 'FSCN2', 'OSBPL1A', 'MDM2', 'MAX', 'LOC100129518', 'GSTT1',
#          'PKMYT1', 'C1ORF213', 'SESN1', 'NIPBL', 'MED31', 'C6ORF228',
#          'G3BP1', 'PIM3', 'SH2D6', 'PABPC4L', 'PRRT2', 'UNC45A', 'ITGA5',
#          'SH2D3A', 'GFPT1', 'KSR1', 'MSL3', 'GPR97', 'LOC644656', 'PARD3B',
#          'SP3', 'ARMC12', 'ZNF639', 'RMND1', 'ETF1', 'PSMG2', 'LCOR',
#          'SMCR8', 'PPP1R12C', 'PSMG1', 'BCAR1', 'NDUFB9', 'DLX4', 'FBXO46',
#          'ATP5I', 'FBXO44', 'MDK', 'LOC728752', 'ALAD', 'ZNF629', 'PPP6R2',
#          'C10ORF10', 'ATP5E', 'C21ORF91', 'ACP2', 'UBE2F-SCLY', 'RUSC1-AS1',
#          'LINC00111', 'LINC00112', 'NDUFA4', 'MID1IP1', 'TPD52L2', 'CDC40',
#          'MRVI1-AS1', 'PPM1D', 'SUCLA2', 'KCTD11', 'KCTD15', 'SLC25A10',
#          'ANAPC2', 'CDCA7L', 'SRC', 'SH2D4A', 'DYSF', 'KIAA0895L', 'SRI',
#          'PTEN', 'ETFB', 'FOXRED2', 'SLC25A28', 'DKFZP434A062',
#          'LOC100287036', 'SUMO3', 'TRIM25', 'ERC1', 'ITGB8', 'PCBD2', 'MMAA',
#          'HNRNPA3', 'SLC12A3', 'FAM76A', 'PLEKHA3', 'ARL16', 'SLC12A2',
#          'TM4SF4', 'ENTPD8', 'MFSD12', 'CDC20', 'SPATA17', 'FNDC5',
#          'PPP1R3C', 'SPATA12', 'SLPI', 'MTCP1', 'FAM76B', 'EPHA2',
#          'MGC27382', 'STX16', 'CCNK', 'PPP1R36', 'CPNE8', 'TIFA', 'HERC5',
#          'RAB11FIP2', 'EXOSC5', 'DHX35', 'SNRPD2', 'CPNE2', 'EXOSC1', 'ALG6',
#          'XRCC4', 'ALG3', 'RASSF8', 'CSNK1E', 'PTK2', 'AIMP2', 'SNHG15',
#          'CETP', 'NUMA1', 'TXNDC11', 'MTMR9LP', 'RCBTB1', 'ZBTB5', 'ART5',
#          'MT2A', 'NEDD8-MDP1', 'ANKH', 'MBTD1', 'PPAT', 'ZBED5', 'SFTPC',
#          'ACAD8', 'SSSCA1', 'AKR1A1', 'MRPS2', 'PRPF40A', 'VEGFA',
#          'C1ORF201', 'BST2', 'PTMA', 'SERGEF', 'DEPDC5', 'SYNC', 'SLC35E2B',
#          'DHX8', 'ACY1', 'IKBKAP', 'NEDD8', 'MLL', 'ACACA', 'C8G', 'SNX5',
#          'MAP1LC3B', 'ERI2', 'NEU1', 'RRAS', 'SNX8', 'SPRYD7', 'GAA', 'TTC3',
#          'C9ORF116', 'MYO9A', 'MIB1', 'DPY19L3', 'KIF26A', 'CANX', 'CARS2',
#          'JAZF1-AS1', 'SNORA16A', 'IL20', 'PRICKLE3', 'NUDT2', 'ZDHHC7',
#          'PRICKLE4', 'CRIP2', 'NUBP2', 'AKAP11', 'SERTAD2', 'SDF4', 'CD59',
#          'FLJ42969', 'SPINK4', 'KLHL26', 'UBE2F', 'ATG9B', 'MRE11A', 'ZNF76',
#          'UBE2A', 'ZNF79', 'SUPT7L', 'ANKHD1', 'DOK1', 'XK', 'UEVLD',
#          'LOC286467', 'FAM173B', 'UBE2T', 'RPP25', 'CCDC146', 'CD82',
#          'COX6A1', 'LOC100507410', 'GPC1', 'CAPN2', 'NDUFV3', 'MORC2',
#          'TBC1D17', 'CARD10', 'UTP15', 'SLC30A7', 'PCID2', 'DDX54', 'KIF24',
#          'MIR27A', 'SSH3', 'SYT7', 'PAN3', 'IFT20', 'KIF2A', 'UBE2R2',
#          'MAP7D1', 'CFL1P1', 'MXD3', 'HOMEZ', 'C20ORF141', 'PDS5B', 'CALHM3',
#          'LOC100288842', 'RGS2', 'NPPB', 'BCL9L', 'ZFHX2', 'BCKDHA', 'RBM15',
#          'LAMB3', 'ABHD14B', 'HIGD2B', 'PJA2', 'POLA1', 'IRF1', 'ELF3',
#          'ACOX1', 'NDUFS6', 'ATG4C', 'NDUFS2', 'TMEM45A', 'HP1BP3',
#          'C9ORF169', 'NNMT', 'AGPAT9', 'GSK3A', 'PIK3R2', 'C4ORF38', 'PLD2',
#          'AGPAT2', 'PHTF1', 'C4ORF34', 'LASP1', 'UBE2Q1', 'BCL7C',
#          'LOC100507217', 'KTN1-AS1', 'DACT3', 'APOPT1', 'LOC100286844',
#          'FAHD1', 'TAF15', 'TMED7-TICAM2', 'MIR23A', 'LOC389247', 'TAF10',
#          'VTRNA1-2', 'C4ORF21', 'IRGQ', 'ERCC1', 'RPIA', 'SUGT1', 'MAN1B1',
#          'LNX2', 'S100P', 'RBM47', 'TRIB1', 'RBM28', 'RBM27', 'CCDC169',
#          'MIR3926-2', 'ATP2A3', 'MIR1908', 'LDB3', 'CLCN4', 'CLCN2', 'ADD1',
#          'POLD1', 'SPATA24', 'DIP2A', 'TAS1R3', 'NPTN', 'RBM34', 'LRRC37A3',
#          'UNC13D', 'RPL22', 'RPL24', 'SOX15', 'CD3EAP', 'SOX12', 'GTPBP3',
#          'GTPBP2', 'GTPBP5', 'TEC', 'TRIP6', 'FLJ33630', 'ASF1A', 'HNRNPC',
#          'NHLRC3', 'HNRNPD', 'PLCD4', 'CDK16', 'ASB1', 'ASF1B', 'RAN',
#          'ZNF155', 'RPL10', 'SERPINE1', 'RPL12', 'LOC284454', 'DCAF6',
#          'ADCY9', 'LOC100507373', 'CYP1B1', 'SF3B2', 'NXNL2', 'PRR11',
#          'DMPK', 'COL25A1', 'FZD5', 'PLK3', 'WDR53', 'INO80', 'CDYL2',
#          'WDR55', 'HCFC2', 'PTP4A2', 'FAM160A2', 'ST20', 'SNAI1',
#          'LOC400891', 'NAA40', 'CFD', 'PLEKHA8P1', 'PRKDC', 'RAPH1', 'FARS2',
#          'SMC5', 'FAM120AOS', 'ZNF280D', 'JUNB', 'WDR37', 'LOC284648',
#          'SSR4', 'ANXA6', 'H19', 'ITPKC', 'GLUD1', 'NSA2', 'ITPKA', 'TRMT6',
#          'PQLC3', 'CLCF1', 'EXOC5', 'REL', 'LOC389791', 'MOCS2', 'LOC728228',
#          'TINAGL1', 'GPT', 'METTL21A', 'GJC2', 'C14ORF182', 'RHPN2',
#          'C16ORF57', 'PBK', 'JARID2', 'TEAD1', 'TEAD4', 'CEP57', 'TPRA1',
#          'YTHDF1', 'ANKRD49', 'ANKHD1-EIF4EBP3', 'ADAT2', 'ELP2', 'TTC7A',
#          'PRSS36', 'FMO4', 'NFIA', 'TUBB4B', 'FAM104A', 'FIG4', 'ERP44',
#          'SOLH', 'COL4A3', 'NMNAT1', 'JKAMP', 'ZNF337', 'ZNF576', 'INHA',
#          'ZNF573', 'SETD3', 'C15ORF38-AP3S2', 'NDUFA10', 'GCNT2', 'ALMS1',
#          'PRSS23', 'ING2', 'SMG7', 'C16ORF72', 'TMSB4X', 'FAM102B',
#          'FLJ13197', 'ADAMTSL5', 'TMEM38B', 'TMEM14A', 'SETD2', 'CEP112',
#          'USP3', 'ANKRD24', 'BET3L', 'ENKUR', 'PNRC2', 'MOB3C', 'LRFN4',
#          'MELK', 'STIM1', 'ST7L', 'CNOT3', 'ZNF319', 'ZNF318', 'ZYX',
#          'ADAM9', 'PCNXL3', 'DHCR7', 'FKBP7', 'ZNF554', 'CHRM1', 'ANKRD36',
#          'DGKD', 'LINC00482', 'TNC', 'PARK7', 'BZW2', 'FAM214A', 'RNF31',
#          'C6ORF130', 'FAM105A', 'DSCR3', 'FGD6', 'GCFC1-AS1', 'RAB24',
#          'SLC39A6', 'HMGN4', 'ZNF302', 'LINC00479', 'STOX1', 'LOC550112',
#          'ZNF783', 'TRAPPC4', 'OSBPL2', 'MIRLET7I', 'LSM1', 'LOC100289361',
#          'LSM5', 'MAFA', 'ABHD15', 'DALRD3', 'PITPNM1', 'TADA3', 'BCL2L1',
#          'SPIRE2', 'MAP3K11', 'SPIRE1', 'TPP2', 'LOC100190939', 'LOC144571',
#          'ZNF775', 'RAB5B', 'RAD9A', 'GLYR1', 'DIDO1', 'NOTCH1', 'CBFB',
#          'CNP', 'CLSTN1', 'C15ORF62', 'RHOBTB2', 'ABHD11', 'BAG3', 'C1QTNF6',
#          'ANKRD10', 'CLCA2', 'ANKRD11', 'PLS1', 'GPX1', 'REXO1', 'SNORD12C',
#          'AVPR2', 'RFC1', 'C15ORF58', 'MFAP4', 'CDK2', 'BCL3', 'C8ORF73',
#          'SERPINI1', 'MCM2', 'METAP2', 'SOS1', 'SEH1L', 'ZC3H4',
#          'LOC100505839', 'ST20-MTHFS', 'ITPR3', 'TARS', 'DUSP14', 'ITPR1',
#          'RIC8B', 'C15ORF38', 'LOC643441', 'MIR4767', 'PIP5KL1', 'DENND3',
#          'MGAT5B', 'DNAJB5', 'MIR4522', 'KIAA0319', 'CD300LG', 'SKIL',
#          'PAAF1', 'GCN1L1', 'MAGI1', 'PLEKHG2', 'RNF25', 'SPAG7', 'PAPD4',
#          'RPRD2', 'GFER', 'WDR96', 'BPGM', 'KLF3', 'SELENBP1', 'ASXL1',
#          'P2RX6', 'PFKL', 'IMPDH1', 'SH3D21', 'POLR1C', 'MAB21L3', 'P2RX1',
#          'POLR1E', 'C8ORF51', 'LOC100130880', 'C3ORF23', 'TPT1',
#          'LOC100506710', 'EIF4A3', 'HDAC4', 'MCM8', 'TCIRG1', 'WDR87',
#          'C1ORF131', 'HDAC7', 'ADAMTS5', 'DCAF17', 'HECTD1', 'HECTD2',
#          'MIR3656', 'PSD3', 'FLAD1', 'MIR3654', 'POLR2H', 'DCAF11', 'STK32C',
#          'LOC728613', 'C3ORF37', 'SLC35A5', 'IFRD1', 'ACSL3', 'SS18L2',
#          'LOC286190', 'KRT8', 'MAPK8IP3', 'MTUS1', 'CTH', 'HIST1H4K',
#          'OBSL1', 'SIK1', 'TLN1', 'WBP4', 'UQCR10', 'GEMIN8P4', 'PKD2L2',
#          'TRMT2A', 'ARNTL', 'TIAL1', 'PDCD10', 'RPL36AL', 'FZR1', 'NIPAL3',
#          'CHEK2', 'HMCN1', 'DENR', 'SHOC2', 'MIR4687', 'KIAA0913', 'TRMT1L',
#          'ABT1', 'BROX', 'IGFL4', 'ACADSB', 'C10ORF131', 'VASP', 'CCDC88C',
#          'MYL12A', 'ZZZ3', 'CEP57L1', 'MIR4674', 'LOC100505783', 'RPS25',
#          'VEZT', 'ARL6IP1', 'DKFZP761E198', 'CSTF3', 'PITPNB', 'CTDSPL2',
#          'TMTC3', 'C14ORF93', 'PWP2', 'CYP4V2', 'MIR4669', 'CSTF2', 'PSENEN',
#          'TSC22D1', 'NME6', 'RHOG', 'FRG1', 'NME7', 'R3HCC1', 'MAPT',
#          'KRT17', 'KRT16', 'KRT15', 'FUBP3', 'RNU6ATAC', 'MEGF9',
#          'LOC100507501', 'AVPI1', 'DAZAP1', 'SLC35F3', 'C2CD2', 'CITED4',
#          'MIR3199-2', 'LINC00163', 'TOP2A', 'ADRB2', 'SLC22A18', 'MLEC',
#          'GNPNAT1', 'ANKRD1', 'CLIC3', 'MIR191', 'TMED7', 'NQO1', 'RANBP2',
#          'MIR4470', 'MPP5', 'NOG', 'RANBP1', 'C1GALT1', 'C17ORF48',
#          'ZDHHC14', 'PACS1', 'ZDHHC12', 'THOC5', 'RANBP9', 'ZNF487P',
#          'HNRNPH1', 'HNRNPH2', 'DNASE1L3', 'LOC253039', 'GFM2', 'INVS',
#          'PRIM2', 'TRAF3IP1', 'PTGER4', 'SLC20A1', 'CST9', 'SIPA1L3',
#          'EPB41L4B', 'NFYA', 'MYOZ1', 'QPCTL', 'ARID3A', 'LIFR', 'ATP1B3',
#          'TUG1', 'ZNFX1', 'TBL1XR1', 'PMS2P4', 'FAU', 'LOC100302401',
#          'SPNS1', 'UCA1', 'PDE7B', 'PDE7A', 'ZSCAN2', 'MIR3191', 'CCBL2',
#          'IFI6', 'LOC647323', 'TATDN3', 'KIAA2018', 'STX16-NPEPL1',
#          'TCTEX1D4', 'COTL1', 'MIR4289', 'LOC100506207', 'GAS2L1', 'SMAD3',
#          'OPN3', 'USP43', 'HMHA1', 'TBCC', 'MIR22', 'C17ORF80', 'HELZ',
#          'TDRD7', 'SMAD6', 'NR4A3', 'NR4A2', 'DCTD', 'EFNA1', 'TMEM2',
#          'ABCA11P', 'DLG4', 'LOC100134368', 'DYNLRB2', 'FGFR4', 'MIR3622B',
#          'LZIC', 'SMEK1', 'ROGDI', 'LPP', 'SYDE2', 'LOC286135', 'PDZD9',
#          'USP25', 'MIR181C', 'ABCC2', 'MIR181D', 'HSPA5', 'CBX4', 'C14ORF45',
#          'PPP2R5B', 'DAK', 'C17ORF110', 'MAN2B1', 'RGNEF', 'PMEL', 'CBY3',
#          'ZNF192', 'CKS1B', 'AGAP3', 'MTIF3', 'DPP3', 'STK4', 'ST7-OT4',
#          'HEBP2', 'CASP9', 'MFSD3', 'FAM83A', 'BDKRB2', 'MGC16703', 'CXADR',
#          'ZNF181', 'C9ORF23', 'OXSR1', 'PLAUR', 'LSR', 'SHCBP1', 'KCTD7',
#          'FMNL1', 'LOC729013', 'DDIT4', 'C2ORF50', 'SSBP4', 'LOC100507127',
#          'DHTKD1', 'TM2D2', 'EHMT1', 'FRMD6-AS1', 'SLC22A18AS', 'RABEPK',
#          'RBM4', 'RPS6KA4', 'MAPK9', 'NT5DC3', 'CHSY1', 'LRIG2'], dtype=object)],
#  'ATF1_K562': [array(['CASP8AP2', 'FNBP4', 'HEXIM1', ..., 'LRIG2', 'BPNT1', 'LEKR1'], dtype=object)],
#  'ATF2_GM12878': [array(['HEXIM2', 'CASP8AP2', 'FNBP4', ..., 'LRIG3', 'BPNT1', 'ZNF169'], dtype=object)],
#  'ATF2_H1': [array(['FNBP4', 'BTBD19', 'ANKFY1', ..., 'LRIG2', 'PCDHGC3', 'LEKR1'], dtype=object)],
#  'ATF3_A549': [array(['ATE1', 'POLR2J4', 'ENDOG', ..., 'POLG', 'SCYL3', 'POLI'], dtype=object)],
#  'ATF3_GM12878': [array(['B3GALNT2', 'ENDOG', 'LINS', ..., 'LRIG3', 'SC5DL', 'BUB3'], dtype=object)],
#  'ATF3_H1': [array(['B3GALNT2', 'LINS', 'C20ORF27', ..., 'BUB3', 'POLI', 'POC1A'], dtype=object)],
#  'ATF3_HEPG2': [array(['B3GALNT2', 'LINS', 'C20ORF29', ..., 'BUB3', 'RBM6', 'POC1A'], dtype=object)],
#  'ATF3_K562': [array(['BTBD19', 'BAD', 'RC3H2', ..., 'LRIG2', 'ZNF169', 'LEKR1'], dtype=object)],
#  'BACH1_H1': [array(['MIR548D2', 'FNBP1', 'BAD', ..., 'LRIG1', 'ABCD1', 'CAMK2G'], dtype=object)],
#  'BACH1_K562': [array(['CASP8AP2', 'FNBP4', 'BAD', ..., 'POLI', 'SCYL2', 'POLH'], dtype=object)],
#  'BAF155_HELA-S3': [array(['STARD4', 'SND1', 'B3GALNT2', 'LINS', 'BTBD19', 'RFX1', 'GATAD2B',
#          'RNF224', 'DDX39A', 'C19ORF44', 'ASPHD1', 'CLNS1A', 'C19ORF42',
#          'TMEM126B', 'LINC00526', 'CKLF', 'ZNF277', 'LOC100306975',
#          'LOC730227', 'TSEN54', 'GMDS', 'PSMD3', 'VTI1A', 'C19ORF57', 'WLS',
#          'ABCA2', 'GABARAPL1', 'PRPF38A', 'EDEM3', 'SPAG5-AS1', 'MLLT11',
#          'ABTB2', 'TDP2', 'SFXN4', 'VAMP1', 'SF1', 'ZNF498', 'EXD1', 'POP7',
#          'C5ORF22', 'FLVCR1-AS1', 'C11ORF10', 'HHLA3', 'ITSN1', 'MUS81',
#          'LOC100506190', 'C12ORF60', 'LYPD3', 'C12ORF62', 'F11R', 'PPFIBP1',
#          'SUV420H2', 'TSKU', 'C3', 'LOH12CR2', 'MRPL21', 'ALKBH5', 'ZC3H12A',
#          'RAVER1', 'ALKBH2', 'PIP5K1A', 'SFN', 'MNX1', 'XYLB', 'DUSP6',
#          'JUN', 'DUSP1', 'TMCO1', 'EMP1', 'IFT122', 'JOSD2', 'GPRC5C',
#          'LYRM4', 'LOC441009', 'RAPGEF3', 'PIGN', 'TUT1', 'C11ORF30',
#          'KIAA1377', 'MRPL37', 'TRMT112', 'HLCS', 'EXTL2', 'PP7080', 'MYO6',
#          'ATXN1', 'LIN52', 'MBD4', 'ATAD1', 'DGAT2', 'HNRNPUL2-BSCL2',
#          'STAT3', 'ACOT13', 'SLC39A13', 'F3', 'LRG1', 'TMEM60', 'DDB1',
#          'PSMA2', 'ADAM15', 'SLMAP', 'SDHAF2', 'FLJ22447', 'SMAGP', 'PRKRIR',
#          'ZNF697', 'LGR4', 'MTMR11', 'CTF1', 'SNX14', 'EFCAB7', 'ODF3L1',
#          'JPH2', 'PIGW', 'FLJ16341', 'RICTOR', 'IKBKG', 'P4HTM', 'ZNF687',
#          'JAK2', 'S100A2', 'SLC9A8', 'MSH6', 'ZNF438', 'IL6ST', 'SLC25A35',
#          'S100A9', 'SLC25A40', 'PDCD6', 'UCP2', 'DLST', 'PLOD3', 'CASC4',
#          'CASC2', 'HSP90B1', 'SLC9A1', 'RUVBL1', 'ZNF425', 'LINC00114',
#          'SH2B3', 'PMS2', 'MAP3K6', 'LRRC49', 'C11ORF82', 'NEK7', 'C21ORF59',
#          'C1ORF220', 'CRNDE', 'POLRMT', 'MED28', 'IBTK', 'LOC729852',
#          'TMEM18', 'LCN2', 'FSCN1', 'TSNAX-DISC1', 'PIN1', 'LY6K', 'NAB2',
#          'ARL2', 'LOC100289495', 'FBXO24', 'ARHGAP1', 'ARHGAP5', 'KIAA0415',
#          'SESN1', 'NIPBL', 'ZNF408', 'C6ORF225', 'G3BP1', 'NEK2', 'SRD5A1',
#          'TXNDC9', 'TSNAXIP1', 'EIF5B', 'ITGA5', 'KSR1', 'ITGA2', 'TMPPE',
#          'GPR97', 'EIF2AK3', 'SP1', 'LOC100130987', 'ZNF639', 'SP4',
#          'ARMC10', 'ERBB2IP', 'SMCR8', 'BCAR1', 'CALR3', 'GTF3C4', 'DLX4',
#          'LRRK1', 'LOC100506804', 'FAM206A', 'NDUFB1', 'BICD1', 'NPAT',
#          'DRAM2', 'RDH13', 'BDNF-AS1', 'PMVK', 'SPR', 'DDI2', 'CEP290',
#          'IP6K1', 'RUSC1-AS1', 'ZNF860', 'LINC00111', 'NTRK1', 'NDUFA4',
#          'MYO10', 'MIR7-3', 'NDUFA1', 'CABLES2', 'TPD52L2', 'TBX6', 'CDC40',
#          'MRVI1-AS1', 'MBOAT1', 'LENG1', 'CDC37', 'SYT12', 'KCTD11', 'EIF3J',
#          'DTL', 'MET', 'MYO1G', 'CDCA7L', 'ALAS1', 'C1S', 'ZBTB47', 'PPM1J',
#          'ETFB', 'ECE2', 'PPM1L', 'PTPLB', 'ZBTB41', 'SLC25A28', 'LOC728730',
#          'KCTD21', 'LOC100287036', 'DHX57', 'ITGB8', 'MIR92B', 'EIF2A',
#          'BEND6', 'UBQLN4', 'SCAF11', 'FBXO3', 'ENTPD7', 'C7ORF25', 'MFSD12',
#          'PEX13', 'CYP39A1', 'C7ORF23', 'PPP1R3C', 'CCDC87', 'TMEM87A',
#          'ITIH4', 'CPNE8', 'PRCP', 'MGC39372', 'RAB11FIP2', 'PEG10', 'DHX38',
#          'CPNE2', 'XRRA1', 'RAB11FIP3', 'INTS4', 'EAF2', 'RAB27A', 'TFB2M',
#          'AIMP2', 'PPP1R21', 'RCOR3', 'RGL1', 'CCNO', 'ACTR3C', 'C7ORF50',
#          'C7ORF55', 'ZBED3', 'ACAD10', 'TSPAN1', 'ACAD11', 'SLC10A7',
#          'TSNAX', 'SSSCA1', 'LOC400027', 'PRPF40B', 'NBPF1', 'ZHX2', 'RAP2A',
#          'CTTNBP2NL', 'C1ORF201', 'IMMP1L', 'RAP2B', 'SERGEF', 'ALDH6A1',
#          'ID3', 'ARHGEF2', 'CRELD1', 'SYNC', 'STK40', 'PXT1', 'ACY1',
#          'CCDC103', 'IKBKAP', 'SUPT4H1', 'AATF', 'PTPRH', 'BBS9', 'FAM192A',
#          'LOC439990', 'MON2', 'CAP1', 'MRPS24', 'ORMDL2', 'DKKL1',
#          'LOC100129726', 'MYO9B', 'HNRNPUL2', 'RAD1', 'SELPLG', 'CD63',
#          'FKBP14', 'AP4E1', 'LOC646329', 'SPAG16', 'HERPUD2', 'LOC100287314',
#          'LOC645249', 'OPHN1', 'ARIH2', 'CD59', 'CCT5', 'DNAJC27-AS1',
#          'KLHL28', 'ZNF76', 'PDAP1', 'SUPT7L', 'ANKHD1', 'DOK1', 'XK',
#          'CKLF-CMTM1', 'UEVLD', 'FAM173B', 'WDFY2', 'IVNS1ABP', 'RAF1',
#          'ST7-AS1', 'CARS', 'DCLRE1B', 'PVT1', 'RBM4B', 'ZFAND3', 'KLHL35',
#          'WWTR1-AS1', 'CAPN2', 'TTC37', 'SLC30A7', 'CCDC132', 'KIF22',
#          'BORA', 'ARHGEF17', 'BUD31', 'NADKD1', 'RNASEH1', 'SSH3', 'SUPT5H',
#          'IFT20', 'FLJ36644', 'APPBP2', 'MAP7D1', 'CFL1P1', 'TSG101',
#          'CCDC127', 'WWC2', 'KLHL18', 'GXYLT1', 'ETS2', 'LOC100506343',
#          'CALHM3', 'SBF2', 'LOC338758', 'COX11', 'RBM15', 'GALNT4', 'ECD',
#          'PEX3', 'ABHD14A', 'HIGD2B', 'PJA2', 'CLCN6', 'IL6', 'PEX5',
#          'NDUFS6', 'COL7A1', 'NDUFS3', 'NDUFS2', 'LOC100507466', 'ZMYND12',
#          'QRICH1', 'RTN4', 'YWHAG', 'AGPAT9', 'NPR1', 'NPR3', 'RAP1GDS1',
#          'NT5C3', 'PLD1', 'TROVE2', 'PHTF2', 'PHTF1', 'CNPPD1', 'SEP15',
#          'ADAL', 'TMEM205', 'UBE2Q1', 'YWHAQ', 'VTRNA1-2', 'THAP2', 'EEPD1',
#          'RPIA', 'FAM179B', 'GFOD2', 'TCEANC2', 'MVD', 'KRAS', 'RSPH1',
#          'FAM50B', 'LDB3', 'DDX20', 'FAM154B', 'CAND1', 'POLD2', 'SFR1',
#          'KDELC1', 'DIP2A', 'DLEU1', 'NPTN', 'UNC13D', 'IFT80', 'GTPBP2',
#          'WDR77', 'GANC', 'CPEB2', 'DEPDC1B', 'MEX3B', 'CCS', 'SARNP',
#          'TRIP6', 'ARMC5', 'ASB7', 'POLR3G', 'RPL28', 'CDK13', 'ZNF398',
#          'SERPINE1', 'NOLC1', 'WDR62', 'DCAF6', 'DCAF7', 'LOC100128164',
#          'TGS1', 'S100A14', 'HOXA1', 'S100A10', 'NCSTN', 'S100A12', 'TIGD4',
#          'COL25A1', 'PLK3', 'COQ10B', 'HCFC2', 'COPZ1', 'PTP4A1', 'NAA40',
#          'CFD', 'IPO13', 'TRIO', 'GNN', 'PLEKHA8P1', 'GNS', 'XPC', 'ENO3',
#          'RXFP4', 'PRDX5', 'BLOC1S2', 'KIAA1468', 'AP1S2', 'PNO1', 'SLC19A2',
#          'EXOC8', 'C1ORF27', 'RAB7L1', 'TRMT5', 'TTC9C', 'C16ORF61', 'GIPC1',
#          'MTF1', 'CLCF1', 'REL', 'PHF14', 'GAS6', 'GPR126', 'RNF145',
#          'DENND1B', 'ADM', 'CHP', 'DOM3Z', 'ADIPOR1', 'METTL21B', 'METTL21A',
#          'CSRP2', 'RHPN1', 'TIMP1', 'MIOS', 'LOC100131564', 'CEP55', 'TPRA1',
#          'ABHD14A-ACY1', 'ELMOD3', 'ANKHD1-EIF4EBP3', 'ELP4', 'DHRS3',
#          'MZT1', 'FAM104A', 'GUCA2A', 'HADHA', 'JKAMP', 'NUCB2', 'ANKRD42',
#          'LAMTOR2', 'RNF121', 'SMG5', 'SETD7', 'ING1', 'SMG7', 'PRSS22',
#          'GLI3', 'TMSB4X', 'NAMPT', 'ASH2L', 'ADAMTSL5', 'AP3S1', 'ROPN1L',
#          'TMEM38A', 'BRD9', 'DEDD', 'UVRAG', 'SEMA4B', 'YIPF3', 'USP3',
#          'RNF138P1', 'C1ORF126', 'YIF1A', 'RAB30', 'DISP1', 'MADD', 'ST7L',
#          'CNOT8', 'PSAT1', 'COPS2', 'MIR3646', 'MYLK-AS1', 'ZYX', 'RNF187',
#          'LINC00482', 'FAM129B', 'BZW2', 'C1ORF112', 'PAPSS2', 'FGD6',
#          'GCFC1-AS1', 'ASCC3', 'PHLDA2', 'TRAPPC3', 'CCDC18', 'EIF2B5',
#          'ESRRA', 'TRAPPC2', 'FAM103A1', 'HARBI1', 'AIP', 'OSBPL2', 'TTC21A',
#          'LSM1', 'LSM3', 'PITPNM1', 'LOC401588', 'MIR4710', 'RAB5A', 'RAB5B',
#          'EIF4G2', 'FAM49B', 'ANKRD33B', 'MOCS3', 'IRS2', 'CLSTN1',
#          'ANKRD12', 'INSIG1', 'C15ORF62', 'VTN', 'RHOBTB2', 'HSPBP1',
#          'MIR611', 'LOC339290', 'C1ORF50', 'C6ORF106', 'BAG3', 'TPR',
#          'LOC729506', 'PAPOLA', 'LOC100130451', 'SRGAP1', 'RFC2',
#          'ARL2-SNX15', 'DHCR24', 'MARCH6', 'MARCH5', 'CEBPZ', 'NES',
#          'MMACHC', 'OSCP1', 'CCDC41', 'MIR2110', 'LMBR1L', 'TARS', 'KLC1',
#          'LOC153684', 'METTL13', 'RIC8B', 'C15ORF39', 'DUSP10', 'PIP5KL1',
#          'DENND3', 'P2RY2', 'WASF1', 'WASF2', 'CEP170', 'MIR1250', 'METTL18',
#          'PAAF1', 'ZNF740', 'SPAG5', 'FBXL18', 'COBL', 'FBXL17', 'C1ORF86',
#          'C15ORF34', 'ASXL1', 'MIR4519', 'MAB21L3', 'C8ORF51', 'RUNDC1',
#          'CSNK1G3', 'CSNK1G2', 'UNC93B1', 'ADPGK', 'WDR3', 'TSSC1', 'WDR87',
#          'C1ORF131', 'HDAC7', 'ADAMTS5', 'SART3', 'WDR93', 'WDR92',
#          'MIR3652', 'CEP152', 'MIR3654', 'MIR1181', 'SLC35A4', 'IFRD1',
#          'YOD1', 'PUS7L', 'SLC35B1', 'LOC646626', 'CBLB', 'GLRX', 'DPCD',
#          'NSL1', 'C10ORF54', 'CHAC1', 'ZNF823', 'APBB3', 'TBL1X', 'FAM63A',
#          'SH3BGR', 'TRMT1L', 'GADD45B', 'MANF', 'CMC1', 'PARP14', 'IL17RB',
#          'RAET1E', 'CEP57L1', 'MIR4434', 'LOC100505783', 'KIAA0947', 'VEZT',
#          'TPI1P2', 'TMTC2', 'LOC100130855', 'GOLGA5', 'ASUN', 'GOLGA1',
#          'MARC2', 'TP53BP1', 'SKP2', 'HEG1', 'ITFG1', 'NME7', 'KRT16',
#          'FUBP3', 'ATM', 'MPND', 'MEGF9', 'AVPI1', 'SDCCAG8', 'ATR', 'TOMM6',
#          'UBXN1', 'FASTKD3', 'CAB39L', 'STIP1', 'PSMC3IP', 'SLC22A18',
#          'MLEC', 'MPZL1', 'TOR3A', 'NQO1', 'NQO2', 'MAP4K3', 'MPP5', 'MLH1',
#          'FAM46C', 'METTL1', 'FAM46A', 'BOLA3-AS1', 'COX4NB', 'PPP2CA',
#          'DNASE1L3', 'MAPRE3', 'LOC253039', 'AMIGO2', 'FAF2', 'PTGER4',
#          'AMN1', 'SERP1', 'EPB41L4A', 'CTNNA1', 'RSPRY1', 'CPSF7', 'CPSF2',
#          'LOC100302640', 'TRPC4AP', 'DPM1', 'LOC100506451', 'TMEM138',
#          'CDK2AP2', 'ABCG1', 'MPHOSPH6', 'KLHDC9', 'ABCG2', 'CIB2', 'HOXA11',
#          'CASKIN2', 'TCTEX1D4', 'LOC100506207', 'OPN3', 'ATP6V0B', 'C2ORF15',
#          'USP43', 'DNAJC14', 'C17ORF80', 'EIF2S1', 'NR4A3', 'ALDH3A2',
#          'DLG2', 'ARHGAP10', 'LOC100506233', 'PREPL', 'TMEM116', 'MGC23284',
#          'PRH1-PRR4', 'SEZ6L2', 'DTWD2', 'CHMP1A', 'POU2F1', 'RHBDD3',
#          'USP24', 'IQCG', 'PPP2R5B', 'IQCD', 'PARVA', 'IQCH', 'SENP1',
#          'PDE3A', 'ABCB8', 'PMEL', 'USP35', 'HS2ST1', 'FAM83G', 'HRH1',
#          'ERBB3', 'FAM83A', 'PDE4A', 'CXADR', 'RWDD3', 'RWDD1', 'OXSR1',
#          'FAM168A', 'RPS6KB2', 'LOC729013', 'VDAC1', 'SSBP4', 'ITGB3BP',
#          'ABCD3', 'THRB', 'SIX2', 'RPS6KA4', 'SEPT7', 'CHCHD4', 'SPRED1',
#          'CHCHD8', 'POLK', 'LRIG2', 'POLG', 'MAPK6', 'RBM7'], dtype=object)],
#  'BAF170_HELA-S3': [array(['SLC35A5', 'RPL22', 'WDPCP', 'FBXO3', 'IFRD2', 'IFT80', 'PUS7L',
#          'WDR77', 'LOC284440', 'PEX16', 'QTRTD1', 'GALNS', 'SPATA17',
#          'C19ORF44', 'APLF', 'UQCRC2', 'BAX', 'NHLRC2', 'LOC100289509',
#          'LETMD1', 'CALM3', 'ASF1B', 'ZNF277', 'ATP6V0D1', 'PRCC', 'WBP2',
#          'NPRL2', 'CPNE8', 'UQCR10', 'GPATCH2', 'EWSR1', 'PRCP', 'DCAF6',
#          'ZFYVE1', 'PNN', 'C19ORF51', 'FAM156A', 'CNST', 'CPNE2', 'UBAP2L',
#          'SNORA13', 'FAM63A', 'TCEB1', 'RPL19', 'BTRC', 'ST3GAL2', 'PKNOX1',
#          'S100A12', 'ATG3', 'PRKCI', 'TOP3A', 'C12ORF52', 'TFB2M', 'UCHL3',
#          'PAFAH2', 'COMMD6', 'MLLT11', 'MYL12A', 'C12ORF49', 'WNK1',
#          'C7ORF44', 'PDE12', 'HPD', 'SUGP1', 'KIAA0947', 'INTS9', 'PEMT',
#          'NMT1', 'LCORL', 'PTP4A1', 'CFD', 'C5ORF22', 'PAXIP1', 'C11ORF10',
#          'HHLA3', 'TTYH2', 'LOC152217', 'ACTR3C', 'OSGEP', 'NAGPA', 'SMC3',
#          'HSPH1', 'PRDX6', 'PTDSS2', 'PTDSS1', 'BLOC1S1', 'NEDD8-MDP1',
#          'NUDCD1', 'C7ORF55', 'ARSK', 'CCRN4L', 'LTA4H', 'BLOC1S1-RDH5',
#          'MIR4781', 'SEC62', 'BANP', 'ZBED5', 'SLC19A2', 'SKP2', 'RPS13',
#          'ACAD9', 'AKIRIN2', 'SSSCA1', 'C1ORF27', 'PHF12', 'ASH1L', 'TTC9C',
#          'TIMM22', 'C12ORF34', 'LRPPRC', 'C16ORF61', 'GIPC1', 'IMMP1L',
#          'DPYD', 'CLCF1', 'TUT1', 'STK40', 'SDCCAG8', 'TMEM106B', 'RANBP10',
#          'UBXN1', 'AHCTF1', 'FASTKD3', 'SEL1L', 'CLTC', 'NEDD8', 'TIMM10',
#          'HOXC13', 'METTL21B', 'ACTR1A', 'MRPL36', 'PRDM10', 'RAD51AP1',
#          'EXTL2', 'PPRC1', 'NKIRAS2', 'MTERFD1', 'TCP11L2', 'ATAD1', 'DFFA',
#          'DGAT2', 'ANKRD30BL', 'METTL1', 'HNRNPUL2-BSCL2', 'GCH1', 'SACM1L',
#          'CNPY2', 'ORMDL2', 'SYVN1', 'PRMT1', 'ELP4', 'SLC39A13', 'RNASE4',
#          'MRPL46', 'ZFP91-CNTF', 'MYO9B', 'PGM2L1', 'TMEM59', 'PER3',
#          'NR6A1', 'AGBL5', 'CTU1', 'HNRNPUL2', 'APEX1', 'FLJ22447',
#          'ANKRD42', 'DNASE1L3', 'RNF121', 'CD44', 'CD63', 'INVS', 'RNASEK',
#          'FAF2', 'AP2A1', 'MIR663A', 'SCARNA16', 'HSPA13', 'ZDHHC5', 'PTGS2',
#          'TMEM48', 'RPL18A', 'RNASEK-C17ORF49', 'ZNF687', 'ZNF444',
#          'ANKRD13A', 'MGEA5', 'UVRAG', 'RALBP1', 'BRPF1', 'CD164', 'PTCD3',
#          'GPT2', 'FBXO15', 'MITF', 'RPGRIP1L', 'ILF3', 'RAB30', 'MADD',
#          'MIR4738', 'ALDH4A1', 'MAU2', 'LOC100507300', 'FAM173B', 'ATG16L2',
#          'CNOT4', 'SPNS1', 'AMOTL2', 'LOC440356', 'IVNS1ABP', 'DCLRE1B',
#          'OXNAD1', 'MPI', 'DLST', 'ARID4A', 'BCCIP', 'ZFAND3', 'KLHL35',
#          'CWC27', 'WWTR1-AS1', 'PHRF1', 'C1ORF112', 'RNFT2', 'LMNA',
#          'LOC647323', 'LAMP1', 'RBBP6', 'GPBP1L1', 'DCLRE1A', 'TTC37',
#          'USP48', 'SLC30A7', 'ESRRA', 'SLC38A2', 'ATP6V0B', 'CCDC132',
#          'C11ORF82', 'GOT1', 'UROS', 'DCAKD', 'HARBI1', 'AIP', 'DDX54',
#          'HPS5', 'LRRC41', 'M6PR', 'DNAJC17', 'EIF2S1', 'C12ORF4', 'ALDH3A2',
#          'ISG20', 'LOC100506233', 'GNB2', 'MAP7D1', 'CFL1P1', 'DNMT1',
#          'RAD9A', 'EIF4G2', 'ANKRD33B', 'MOCS3', 'MAX', 'LRRC58', 'ATP8A1',
#          'ANKRD12', 'ARHGAP1', 'ARL1', 'UQCRH', 'ARHGAP5', 'MIR611',
#          'VCPIP1', 'KIAA0415', 'NIPBL', 'TPR', 'KIAA0895', 'C6ORF228',
#          'ZNF408', 'G3BP1', 'BRIX1', 'TSNAXIP1', 'RBM15', 'TTC13', 'RHBDD3',
#          'LAMB3', 'BOD1', 'IQCG', 'PPP2R5B', 'MARCH5', 'IQCH', 'AHSA1',
#          'CLCN7', 'CLCN6', 'G6PC3', 'MEIS1', 'C6ORF211', 'ESPL1', 'CDK5',
#          'NDUFS7', 'THRAP3', 'NDUFS6', 'AKT1S1', 'HAGH', 'CYCS', 'SMCR8',
#          'MMACHC', 'MIR2110', 'TMEM55B', 'CALR3', 'ENY2', 'AGPAT9', 'GSK3A',
#          'NPR3', 'USP35', 'LMBR1L', 'FBXO48', 'TARS', 'NDUFB1', 'DDX42',
#          'UFSP2', 'LOC153684', 'FLJ31306', 'TROVE2', 'PHTF1', 'RIC8B',
#          'HMBOX1', 'DPP9', 'BDNF-AS1', 'PMVK', 'UBE2Q1', 'ISOC2', 'FAM83A',
#          'MIR3676', 'C21ORF91', 'CEP290', 'WASF2', 'CEP170', 'TRIM44',
#          'METTL18', 'ZNF740', 'TAF15', 'LINC00111', 'NDUFA4', 'FEM1A',
#          'MYO10', 'MIR7-3', 'VTRNA1-2', 'BOLA1', 'LSR', 'TBX6', 'C15ORF34',
#          'HTR3A', 'CDC40', 'LYSMD1', 'ZFP91', 'MCOLN1', 'THAP5', 'RPIA',
#          'CD109', 'ANG', 'LOC100506713', 'TCEANC2', 'MET', 'EIF3B', 'CDCA7L',
#          'KRT80', 'MGRN1', 'LOC143666', 'WDR3', 'ZNF292', 'SLC4A2', 'PPM1L',
#          'FLCN', 'RPS6KA4', 'CHCHD4', 'POLK', 'ITGB8', 'CDIPT', 'RNMTL1',
#          'POLG', 'PLEKHH1', 'BUB3', 'GET4', 'EIF2A', 'NPTN'], dtype=object)],
#  'BATF_GM12878': [array(['POLR2J4', 'POLR2J2', 'FNBP1', ..., 'ABCD2', 'SCYL3', 'POLI'], dtype=object)],
#  'BCL11A_GM12878': [array(['POLR2J4', 'POLR2J2', 'POLR2J3', ..., 'ABCD2', 'MAPK6', 'POLI'], dtype=object)],
#  'BCL11A_H1': [array(['ZC3H10', 'RPS7', 'MIR135B', 'SEPP1', 'SCAMP4', 'ADAT3', 'TJP2',
#          'LOC646168', 'MIR367', 'LIN28B', 'REST', 'PER1', 'SNX16', 'PAM',
#          'HPD', 'HIST1H2BD', 'WDR49', 'POLDIP3', 'ZFP36L1', 'MIR302D',
#          'ZNF3', 'MIR302A', 'CHD2', 'ZBTB4', 'MIR302C', 'MIR302B',
#          'C12ORF57', 'LRRTM3', 'MIR4461'], dtype=object)],
#  'BCL3_A549': [array(['NIPSNAP3A', 'FNBP4', 'HEXIM1', ..., 'BPNT1', 'CAMK2G', 'LEKR1'], dtype=object)],
#  'BCL3_GM12878': [array(['BTBD19', 'WDR83OS', 'LNPEP', ..., 'SENP6', 'CHCHD7', 'POLG'], dtype=object)],
#  'BCL3_K562': [array(['MYLIP', 'HSD3B7', 'SLC35A2', 'C21ORF33', 'RPS8', 'FBXW9',
#          'DNAJB14', 'RFX1', 'SCRIB', 'ROCK1P1', 'MIR933', 'NEAT1', 'GTPBP5',
#          'C20ORF30', 'PDCL2', 'MSH4', 'FKBP8', 'ERP29', 'HIST1H4D',
#          'HIST1H4E', 'CD68', 'MIR3191', 'MIR3190', 'ADARB1', 'SLC1A5',
#          'HIRA', 'NOL7', 'EXOSC6', 'C10ORF103', 'LOC100506046', 'HERC1',
#          'PIP4K2B', 'HIST1H2AE', 'HIST1H2AH', 'TBL1X', 'SNORD74', 'ZC3H10',
#          'SNHG1', 'YES1', 'JUND', 'MLL5', 'TTC33', 'FAM54A', 'CCDC138',
#          'ABCA7', 'ARRDC3', 'OSBPL3', 'SYNRG', 'SECISBP2', 'MIRLET7I',
#          'SNHG9', 'VEZF1', 'B3GALT4', 'ASPSCR1', 'C6ORF120', 'SNHG5',
#          'HIST2H2BE', 'MOV10', 'DIAPH1', 'FIBP', 'NIT1', 'SNORD27',
#          'SNORD25', 'SNORD26', 'ADNP', 'POLG2', 'SSR4P1', 'EIF2C3', 'RGL2',
#          'C16ORF42', 'MIR3188', 'EZH2', 'MIR3187', 'GABARAP', 'TNFRSF6B',
#          'MAZ', 'ECI1', 'ROGDI', 'ANKRD12', 'BAZ2A', 'NAT14', 'C1ORF55',
#          'PWP2', 'ZBTB4', 'MRPL12', 'C12ORF57', 'RPS15', 'CHAF1B', 'ZNHIT2',
#          'AMDHD2', 'CCDC97', 'EIF4EBP3', 'SRD5A1', 'MIR3175', 'PIDD',
#          'BZRAP1', 'RHBDL1', 'PRRT2', 'NCBP2', 'LOC284801', 'CBX3', 'ZNF34',
#          'RAD23A', 'HMGA1', 'EPN1', 'TTI2', 'SUMF2', 'MTF1', 'BHLHE40',
#          'NAT10', 'SP4', 'GAS5', 'LOC100506779', 'SERINC4', 'LOC728743',
#          'LOC100507346', 'PSMG1', 'HMX3', 'ZC3H6', 'SLC3A2', 'LOC652276',
#          'CHD2', 'SAV1', 'SYCE2', 'MRPL40', 'SCFD1', 'NKIRAS1', 'SNAPC5',
#          'UBE2Q1', 'MIR4647', 'DNAJB4', 'DVL2', 'C8ORF82', 'TCP11L2',
#          'SNORA57', 'CEMP1', 'SNX8', 'SNORA56', 'C21ORF119', 'GCN1L1',
#          'RBM39', 'LOC400604', 'ZBTB37', 'PARP2', 'TMEM64', 'THOC6',
#          'ARID1B', 'APRT', 'TMEM60', 'THAP3', 'LOC646862', 'AGBL5',
#          'ENO1-AS1', 'FAM200B', 'RIT1', 'PER1', 'FOSB', 'TSSK6', 'SLC25A10',
#          'SNRPA1', 'CTXN1', 'DNASE1L2', 'HIST1H2BD', 'MIR3143', 'DHRS13',
#          'HIST1H2BO', 'NAPRT1', 'ZNF451', 'DHRS11', 'C11ORF54', 'XXYLT1',
#          'HSP90AB1', 'HIST1H2BK', 'POLDIP3', 'NDUFA13', 'HIST1H2BJ',
#          'CTNNB1', 'QRFP', 'MIR663A', 'POLB', 'AP4M1', 'MNT', 'PUF60',
#          'ROPN1L', 'LOC100506548', 'SNORD55', 'IGF2BP3', 'ENOPH1', 'SNORA78'], dtype=object)],
#  'BCLAF1_GM12878': [array(['HEXIM2', 'NIPSNAP3A', 'CASP8AP2', ..., 'LRIG1', 'BPNT1', 'ZNF169'], dtype=object)],
#  'BCLAF1_K562': [array(['POLR2J4', 'BTBD19', 'RFX3', ..., 'CDIPT', 'POLG', 'CHCHD2'], dtype=object)],
#  'BDP1_HELA-S3': [array(['C8ORF37', 'HSPA6', 'NCOA7', 'PEX3', 'ILF2', 'LOC643770', 'GSTA4',
#          'NDUFS7', 'POLR3E', 'PSMC3', 'HIST1H4H', 'RNU6ATAC', 'DAGLB',
#          'WBP4', 'RPN2', 'CASC5', 'CCDC107', 'MED16', 'FAM125A', 'MYNN',
#          'DPP9', 'PPP6R3', 'C16ORF13', 'C19ORF6', 'SLC25A44', 'HMGN4',
#          'CDKL4', 'SMARCC2', 'PLEKHG2', 'GABARAPL1', 'TIA1', 'SACM1L',
#          'ARNT', 'LOC644714', 'LOC100270746', 'RAB11A', 'AGBL5', 'SMU1',
#          'SNX16', 'B3GNT1', 'SLC27A4', 'MDM2', 'RABEPK', 'C7ORF55', 'LTA4H',
#          'RAC1', 'MLKL', 'POLG', 'HCG11'], dtype=object)],
#  'BDP1_K562': [array(['C8ORF37', 'HSPA6', 'NCOA7', 'NIPA2', 'VTRNA2-1', 'ILF2', 'FAM113B',
#          'GSTA4', 'NDUFS7', 'POLR3E', 'HIST1H4H', 'RNU6ATAC', 'WBP4',
#          'CASC5', 'SNAR-H', 'CCDC107', 'CGB2', 'MED16', 'CGB1', 'MYNN',
#          'LASP1', 'DPP9', 'PPP6R3', 'MIR4521', 'C16ORF13', 'C19ORF6',
#          'MIR3676', 'HMGN4', 'ALOXE3', 'SMARCC2', 'PLEKHG2', 'TIA1', 'PARP2',
#          'PRMT5', 'SACM1L', 'VTRNA1-3', 'LOC644714', 'LOC100270746',
#          'RNASE4', 'RAB11A', 'AGBL5', 'RPS29', 'ANG', 'B3GNT1', 'SLC27A4',
#          'SNAR-G2', 'SNAR-G1', 'RPPH1', 'PSMB3', 'C7ORF55', 'LTA4H', 'RAC1',
#          'POLG', 'HCG11', 'RMRP'], dtype=object)],
#  'BHLHE40_A549': [array(['B3GALNT2', 'HEXIM1', 'C5ORF15', ..., 'POLG', 'MAPK6', 'LEKR1'], dtype=object)],
#  'BHLHE40_GM12878': [array(['BAD', 'RC3H2', 'PRKAB1', ..., 'RMND5B', 'ABCD1', 'CAMK2G'], dtype=object)],
#  'BHLHE40_HEPG2': [array(['LOC613038', 'FNBP1', 'BTBD19', ..., 'LRIG1', 'LRIG3', 'CAMK2G'], dtype=object)],
#  'BHLHE40_K562': [array(['BAD', 'DHDH', 'RC3H2', ..., 'BTN3A3', 'FLJ39653', 'MAPT'], dtype=object)],
#  'BRCA1_GM12878': [array(['BTBD19', 'RC3H2', 'LNPEP', ..., 'ABCD1', 'CAMK2G', 'LEKR1'], dtype=object)],
#  'BRF1_HELA-S3': [array(['C8ORF37', 'SMARCC2', 'PLEKHG2', 'TIA1', 'HSPA6', 'NCOA7',
#          'PDE4DIP', 'SACM1L', 'VTRNA1-3', 'VTRNA1-2', 'VTRNA2-1', 'NBPF10',
#          'LOC644714', 'VTRNA1-1', 'ILF2', 'RAB11A', 'AGBL5', 'LOC643770',
#          'NDUFS7', 'POLR3E', 'SNX16', 'HIST1H4H', 'B3GNT1', 'SNORD6', 'WBP4',
#          'CASC5', 'MYNN', 'DPP9', 'C7ORF55', 'PPP6R3', 'C16ORF13', 'LTA4H',
#          'POLG', 'MLLT10P1', 'HCG11', 'SNORA1'], dtype=object)],
#  'BRF1_K562': [array(['C8ORF37', 'PLEKHG2', 'HSPA6', 'PRMT5', 'SACM1L', 'CASC5',
#          'LOC644714', 'VTRNA1-2', 'RAB11A', 'AGBL5', 'LASP1', 'DPP9',
#          'PSMB3', 'C7ORF55', 'NDUFS7', 'POLR3E', 'PPP6R3', 'C16ORF13',
#          'MIR3676', 'POLG', 'HMGN4', 'HCG11'], dtype=object)],
#  'BRF2_HELA-S3': [array(['MIR3193', 'RPPH1', 'PARP2', 'GSTA4', 'SNX16', 'C19ORF6', 'CCDC107',
#          'RNU6ATAC', 'MED16', 'RMRP'], dtype=object)],
#  'BRG1_HELA-S3': [array(['MLL5', 'LOC153684'], dtype=object)],
#  'BRG1_K562': [array(['DUSP1', 'LOC200261', 'EPT1', 'GP1BB', 'C1ORF55', 'C6ORF192',
#          'PKMYT1', 'MIR648', 'ATP2C1', 'PPOX', 'MIR301B', 'UBE2L3', 'CRKL',
#          'MYL12A', 'CAT', 'MIR4766', 'TEPP', 'GNB1L', 'THAP7-AS1',
#          'C22ORF29', 'LOC648691', 'MIR4276'], dtype=object)],
#  'CBX3_K562': [array(['BAD', 'DHDH', 'RC3H2', ..., 'CDS2', 'BAP1', 'CUTA'], dtype=object)],
#  'CCNE1_K562': [array(['LOC284801', 'LINC00273', 'MIR663B', 'MIR3687', 'MIR663A'], dtype=object)],
#  'CCNT2_K562': [array(['CASP8AP2', 'NIPSNAP3B', 'FNBP1', ..., 'LRIG1', 'ABCD1', 'CAMK2G'], dtype=object)],
#  'CDKN1B_K562': [array(['MIR3648', 'LOC284801', 'LINC00273', 'MIR3687', 'MIR663A', 'OPLAH'], dtype=object)],
#  'CEBPB_A549': [array(['ENDOG', 'FNBP4', 'BTBD19', ..., 'LOC339926', 'SCYL3', 'POLI'], dtype=object)],
#  'CEBPB_GM12878': [array(['NIPSNAP3A', 'CASP8AP2', 'FNBP4', ..., 'ABCD2', 'SCYL3', 'POLI'], dtype=object)],
#  'CEBPB_H1': [array(['HEXIM2', 'FNBP4', 'FNBP1', ..., 'LRIG1', 'CAMK2G', 'ABCD2'], dtype=object)],
#  'CEBPB_HCT116': [array(['C2ORF76', 'ARL15', 'ESCO1', 'TM4SF4', 'RC3H2', 'RFX2', 'ROCK1P1',
#          'NECAP1', 'EID1', 'NISCH', 'IL31RA', 'SLPI', 'FAM40A', 'RPL26',
#          'ZNF711', 'ALPK1', 'SNORA21', 'MT1F', 'CCNK', 'COL12A1', 'IWS1',
#          'CISD1', 'MIR549', 'MGC39372', 'PNN', 'SRPX2', 'LOC100128164',
#          'S100A14', 'CHAC1', 'E2F2', 'STAT6', 'TBL1X', 'GBP2', 'ABT1',
#          'PRPF38A', 'PMM1', 'EAF2', 'HAS2-AS1', 'ALG3', 'PLA2G4B', 'MLLT11',
#          'CDCP2', 'TCN1', 'PRR13', 'ATF6', 'CAPS2', 'RPS24', 'HDAC11',
#          'DCUN1D5', 'LPAR2', 'GMCL1', 'SYNCRIP', 'ZNHIT2', 'ZNF280A',
#          'OR10S1', 'LIPH', 'HMOX1', 'SEC62', 'HIST1H3D', 'PUSL1', 'GSDMC',
#          'ANXA1', 'NCOA7', 'ATPIF1', 'OSMR', 'MMP19', 'CLCF1', 'STK40',
#          'MIR3165', 'TINAGL1', 'HIST2H2AC', 'HIST2H2AB', 'BRCA1', 'MRPL38',
#          'ADIPOR1', 'SLC7A11', 'LOC100129858', 'PTPRG', 'APOLD1', 'C10ORF91',
#          'ERI1', 'MIS18BP1', 'C12ORF39', 'ANKRD1', 'RSU1', 'NFIL3', 'TIGD2',
#          'BRD4', 'ZNF221', 'CDKL4', 'RPA3', 'FMO4', 'LOC730755', 'PA2G4P4',
#          'LZTFL1', 'FLJ22447', 'DNASE1L3', 'PPARD', 'MIR3143', 'ANKRD13D',
#          'SETD3', 'CSTA', 'LOC646329', 'MRPS30', 'ADAM28', 'KRTAP2-4',
#          'TNKS1BP1', 'LINC00254', 'UBE2F', 'ZBTB10', 'PDAP1', 'ARHGAP24',
#          'MIR3649', 'ACAP3', 'LOC100507300', 'CYP24A1', 'RPL13AP5',
#          'C18ORF32', 'ABCG1', 'ULBP1', 'GOLT1A', 'ADAM9', 'YPEL5', 'MIR3193',
#          'MPG', 'CASC5', 'BEST1', 'SLC9A1', 'CLGN', 'ABLIM2', 'RAB20',
#          'C1ORF226', 'C1RL', 'COTL1', 'HIST1H2AD', 'BCL2L15', 'ABCF2',
#          'HIST1H2AC', 'CPA4', 'CAST', 'FAM26E', 'BUD31', 'TIMM44', 'INHBE',
#          'EIF2S3', 'SMAD6', 'FBXO32', 'HIST2H2BE', 'ISG20', 'TMEM114',
#          'EBPL', 'MALAT1', 'LCN2', 'LOC100190939', 'LOC285847', 'COX18',
#          'RPS19BP1', 'CUL2', 'PDS5A', 'GLIPR1', 'NRD1', 'UBB', 'SESN2',
#          'DTWD1', 'NARS', 'ZNF766', 'IL6R', 'ZNF641', 'TSFM', 'CBX4',
#          'PYCR1', 'RPL13A', 'GPX8', 'RAD23B', 'TTC19', 'MCC', 'ETV6',
#          'C4ORF46', 'SNORD114-28', 'ACOX3', 'MIR221', 'IRF2', 'FAAH2',
#          'LOC100506810', 'KCNK1', 'CUEDC1', 'SLC26A4', 'USP36', 'RNU4ATAC',
#          'DLX4', 'DAGLB', 'AGPAT9', 'CXCL2', 'DBI', 'C4ORF33', 'HK1',
#          'C1ORF158', 'MIRLET7A2', 'C4ORF34', 'P2RY8', 'LOC100128126', 'SPR',
#          'TMEM205', 'CASP4', 'DNAJB4', 'FAM83A', 'UBE2F-SCLY', 'RBM39',
#          'HIST1H2AM', 'POLQ', 'ATP2B4', 'C15ORF33', 'SGPP2', 'SGPP1', 'LTBR',
#          'LOC100132707', 'SPRY4', 'LRIF1', 'HIST1H2BF', 'RBM45', 'TRIB1',
#          'HIST1H2BD', 'HIST1H2BO', 'PLEKHH3', 'STEAP4', 'ARHGAP11A',
#          'HIST1H2BK', 'TM2D2', 'HIST1H2BJ', 'LOC257358', 'MIR3926-2', 'SRI',
#          'ZBTB44', 'DDX60L', 'ECE2', 'CECR2', 'SLC25A28', 'PALMD', 'SFR1',
#          'TRIM25', 'WDR7', 'CAMK2G', 'POC1A'], dtype=object)],
#  'CEBPB_HELA-S3': [array(['BAD', 'DHDH', 'PRKAB1', ..., 'ABCD1', 'CAMK2G', 'ZNF169'], dtype=object)],
#  'CEBPB_HEPG2': [array(['HEXIM2', 'FNBP4', 'FNBP1', ..., 'PSTK', 'CAMK2G', 'ZNF169'], dtype=object)],
#  'CEBPB_IMR90': [array(['FNBP4', 'FNBP1', 'BTBD19', ..., 'ZNF169', 'POLI', 'POLH'], dtype=object)],
#  'CEBPB_K562': [array(['HEXIM2', 'NIPSNAP3B', 'FNBP4', ..., 'PSTK', 'CAMK2G', 'ZNF169'], dtype=object)],
#  'CEBPD_HEPG2': [array(['FNBP4', 'FNBP1', 'BAD', ..., 'ABCD1', 'CAMK2G', 'LEKR1'], dtype=object)],
#  'CEBPZ_HEPG2': [array(['CASP8AP2', 'ACOT8', 'TMX2-CTNND1', 'FNBP4', 'NGDN', 'ZFYVE21',
#          'GATAD2A', 'RFX1', 'FLJ42351', 'HN1', 'FAM158A', 'MIR658',
#          'GATAD2B', 'DDX39A', 'ARMC1', 'SARNP', 'ZSCAN20', 'C19ORF42',
#          'HNRNPC', 'ALG10B', 'ASF1B', 'MTMR4', 'TESK2', 'NAIF1', 'GABPB1',
#          'NAA60', 'PDXP', 'DCAF7', 'TPRG1L', 'C19ORF51', 'GNG2', 'ASNA1',
#          'GTPBP1', 'C19ORF55', 'TFG', 'CREB3L2', 'LOC100507373', 'NUP88',
#          'NCSTN', 'C5ORF34', 'BATF2', 'ZNF143', 'PRR11', 'ZNF384', 'ATP6AP2',
#          'EDEM2', 'EDEM3', 'NR1D1', 'NR1D2', 'C12ORF51', 'THAP10', 'GPR137C',
#          'ZNF17', 'EIF6', 'SIVA1', 'HBP1', 'ZNF138', 'CETN4P', 'CEP68',
#          'FAM108B1', 'TDRKH', 'C5ORF22', 'CDCA3', 'ZNF493', 'ITSN1',
#          'MRPL18', 'SUV420H2', 'ALKBH6', 'BLOC1S3', 'ZNF20', 'RPL36',
#          'CDK5RAP3', 'PRKACA', 'SDF2L1', 'DUSP6', 'JUP', 'ATPIF1', 'TCP1',
#          'TYW1B', 'C9ORF85', 'C6ORF62', 'TRMT1', 'TTLL5', 'C12ORF26',
#          'INCENP', 'ZNF724P', 'CENPO', 'RNF141', 'PCYOX1L', 'CEP44', 'CDKN3',
#          'FXC1', 'ZNF597', 'SNORA60', 'ZNF44', 'ABHD8', 'TMEM160', 'RASAL2',
#          'MRPL37', 'FAM113A', 'MED19', 'PRDM10', 'TRIM4', 'PNPO', 'HMGXB4',
#          'PACSIN2', 'DLGAP5', 'ZNF101', 'YTHDF1', 'STAT2', 'ANKHD1-EIF4EBP3',
#          'SYVN1', 'F2', 'MIR638', 'TUBB4B', 'TMEM60', 'CASD1', 'TOM1L2',
#          'XAB2', 'SPSB3', 'NUDT21', 'RFWD3', 'SNX18', 'TMEM57', 'C16ORF80',
#          'PTRH2', 'FRYL', 'ZNF574', 'SETD5', 'CCL15', 'ZNF211', 'FH',
#          'ZNF691', 'MTMR12', 'NDUFA11', 'SETD8', 'TMEM53', 'SMG8', 'CENPA',
#          'TP53TG1', 'PSMB3', 'PSMB1', 'PWWP2A', 'ANKRD54', 'STRA13',
#          'TMEM38A', 'SBDSP1', 'ZNF687', 'ZSWIM3', 'ZNF202', 'ZSWIM4',
#          'ZNF443', 'ZNF564', 'MAP3K3', 'UVRAG', 'MAP3K4', 'SLC39A1', 'FKBPL',
#          'USP5', 'FBXO18', 'DOLPP1', 'YIF1A', 'VMAC', 'ACAP2', 'STIM2',
#          'CNOT3', 'KAT6B', 'UQCRQ', 'TRAFD1', 'ZNF799', 'PCNXL3', 'ZNF556',
#          'LRCH4', 'ZNF555', 'ZNF430', 'ANKRD39', 'PUS10', 'FAM117A',
#          'KATNB1', 'TSPAN31', 'MPV17L2', 'HSP90B1', 'ZBTB20', 'C1ORF228',
#          'FRZB', 'LOC100287177', 'RUVBL2', 'SLC25A42', 'ZNF548', 'SPOP',
#          'KIAA1609', 'LRRC48', 'RAB4B', 'C21ORF56', 'OSBPL2', 'TRAF2',
#          'LRRC45', 'MED29', 'FRMD5', 'DDOST', 'METTL22', 'TRAF7', 'GPR108',
#          'FTL', 'MAP3K14', 'ZNF776', 'RAB5B', 'PFKFB1', 'MDM1', 'PIN1',
#          'ANKRD16', 'RAB3A', 'AK2', 'LOC284632', 'UBP1', 'LOC340544',
#          'LIN7C', 'EDC3', 'STK11', 'UROD', 'G3BP1', 'ANKRD11', 'NFATC2IP',
#          'TMEM167A', 'EVI5L', 'HACL1', 'MAF1', 'ZNF883', 'SNORD12B', 'VBP1',
#          'HMGCS1', 'EIF2AK3', 'LOC644656', 'TPCN1', 'CYB5A', 'SP1', 'SARS2',
#          'CYP2G1P', 'ZNF519', 'PCNA-AS1', 'LOC374443', 'NF2', 'DCTPP1',
#          'PIK3C3', 'NFE2L1', 'LOC257396', 'TNRC6B', 'NFE2L2', 'MCM3', 'NUMB',
#          'NUFIP1', 'WHAMM', 'GLO1', 'LMBR1L', 'HMMR', 'MLLT1', 'C15ORF42',
#          'C15ORF44', 'FLJ31306', 'METTL13', 'PTBP1', 'MGC16025', 'ATP5B',
#          'FCHO2', 'ATP5H', 'DNAJB5', 'PPP6R3', 'DNAJB4', 'MIR4647', 'ZNF626',
#          'IP6K1', 'BCAS3', 'TRIM45', 'HN1L', 'MMAB', 'CKAP2L', 'MAGI3',
#          'KIAA1683', 'HDGFRP2', 'BPGM', 'MTOR', 'TBX3', 'KPNB1', 'LENG1',
#          'PPM1B', 'SNRNP40', 'P4HB', 'MIR1243', 'TRIM35', 'EIF4A1', 'NXT1',
#          'HDAC4', 'C1S', 'AKAP8L', 'PBXIP1', 'TPRN', 'SLC25A28', 'HECTD3',
#          'PRADC1', 'MIR3652', 'FLAD1', 'ATP7B', 'HNRNPA1', 'SLC25A25',
#          'DCAF15', 'TMEM194A', 'JMJD5', 'GOLPH3L', 'PC', 'HIST1H4C',
#          'PPP1R3F', 'ZNF714', 'ANP32E', 'RIN1', 'WBP1', 'FGL1', 'SLC35B1',
# ...
#          'ILF2', 'MIR933', 'NEAT1', 'LOC100129427', 'COPS5', 'COPS4',
#          'CNOT8', 'LOC643770', 'YEATS4', 'MSH6', 'PKP2', 'SNRPF', 'PDCD2',
#          'PHIP', 'AJUBA', 'CNIH3', 'KIAA0528', 'FKBP7', 'ZNF433', 'FRA10AC1',
#          'SLC25A36', 'KCNG3', 'C11ORF74', 'FKBP2', 'ANKRD39', 'SRSF1',
#          'CTNND2', 'CASC5', 'MIR374A', 'CASC4', 'SLC9A1', 'DSCR3', 'CTGF',
#          'RAB26', 'RBBP5', 'HAS2', 'RNF19A', 'ANKRD36BP2', 'MACROD1', 'STX6',
#          'ZNF669', 'C19ORF6', 'SLC39A8', 'ZNF546', 'RHBG', 'HMGN4',
#          'KRTAP3-1', 'LINC00479', 'SEMA6A', 'CCDC19', 'FANCL', 'NOP16',
#          'TIA1', 'FANCM', 'SHFM1', 'MED28', 'FANCG', 'MED23', 'TMEM18',
#          'MED25', 'SLC27A4', 'MAX', 'CD274', 'UPK2', 'METTL2A', 'WISP2',
#          'RHOBTB3', 'NHSL1', 'VPS72', 'NIPBL', 'FNTB', 'SALL4', 'PLS1',
#          'PABPC4L', 'LOC100506939', 'BOD1', 'MACC1', 'PA2G4', 'OSGIN2',
#          'EIF2AK3', 'AHSA2', 'GPX8', 'GPR98', 'AIM1L', 'TPRKB', 'OSGIN1',
#          'PARD3B', 'NIPSNAP1', 'C15ORF58', 'MARCH4', 'BCL9', 'C6ORF211',
#          'RPL21P28', 'SYF2', 'MFAP3', 'ESRP1', 'RMND1', 'ZG16B', 'TNRC6A',
#          'TRIM56', 'MCM3', 'IREB2', 'ZNF750', 'MIPEP', 'PLEKHF2', 'ZC3H6',
#          'CELF3', 'UFSP1', 'KLC1', 'FSD1L', 'RIC8B', 'PPP6R1', 'PIP5KL1',
#          'PPP6R3', 'ME1', 'DNAJB9', 'MIR3676', 'KIAA0319', 'ACP2', 'TRIM44',
#          'MIR4761', 'ZNF860', 'NDUFA9', 'LINC00111', 'PLEKHG2',
#          'LOC100505989', 'LINC00112', 'FEM1B', 'CYP51A1', 'UGT2B15', 'DST',
#          'LRRC8A', 'KRR1', 'MID1IP1', 'FBXL18', 'FOXJ3', 'RPRD2', 'ARNT',
#          'PRC1', 'C15ORF33', 'TSN', 'CLEC2A', 'P2RX7', 'RAD52', 'PPM1D',
#          'CTDSP1', 'SYT12', 'MIR4513', 'SYT11', 'ANG', 'LOC100130880',
#          'MIR4754', 'SEC22B', 'CBLL1', 'AGXT', 'CDCA7L', 'DYSF', 'SRI',
#          'TTK', 'PIK3C2G', 'HSD17B11', 'HDAC7', 'PPM1H', 'ZNRF1', 'EFR3B',
#          'LOC100287036', 'OPA1', 'UBQLN1', 'ERC1', 'MIR3654', 'ITGB8',
#          'ITGAV', 'SLC25A24', 'POLR2K', 'IFRD1', 'KRT5', 'GIN1', 'TM4SF4',
#          'GOLPH3L', 'KRT8', 'CTNS', 'SEPP1', 'PEX13', 'FLJ40852', 'FRAS1',
#          'MAPK10', 'MGP', 'HIST1H4H', 'CALM2', 'OBSL1', 'RIN1', 'WFDC13',
#          'STXBP1', 'STX16', 'ANKRD19P', 'TIFA', 'CBLB', 'MYL12B', 'CRKL',
#          'STS', 'RPL36AL', 'PARD6B', 'NIPAL1', 'NIPAL2', 'C1ORF151-NBL1',
#          'MIR4328', 'TBL1X', 'CHAC2', 'POF1B', 'N4BP3', 'FMO9P', 'DTNA',
#          'GLIPR1L1', 'LIX1L', 'ARRDC3', 'ST8SIA4', 'PLA2G4B', 'IGFL4',
#          'NMBR', 'COMMD2', 'PUM2', 'OVOL2', 'DOPEY2', 'CCDC88C', 'BBS12',
#          'CCDC88A', 'RPS29', 'ANKRD18A', 'MIR4675', 'RAET1L', 'LOC100506994',
#          'PAEP', 'CDS1', 'IL1RN', 'SLC45A4', 'RFESD', 'TPI1P2', 'MPHOSPH10',
#          'NUMA1', 'LOC100129917', 'TMTC2', 'TTBK2', 'TNS1', 'NUDCD1',
#          'C7ORF55', 'PCBP2', 'PPAT', 'CCDC99', 'HIST1H3J', 'FFAR2',
#          'HIST1H3D', 'LGALS8', 'DECR1', 'FEZF1', 'LOC100379224', 'NCOA7',
#          'GREB1', 'LOC400027', 'FLJ10038', 'NBPF1', 'ID1', 'RNU6ATAC',
#          'TFF1', 'ATR', 'LOC100506776', 'IGSF9', 'MRPS14', 'CITED2',
#          'TMPRSS4', 'SLC44A1', 'CCDC107', 'PTPRH', 'PCF11', 'NEU1', 'RRAS',
#          'ANKRD2', 'ANKRD1', 'CLIC3', 'UBXN7', 'ADIPOQ', 'MON2', 'DMRT2',
#          'FAM46C', 'DNAJC5B', 'PARP2', 'PRMT5', 'MRPS23', 'FTSJD1', 'ANO6',
#          'RAB11A', 'PA2G4P4', 'TJP2', 'TJP1', 'CMPK2', 'ESYT3', 'B3GNT1',
#          'XGPY2', 'FOXA1', 'MLF1IP', 'FAF1', 'HEATR2', 'GBE1', 'PTGER4',
#          'AP4E1', 'SLC20A1', 'N4BP2L2', 'MRPS31', 'CRIP2', 'SH3RF2', 'CNIH',
#          'MGAT2', 'HEATR6', 'FLJ42969', 'CD55', 'GINS2', 'TGFB2', 'ATG9B',
#          'ZNF76', 'RSBN1', 'GRHL2', 'ALG10', 'TATDN1', 'XG', 'BATF', 'UEVLD',
#          'FLJ35776', 'GSTA4', 'UBE2T', 'POLE3', 'WDFY2', 'TGFBI', 'SPNS1',
#          'GOLT1A', 'AMOTL2', 'KLHDC9', 'IVNS1ABP', 'RAF1', 'DCLRE1B',
#          'PRUNE', 'ZFAND4', 'NRK', 'CPOX', 'CCND1', 'SH3TC2', 'CAPN8',
#          'STX16-NPEPL1', 'CLASP1', 'SPTSSB', 'HIST1H2AD', 'HGD', 'SLC30A6',
#          'TTC32', 'DSTN', 'A2ML1', 'NUP155', 'TMPRSS11F', 'ESR1', 'SYT8',
#          'HIST2H2BE', 'NR4A3', 'POLG2', 'MUC20', 'MIR3622B', 'SAE1', 'HOMEZ',
#          'LZIC', 'COX16', 'GOLT1B', 'GSTCD', 'ARHGAP17', 'TTF2', 'KCNV1',
#          'TGM1', 'CALHM3', 'ZCWPW1', 'CDH26', 'ZC3H15', 'PDZD8', 'VWC2L',
#          'TIPARP', 'TTC14', 'SMURF2', 'CYP3A43', 'CBX3', 'LOC285456',
#          'UPK1A', 'URB1', 'IQCK', 'LOC100507584', 'MEIS1', 'RBL2', 'NDUFS7',
#          'PIKFYVE', 'ELF5', 'DPPA2', 'NDUFS4', 'C17ORF110', 'ZMYND11',
#          'RBM25', 'TTC26', 'ESRG', 'DNAH3', 'USP32', 'NPR3', 'ZNF193',
#          'ZNF192', 'SNORD114-1', 'SNORD114-2', 'AFF1', 'FAM188A', 'SCIN',
#          'DPP9', 'ERBB3', 'FAM83A', 'BLNK', 'USP30', 'SNAPC1', 'TBP',
#          'RBM39', 'HSDL2', 'PDE4D', 'LOC90246', 'TBC1D9', 'VTRNA1-2',
#          'OXSR1', 'FNDC3A', 'LSR', 'FAM168A', 'YWHAZ', 'C14ORF135', 'U2SURP',
#          'IRGQ', 'TBC1D2', 'MLPH', 'TRAPPC6B', 'FAM179B', 'TOMM70A', 'NUP35',
#          'KIAA0907', 'MST1P2', 'DKFZP434J0226', 'HIST1H2BF', 'SSBP1',
#          'FAM98B', 'SSBP2', 'RBM47', 'TMEM55A', 'TRIB1', 'RBM45', 'KDM3A',
#          'USP15', 'ABCD3', 'STEAP4', 'KRT80', 'POLDIP3', 'TUFT1', 'SIX2',
#          'CLCN4', 'JPX', 'SPRED2', 'RBM3', 'SIX5', 'NT5DC3', 'PDSS1', 'POLG'], dtype=object)],
#  'ZNF263_HEK293': [array(['FNBP1', 'BAD', 'BTBD19', ..., 'LRIG2', 'CXORF26', 'ABCD2'], dtype=object)],
#  'ZNF263_K562': [array(['SLC12A4', 'UNC13D', 'ACVR1', 'NHLRC4', 'LINC00094', 'SFMBT1',
#          'HOMER1', 'EBF1', 'GTPBP3', 'EREG', 'ASPHD1', 'C7ORF23',
#          'LOC100128292', 'DCHS2', 'SUCLG2', 'CDK13', 'CAHM', 'LOC147646',
#          'CYFIP1', 'STX16', 'SGMS1', 'SATB2', 'SLC35B2', 'LINC00085',
#          'DCAF5', 'SNX30', 'KIAA1328', 'MAGEA8', 'RAB11FIP2', 'EXPH5',
#          'ANKS1B', 'ZNF148', 'C22ORF29', 'EGR1', 'SLC6A18', 'TFB2M', 'PBX2',
#          'PBX1', 'FCHSD2', 'FOSL2', 'SLC6A8', 'BCAN', 'SLC6A9', 'SFXN2',
#          'GLIPR1L2', 'C2CD2L', 'RPS25', 'FANK1', 'TPI1P2', 'ECI2', 'TSHZ3',
#          'TCL1B', 'LOC100506068', 'RAVER1', 'FASTK', 'HIVEP2', 'RALGPS1',
#          'LTA4H', 'MNX1', 'NCOA2', 'CCDC111', 'MAD2L1BP', 'SAMD4A',
#          'PRPF40A', 'VAV1', 'TMEM37', 'C16ORF61', 'KIF9', 'FRG1', 'CENPJ',
#          'BHLHE40', 'MIR17HG', 'LOC441009', 'PI4KA', 'ATM', 'CRELD1', 'SYNC',
#          'LOC100506776', 'LOC100292680', 'ZCCHC11', 'EBI3', 'TMEM164',
#          'METTL21A', 'CHRAC1', 'GJC2', 'PPP3CA', 'MED15', 'MRPL40', 'TFE3',
#          'RCE1', 'KIF1B', 'ATXN1', 'MPP3', 'CDKN2C', 'DBNL', 'MIR99B',
#          'ANKRD30BL', 'FLJ20021', 'MRPS23', 'UBE2E2', 'ZDHHC14', 'TTC7A',
#          'SLC39A13', 'MIR636', 'LOC100129845', 'SCAF4', 'MORN1', 'ENO1-AS1',
#          'CTTN', 'NEDD4', 'ESYT2', 'SLC29A4', 'LLGL2', 'SLC22A23', 'HRSP12',
#          'FOXA1', 'MIA3', 'QRFP', 'MIR663A', 'ING2', 'MRPL55', 'GLI3',
#          'C16ORF72', 'DFNB59', 'TUBA1C', 'NUF2', 'ADRBK2', 'PRAME', 'CD58',
#          'REV3L', 'RALBP1', 'LOC338799', 'PPIL2', 'CA11', 'FBXW11',
#          'FLJ27354', 'PTCD1', 'TPM4', 'APLP2', 'SHISA5', 'HIPK2', 'FOXP4',
#          'ENKUR', 'SUPT7L', 'CTDNEP1', 'ATG16L2', 'SRSF3', 'STEAP3', 'LRP12',
#          'GTF2I', 'KANK1', 'SLC25A40', 'SRSF2', 'ZFAND3', 'PHRF1', 'CASC2',
#          'HIRA', 'GALNT11', 'DOCK11', 'BCL2L11', 'PAK1', 'KIAA0754',
#          'STX16-NPEPL1', 'COTL1', 'NPHP4', 'ZNF668', 'ZNF425', 'SLC16A3',
#          'C11ORF67', 'ZNF786', 'WHSC1L1', 'SEMA6C', 'MLL4', 'MLL5', 'NOP16',
#          'MIRLET7E', 'POU3F2', 'DDOST', 'TFDP1', 'SYNJ2', 'DLG5', 'LHX2',
#          'RCAN3', 'GNAQ', 'STT3B', 'MAP7D1', 'MIR4710', 'LHX6', 'PHPT1',
#          'FGFR3', 'EIF4G3', 'ANKRD33B', 'WHSC1', 'INSIG1', 'WWC3', 'TRIAP1',
#          'ARHGAP1', 'SEZ6L2', 'IGF1R', 'CAMSAP2', 'RGS5', 'SYDE2', 'SCMH1',
#          'BAG3', 'ZNF768', 'C6ORF108', 'RGS9', 'BZRAP1', 'SEMA7A', 'ZNF643',
#          'SRGAP1', 'ZFHX2', 'USP25', 'SETD1A', 'ECD', 'CRYGN', 'IQCD',
#          'BAIAP2', 'LINGO1', 'MIR125A', 'MARCH3', 'SON', 'GNL3L', 'FLJ90757',
#          'CDK8', 'LOC100506012', 'C7ORF60', 'CDK5', 'IRF2', 'VSTM2L',
#          'ERBB2IP', 'ARMC10', 'CBLN3', 'AHDC1', 'MCTP1', 'AGPAT9',
#          'LOC100506804', 'PTPN23', 'ATP5I', 'HMGB2', 'UFSP1', 'DUSP16',
#          'ITPR1', 'PITPNC1', 'NPAT', 'FGGY', 'DPP7', 'CASP8', 'SEP15',
#          'FBXL19-AS1', 'MAN1A2', 'SNAP29', 'ATRIP', 'ZNF740', 'LOC400680',
#          'TBX1', 'IRX5', 'NFKBIL1', 'OXSR1', 'TPD52L2', 'THAP5', 'FAM155A',
#          'PFKL', 'APOC1', 'PPDPF', 'P4HB', 'GNB1L', 'SPRY2', 'MIR4632',
#          'SLC25A6', 'ANAPC2', 'ZMYND8', 'THRB', 'MCM8', 'SOWAHD', 'SLC4A2',
#          'PPM1L', 'ADAMTS3', 'LOC728730', 'SPRED1', 'FLJ33065', 'MIR3656',
#          'DIP2A', 'IGF2BP3'], dtype=object)],
#  'ZNF274_GM08714': [array(['MRFAP1L1', 'FANK1', 'MIR4273', 'ANKRD30BL', 'LOC100526771',
#          'CPXM1', 'ROCK1P1', 'MIR663A'], dtype=object)],
#  'ZNF274_GM12878': [array(['PSMB5', 'MIR4273', 'MRPS23', 'HEATR5A', 'LOC100526771', 'BAZ1A',
#          'CHMP4A', 'MLLT10P1', 'SNX6', 'C14ORF126'], dtype=object)],
#  'ZNF274_H1': [array(['MIR4273', 'ANP32B', 'USP3', 'MIR135B', 'IER5L', 'ROCK1P1',
#          'MIR663A', 'SNX16', 'LOC100526771', 'NR2C2AP', 'LOC100130581',
#          'MAP7D1', 'MIR548H4', 'CHMP7', 'MLLT10P1', 'MIR4461', 'OR4D5',
#          'ATP6V1B2'], dtype=object)],
#  'ZNF274_HELA-S3': [array(['MIR4273', 'KCNJ18', 'ROCK1P1', 'MIR663A'], dtype=object)],
#  'ZNF274_HEPG2': [array(['MIR4273', 'SNORD116-9', 'LOC100526771', 'ROCK1P1', 'SNORD116-3',
#          'MIR4461'], dtype=object)],
#  'ZNF274_K562': [array(['C2ORF77', 'RFX1', 'LOC100289187', 'GTPBP3', 'PRKAB1', 'COMTD1',
#          'PEX14', 'SNORD116-10', 'ZNF718', 'POLR3E', 'TMEM79', 'HIST1H4I',
#          'CKLF', 'SNORD116-6', 'ZNF398', 'SNORD116-8', 'USP6NL', 'HM13',
#          'LRP6', 'SNORD116-2', 'MYL12B', 'CRKL', 'PRPSAP1', 'KCNQ1OT1',
#          'HERC1', 'LOC100506844', 'SNORD76', 'UBASH3A', 'SNORD77', 'HES4',
#          'C22ORF29', 'MIR4441', 'NDFIP1', 'ABCA3', 'TIGD5', 'TOP3B', 'SNHG9',
#          'C12ORF52', 'COMMD2', 'CBFA2T3', 'GPN3', 'MYL12A', 'MIR92A1', 'POR',
#          'KLHDC8B', 'C7ORF42', 'C19ORF24', 'LOC727710', 'FLVCR1-AS1',
#          'MIR20A', 'IPO13', 'PRKDC', 'ZBTB4', 'MRPL12', 'PTDSS1', 'PRDX5',
#          'C7ORF55', 'ZNF280B', 'ANPEP', 'GOLGA1', 'MIR570', 'LTA4H', 'ZBED4',
#          'SDF2L1', 'WARS', 'STRADA', 'MST1', 'RHOF', 'ASH1L', 'CARD6',
#          'FRG1B', 'FRG1', 'BHLHE40', 'MIR17HG', 'PI4KA', 'SNORD2',
#          'RNU6ATAC', 'HMX3', 'ZNF595', 'GYPB', 'SNORA14B', 'LOC100506649',
#          'SUV39H1', 'OTUD7B', 'AKAP17A', 'HIST2H2AC', 'ADIPOR1', 'IQGAP2',
#          'TIMM10', 'PPCDC', 'CYB561D1', 'STYXL1', 'MYNN', 'TRMT112',
#          'CHRAC1', 'LOC729444', 'MED15', 'MRPL40', 'FAM100A', 'MTERFD1',
#          'TCP11L2', 'EMD', 'FLVCR1', 'CD33', 'ZNF582', 'FAM46C', 'PRMT5',
#          'ANKRD45', 'RANBP1', 'SACM1L', 'ELP2', 'LOC644714', 'TMEM64',
#          'RNASE4', 'RAB11A', 'MYO9B', 'MIR19A', 'RANBP9', 'C6ORF162',
#          'MIR301B', 'AGBL5', 'ABCB10', 'ZNF487P', 'NDUFAB1', 'SNX16',
#          'HNRNPH3', 'B3GNT1', 'ESYT2', 'RNF123', 'ZNF696', 'TRUB2',
#          'ANKRD13D', 'SNORA16A', 'LOC253039', 'ZNF451', 'PGCP', 'MRPS34',
#          'HEATR2', 'NUDT3', 'MIR663B', 'MIR663A', 'AMN1', 'FAM3C',
#          'LOC100506305', 'HIST3H2BB', 'MIR4461', 'SNORA78', 'KIAA0090',
#          'C8ORF37', 'CRBN', 'LOC386758', 'ILF2', 'AKR7A2', 'TRPC4AP',
#          'GFI1B', 'RAB32', 'CKLF-CMTM1', 'SYPL1', 'MSH4', 'EHBP1L1', 'CR1L',
#          'RAB36', 'FKBP8', 'PHIP', 'BRWD1', 'STAM2', 'LZTR1', 'ZNF555',
#          'RNF32', 'ZWILCH', 'C21ORF49', 'ODC1', 'MIR3190', 'NOL8', 'CASC5',
#          'ATAD2B', 'ATP2C1', 'TMEM241', 'SLC9A1', 'HIRA', 'EIF4ENIF1',
#          'MIR4729', 'TMEM127', 'TBC1D14', 'NBN', 'C16ORF13', 'SLC39A6',
#          'HIST1H2AE', 'C19ORF6', 'HMGN4', 'MLL3', 'MIR4273', 'MLL4',
#          'EIF2B4', 'SHFM1', 'DCAKD', 'DDX54', 'SNORD18A', 'KIAA0430',
#          'MIR21', 'C20ORF132', 'SNORD18B', 'HIST2H2BE', 'LSM3', 'DIAPH1',
#          'NR4A2', 'DMXL1', 'RHEB', 'SNORD27', 'SNORD28', 'CAPRIN2', 'TADA3',
#          'MIR1205', 'SNORD26', 'ADNP', 'SNORD22', 'C16ORF48', 'BCAT1',
#          'TSG101', 'CNO', 'TACO1', 'C1ORF55', 'FBXO24', 'TM7SF3', 'RHOBTB3',
#          'FGF7', 'EEF2K', 'KIAA0895', 'SNORD12', 'LOC100130691', 'CEP350',
#          'SNORD50B', 'WHSC2', 'MIR3175', 'COA5', 'SNORD12B', 'ARFGEF1',
#          'HSPA6', 'RHBDD1', 'TMPPE', 'LOC644656', 'MARCH8', 'HMGA1', 'TTI2',
#          'AHI1', 'COQ4', 'CLCN6', 'RABEP2', 'ESPL1', 'NDUFS7', 'DNLZ',
#          'ATG4D', 'SNORD46', 'SNORD44', 'LOC100507346', 'MIR4651', 'IDI1',
#          'UFD1L', 'ABCB8', 'AMD1', 'SLC3A2', 'MTIF2', 'SNORD49A', 'SNORD49B',
#          'C7ORF73', 'GRK4', 'CA1', 'DPP9', 'PPP6R1', 'MIR4766', 'FAM164C',
#          'PPP6R3', 'DNAJB4', 'PDE4A', 'METTL19', 'MBTPS1', 'MIR19B1',
#          'EIF3A', 'WTAP', 'NOS3', 'ARID1A', 'LSR', 'LOC100270746', 'TBX6',
#          'WRAP73', 'GLB1', 'KLF6', 'HIST1H2BG', 'SNORD68', 'ANG', 'GNB1L',
#          'EFHA1', 'THAP7-AS1', 'ZP3', 'HIST1H2BD', 'HDAC1', 'POLDIP3',
#          'HIST1H2BJ', 'HDAC2', 'NOB1', 'ARHGDIA', 'CDC45', 'RMND5B', 'EXO1',
#          'TAS1R1', 'LOC100526771', 'DIP2A', 'SNORD54', 'SNORD55', 'ADSS',
#          'POLG', 'KCNJ1', 'CHCHD2', 'HCG11'], dtype=object)],
#  'ZNF274_NT2D1': [array(['PRPS2', 'MIR4273', 'NOS3', 'MIR663B', 'ROCK1P1', 'MIR663A',
#          'LCE1B', 'CPT2', 'SCARNA6', 'SNX16', 'LOC100526771', 'KLRC1',
#          'CPXM1', 'SCYL1', 'OR4D5'], dtype=object)],
#  'ZZZ3_GM12878': [array(['BRF2', 'GIN1', 'NOSIP', 'PEX13', 'KLHL20', 'SUPT7L', 'FLJ40852',
#          'DOK2', 'LAS1L', 'COPS2', 'SNRNP27', 'VPS25', 'ZNF799', 'C11ORF57',
#          'ALG10B', 'TARS2', 'BRWD3', 'KLHDC9', 'SNORA21', 'FRA10AC1',
#          'STX16', 'LOC100306975', 'UBE3B', 'CASC4', 'NSL1', 'HIRA', 'NPAS3',
#          'TEFM', 'EIF1AD', 'DHX33', 'KIAA1324', 'BASP1', 'RBBP5', 'ZNF827',
#          'LOC100507250', 'STX16-NPEPL1', 'TMEM69', 'STX6', 'DMAP1',
#          'MLLT10P1', 'MAP3K8', 'SNORD58B', 'FZD1', 'TOP3B', 'VPS13B',
#          'NR2F1', 'COMMD2', 'FLI1', 'SNORD58A', 'MED22', 'LINC00426',
#          'SNORD24', 'INTS5', 'DUS1L', 'NOL12', 'MNAT1', 'GMFB', 'GRIA3',
#          'COX16', 'TPI1P2', 'GSTCD', 'TACO1', 'IPO4', 'COPS7B', 'ARHGAP1',
#          'C20ORF4', 'MTBP', 'TMEM101', 'RGS5', 'MRPL21', 'ALKBH3', 'MRPL3',
#          'NME1-NME2', 'DSTYK', 'GLIPR1', 'ALKBH1', 'CDK5RAP1', 'ACAD11',
#          'LOC285456', 'KLK10', 'REXO4', 'FAM126B', 'NME1', 'SENP1', 'NSA2',
#          'BCL9', 'LSG1', 'PCNA-AS1', 'NDUFS7', 'NDUFS3', 'SNORD43', 'CENPP',
#          'MITD1', 'GALK2', 'INTS12', 'SHOX2', 'SH2D2A', 'C11ORF2', 'WDR24',
#          'CHD2', 'EMG1', 'MRPL40', 'FOXS1', 'MLEC', 'MAN2C1', 'USP30',
#          'FLJ42709', 'SPAG8', 'G0S2', 'NR1H2', 'MRPL48', 'KCTD10', 'SNX16',
#          'EIF3F', 'SSBP1', 'FAM98B', 'SEC22B', 'GCFC1', 'ITGB3BP', 'TIMM9',
#          'SEMA3A', 'MDGA1', 'NUP107', 'GBA', 'C2ORF68', 'ZDHHC6', 'CXXC4',
#          'SMG8', 'CSTF2T', 'SMG7', 'SNORD15A', 'JPX', 'SNORA7A', 'SLITRK3',
#          'AIFM2', 'C7ORF11', 'NUF2', 'C7ORF10', 'DKFZP564C196', 'PRRG2',
#          'C11ORF49', 'DCAF10'], dtype=object)],
#  'ZZZ3_HELA-S3': [array(['TGFB3', 'RPS7', 'NOSIP', 'ROCK1P1', 'KLHL20', 'SUPT7L', 'FLJ40852',
#          'MIR4734', 'COPS2', 'VPS25', 'CDK12', 'C11ORF57', 'ALG10B', 'TARS2',
#          'BRWD3', 'KLHDC9', 'SNORA21', 'C11ORF74', 'SNORA4', 'STX16',
#          'LOC100306975', 'SRSF1', 'MTMR9', 'CASC4', 'TEFM', 'YY1', 'BASP1',
#          'LOC100507250', 'STX16-NPEPL1', 'STX6', 'DMAP1', 'MLLT10P1',
#          'MAP3K8', 'FZD2', 'MIR4273', 'FANCM', 'COG4', 'IGFL4', 'NR2F1',
#          'MIR21', 'MED22', 'SNORD24', 'INTS5', 'GMFB', 'COX16', 'IPO4',
#          'COPS7B', 'ARHGAP1', 'C20ORF4', 'HOXB13', 'MTBP', 'NME1-NME2',
#          'C12ORF59', 'CDK5RAP1', 'UGT3A2', 'FGFBP3', 'ZFHX3', 'SMC1B',
#          'REXO4', 'TYR', 'FAM126B', 'NME1', 'SENP1', 'BCL9', 'CENPL', 'PIGL',
#          'CENPP', 'GALK2', 'SNORA63', 'DLX3', 'SLC35F3', 'C11ORF2', 'LMOD1',
#          'WDR24', 'C17ORF75', 'FOXS1', 'USP30', 'FLJ42709', 'KRR1', 'UTP3',
#          'NR1H2', 'MRPL48', 'KCTD10', 'SNX16', 'EIF3F', 'SSBP1', 'FAM98B',
#          'SEC22B', 'GCFC1', 'ITGB3BP', 'SEMA3A', 'TIMM9', 'MDGA1', 'NUP107',
#          'GBA', 'C2ORF68', 'ZDHHC6', 'EFCAB7', 'SMG8', 'SMG7', 'SLITRK3',
#          'AIFM2', 'NKAPP1', 'DKFZP564C196', 'PRRG2'], dtype=object)]}

# %%
#Create an empty dataframe to house entries from the dictionary
#for each key, list value pairs
df = pd.DataFrame(columns = ['Transcription_Factor', 'Target'])
df
# Out:
# Empty DataFrame
# Columns: [Transcription_Factor, Target]
# Index: []

# %%
for key, value in d.items():
    lst = value[0]
    for i in range(0, len(lst)):
        term = lst[i]
        df2 = pd.DataFrame([[key, term]], 
                            columns = ['Transcription_Factor', 'Target'])
        df = df.append(df2)

# %%
df
# Out:
#    Transcription_Factor        Target
# 0              PML_K562      CASP8AP2
# 0              PML_K562     NIPSNAP3B
# 0              PML_K562         FNBP4
# 0              PML_K562           BAD
# 0              PML_K562        BTBD19
# 0              PML_K562       WDR83OS
# 0              PML_K562      KIAA1586
# 0              PML_K562         LNPEP
# 0              PML_K562        PRKAB1
# 0              PML_K562        BTBD10
# 0              PML_K562         LARP4
# 0              PML_K562        PRKAB2
# 0              PML_K562        COMTD1
# 0              PML_K562        NECAP1
# 0              PML_K562           SCD
# 0              PML_K562        NECAP2
# 0              PML_K562         LAS1L
# 0              PML_K562          TFR2
# 0              PML_K562        MTHFD1
# 0              PML_K562          SCO1
# 0              PML_K562       ZC3H11A
# 0              PML_K562         ORAI1
# 0              PML_K562       CIAPIN1
# 0              PML_K562         FSIP1
# 0              PML_K562         NPRL3
# 0              PML_K562        IFT172
# 0              PML_K562          IWS1
# 0              PML_K562        PRKAA1
# 0              PML_K562        PTPDC1
# 0              PML_K562         SNX30
# ..                  ...           ...
# 0         MEF2C_GM12878         ERCC1
# 0         MEF2C_GM12878        TBC1D4
# 0         MEF2C_GM12878         ZPBP2
# 0         MEF2C_GM12878     LOC729013
# 0         MEF2C_GM12878     HIST1H2BG
# 0         MEF2C_GM12878       SNORD68
# 0         MEF2C_GM12878         SSBP1
# 0         MEF2C_GM12878          KRAS
# 0         MEF2C_GM12878         SSBP2
# 0         MEF2C_GM12878       B4GALT7
# 0         MEF2C_GM12878     HIST1H2BB
# 0         MEF2C_GM12878       B4GALT6
# 0         MEF2C_GM12878     HIST1H2BD
# 0         MEF2C_GM12878     HIST1H2BO
# 0         MEF2C_GM12878        CAMK2D
# 0         MEF2C_GM12878  LOC100131060
# 0         MEF2C_GM12878     HIST1H2BK
# 0         MEF2C_GM12878       POLDIP3
# 0         MEF2C_GM12878     HIST1H2BJ
# 0         MEF2C_GM12878       CCDC28A
# 0         MEF2C_GM12878           DDN
# 0         MEF2C_GM12878           JPX
# 0         MEF2C_GM12878         HMGCL
# 0         MEF2C_GM12878         POLD4
# 0         MEF2C_GM12878          POLE
# 0         MEF2C_GM12878        TAS1R1
# 0         MEF2C_GM12878       SNORD54
# 0         MEF2C_GM12878         BPNT1
# 0         MEF2C_GM12878          POLG
# 0         MEF2C_GM12878       SNORD52
#
# [1771410 rows x 2 columns]

# %%
df.reset_index(drop = True, inplace = True)

df
# Out:
#         Transcription_Factor        Target
# 0                   PML_K562      CASP8AP2
# 1                   PML_K562     NIPSNAP3B
# 2                   PML_K562         FNBP4
# 3                   PML_K562           BAD
# 4                   PML_K562        BTBD19
# 5                   PML_K562       WDR83OS
# 6                   PML_K562      KIAA1586
# 7                   PML_K562         LNPEP
# 8                   PML_K562        PRKAB1
# 9                   PML_K562        BTBD10
# 10                  PML_K562         LARP4
# 11                  PML_K562        PRKAB2
# 12                  PML_K562        COMTD1
# 13                  PML_K562        NECAP1
# 14                  PML_K562           SCD
# 15                  PML_K562        NECAP2
# 16                  PML_K562         LAS1L
# 17                  PML_K562          TFR2
# 18                  PML_K562        MTHFD1
# 19                  PML_K562          SCO1
# 20                  PML_K562       ZC3H11A
# 21                  PML_K562         ORAI1
# 22                  PML_K562       CIAPIN1
# 23                  PML_K562         FSIP1
# 24                  PML_K562         NPRL3
# 25                  PML_K562        IFT172
# 26                  PML_K562          IWS1
# 27                  PML_K562        PRKAA1
# 28                  PML_K562        PTPDC1
# 29                  PML_K562         SNX30
# ...                      ...           ...
# 1771380        MEF2C_GM12878         ERCC1
# 1771381        MEF2C_GM12878        TBC1D4
# 1771382        MEF2C_GM12878         ZPBP2
# 1771383        MEF2C_GM12878     LOC729013
# 1771384        MEF2C_GM12878     HIST1H2BG
# 1771385        MEF2C_GM12878       SNORD68
# 1771386        MEF2C_GM12878         SSBP1
# 1771387        MEF2C_GM12878          KRAS
# 1771388        MEF2C_GM12878         SSBP2
# 1771389        MEF2C_GM12878       B4GALT7
# 1771390        MEF2C_GM12878     HIST1H2BB
# 1771391        MEF2C_GM12878       B4GALT6
# 1771392        MEF2C_GM12878     HIST1H2BD
# 1771393        MEF2C_GM12878     HIST1H2BO
# 1771394        MEF2C_GM12878        CAMK2D
# 1771395        MEF2C_GM12878  LOC100131060
# 1771396        MEF2C_GM12878     HIST1H2BK
# 1771397        MEF2C_GM12878       POLDIP3
# 1771398        MEF2C_GM12878     HIST1H2BJ
# 1771399        MEF2C_GM12878       CCDC28A
# 1771400        MEF2C_GM12878           DDN
# 1771401        MEF2C_GM12878           JPX
# 1771402        MEF2C_GM12878         HMGCL
# 1771403        MEF2C_GM12878         POLD4
# 1771404        MEF2C_GM12878          POLE
# 1771405        MEF2C_GM12878        TAS1R1
# 1771406        MEF2C_GM12878       SNORD54
# 1771407        MEF2C_GM12878         BPNT1
# 1771408        MEF2C_GM12878          POLG
# 1771409        MEF2C_GM12878       SNORD52
#
# [1771410 rows x 2 columns]

# %%
df['PubMed_ID'] = ' 15499007'

# %%
#Insert first four columns for .sig file format (NaNs)
df.insert(1, 'NA-1', str(np.nan))
df.insert(2, 'NA-2', str(np.nan))
df.insert(3, 'NA-3', str(np.nan))
df.insert(4, 'NA-4', str(np.nan))

#Insert first four columns for .sig file format (NaNs)
df.insert(6, 'NA-5', str(np.nan))
df.insert(7, 'NA-6', str(np.nan))
df.insert(8, 'NA-7', str(np.nan))
df.insert(9, 'NA-8', str(np.nan))

#Insert column corresponding to sign 
df.insert(10, 'Sign', str(np.nan))

#Insert column specifying interaction type as unknown
df.insert(11, 'Interaction', str(np.nan))

#View dataframe
df.head()
# Out:
#   Transcription_Factor NA-1 NA-2 NA-3 NA-4     Target NA-5 NA-6 NA-7 NA-8  \
# 0             PML_K562  nan  nan  nan  nan   CASP8AP2  nan  nan  nan  nan
# 1             PML_K562  nan  nan  nan  nan  NIPSNAP3B  nan  nan  nan  nan
# 2             PML_K562  nan  nan  nan  nan      FNBP4  nan  nan  nan  nan
# 3             PML_K562  nan  nan  nan  nan        BAD  nan  nan  nan  nan
# 4             PML_K562  nan  nan  nan  nan     BTBD19  nan  nan  nan  nan
#
#   Sign Interaction  PubMed_ID
# 0  nan         nan   15499007
# 1  nan         nan   15499007
# 2  nan         nan   15499007
# 3  nan         nan   15499007
# 4  nan         nan   15499007

# %%
#Create dictionary 'sigd' with index numbers as keys
sigd = dict([(key, '') for key in df.index])

# loop through rows with iterrows()
for index, rowData in df.iterrows():
    line = ('\t'.join(rowData))
    sigd[index] = line
    
#Transfer tab-separated info into a new txt file
#Make sure to include in ReadMe corresponding column names
with open('ENCODE_2014.sig', 'w') as openfile:
    for index in sigd:
        openfile.write(str(sigd[index]) + '\n')
